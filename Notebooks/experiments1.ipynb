# %% [markdown]
# ## Neural Net Option Pricer - Gaussian Weightes Loss for ATM and Short Dated Optons
#
# ## Research Question
# Can a simple feed forward network, trained with a gaussian-weighted loss function focused on ATM can outperform baseline models for short dated ATM options
#
# ## Notebook Outline
# 1. Generate synthetic blackscholes training data using sobol sequence sampling over (M,T,sigma)
# 2. Train a baseline model on synthtic data and IV mapping from yfinance
# 3. Train a Gaussian Weighted Loss:
#     - Check overall error
#     - ATM Error
# 4. Check on Real Data (SPY Option Chain)
#     - clean the stale quotes
#     - fit implied volatility surface
#     - Checks for Model (non-negativity, Smile, Skew, Calendar variance monocity)
# 5. Report runtime speed and gradient stability
#
# ## Key defination
# - Log-moneyness $M = ln(S/K)$
# - time to expiry $T$ in years
# - Implied Volatitlity: $\sigma_{impl}$
#
#
# ## Hypothesis
# Weighted loss will improve accuracy in regions that matter most for trading/hedging (ATM/near-term),
# at the cost of slightly worse fit in far OTM/long-dated regions

# %%
pip install yfinance
# Out:
# Requirement already satisfied: yfinance in /Users/karandeepsonewane/Projects/Option Pricing using Neural Network/.venv/lib/python3.13/site-packages (1.0)
# Requirement already satisfied: pandas>=1.3.0 in /Users/karandeepsonewane/Projects/Option Pricing using Neural Network/.venv/lib/python3.13/site-packages (from yfinance) (2.3.3)
# Requirement already satisfied: numpy>=1.16.5 in /Users/karandeepsonewane/Projects/Option Pricing using Neural Network/.venv/lib/python3.13/site-packages (from yfinance) (2.4.0)
# Requirement already satisfied: requests>=2.31 in /Users/karandeepsonewane/Projects/Option Pricing using Neural Network/.venv/lib/python3.13/site-packages (from yfinance) (2.32.5)
# Requirement already satisfied: multitasking>=0.0.7 in /Users/karandeepsonewane/Projects/Option Pricing using Neural Network/.venv/lib/python3.13/site-packages (from yfinance) (0.0.12)
# Requirement already satisfied: platformdirs>=2.0.0 in /Users/karandeepsonewane/Projects/Option Pricing using Neural Network/.venv/lib/python3.13/site-packages (from yfinance) (4.5.1)
# Requirement already satisfied: pytz>=2022.5 in /Users/karandeepsonewane/Projects/Option Pricing using Neural Network/.venv/lib/python3.13/site-packages (from yfinance) (2025.2)
# Requirement already satisfied: frozendict>=2.3.4 in /Users/karandeepsonewane/Projects/Option Pricing using Neural Network/.venv/lib/python3.13/site-packages (from yfinance) (2.4.7)
# Requirement already satisfied: peewee>=3.16.2 in /Users/karandeepsonewane/Projects/Option Pricing using Neural Network/.venv/lib/python3.13/site-packages (from yfinance) (3.19.0)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /Users/karandeepsonewane/Projects/Option Pricing using Neural Network/.venv/lib/python3.13/site-packages (from yfinance) (4.14.3)
# Requirement already satisfied: curl_cffi<0.14,>=0.7 in /Users/karandeepsonewane/Projects/Option Pricing using Neural Network/.venv/lib/python3.13/site-packages (from yfinance) (0.13.0)
# Requirement already satisfied: protobuf>=3.19.0 in /Users/karandeepsonewane/Projects/Option Pricing using Neural Network/.venv/lib/python3.13/site-packages (from yfinance) (6.33.4)
# Requirement already satisfied: websockets>=13.0 in /Users/karandeepsonewane/Projects/Option Pricing using Neural Network/.venv/lib/python3.13/site-packages (from yfinance) (16.0)
# Requirement already satisfied: cffi>=1.12.0 in /Users/karandeepsonewane/Projects/Option Pricing using Neural Network/.venv/lib/python3.13/site-packages (from curl_cffi<0.14,>=0.7->yfinance) (2.0.0)
# Requirement already satisfied: certifi>=2024.2.2 in /Users/karandeepsonewane/Projects/Option Pricing using Neural Network/.venv/lib/python3.13/site-packages (from curl_cffi<0.14,>=0.7->yfinance) (2026.1.4)
# Requirement already satisfied: soupsieve>=1.6.1 in /Users/karandeepsonewane/Projects/Option Pricing using Neural Network/.venv/lib/python3.13/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.8.1)
# Requirement already satisfied: typing-extensions>=4.0.0 in /Users/karandeepsonewane/Projects/Option Pricing using Neural Network/.venv/lib/python3.13/site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.15.0)
# Requirement already satisfied: pycparser in /Users/karandeepsonewane/Projects/Option Pricing using Neural Network/.venv/lib/python3.13/site-packages (from cffi>=1.12.0->curl_cffi<0.14,>=0.7->yfinance) (2.23)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/karandeepsonewane/Projects/Option Pricing using Neural Network/.venv/lib/python3.13/site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /Users/karandeepsonewane/Projects/Option Pricing using Neural Network/.venv/lib/python3.13/site-packages (from pandas>=1.3.0->yfinance) (2025.3)
# Requirement already satisfied: six>=1.5 in /Users/karandeepsonewane/Projects/Option Pricing using Neural Network/.venv/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/karandeepsonewane/Projects/Option Pricing using Neural Network/.venv/lib/python3.13/site-packages (from requests>=2.31->yfinance) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/karandeepsonewane/Projects/Option Pricing using Neural Network/.venv/lib/python3.13/site-packages (from requests>=2.31->yfinance) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/karandeepsonewane/Projects/Option Pricing using Neural Network/.venv/lib/python3.13/site-packages (from requests>=2.31->yfinance) (1.26.20)
#
# [notice] A new release of pip is available: 25.3 -> 26.0
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
from scipy.stats import norm, qmc
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import yfinance
import datetime
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns

# %% [markdown]
# ## Dependencies
# Reproducibility notes:
# - Random seeds are set where relevant (Sobol seed, torch seed).
# - Real-data results depend on the market snapshot time when yfinance is queried.

# %% [markdown]
# ## Problem Setup and Learning Objective
#
# ### Synthetic setting (primary experiment)
# We study European option pricing under the Black–Scholes model and train a neural network to learn the **normalized option price**
# $\frac{C}{K} = f(M, T, \sigma)$
# where:
# - $M = \ln(S/K)$ is log-moneyness,
# - $T$ is time to maturity (years),
# - $\sigma$ is volatility.
#
# Using the homogeneity of Black–Scholes, pricing in units of the strike removes scale dependence and improves numerical stability.
#
# ### Learning task
# Given inputs:
# $x = (M, T, \sigma)$
#
# learn a smooth function approximator for strike normalized price $C/K$
#
# ### Input domain
# The synthetic data spans a broad but realistic option surface:
# - $M \in [-1.5, 1.5]$
# - $T \in [0.01, 2.0]$ years
# - $\sigma \in [0.05, 0.90]$
# - Risk-free rate $r$ is fixed initially
#
# ### Sampling strategy
# We use **Sobol low-discrepancy sequences** instead of IID Monte Carlo sampling to:
# - ensure uniform coverage of the domain,
# - reduce clustering,
# - improve convergence of the neural network for a fixed sample size.
#
# Time is sampled uniformly in $\sqrt{T}$  then squared to increase samples near short maturities, which are most sensitive in option pricing. Log(S/K) moneyness is sampled directly to have a uniform sample accross moneyness

# %% [markdown]
# __________________
#
# #### Rationale
# Although long-dated options exist, the option market is structurally and economically dominated by short-dated contracts, motivating sampling and loss weighting schemes that emphasize small Time to maurity. $𝑇$

# %%
## log(S/K) sample vs S/K sample then taking log
## we are using uniform sampling for log(s/k) to avoid non-meaningful 
sampler = qmc.Sobol(d=1, scramble=True, seed=42)
sample = sampler.random_base2(m=10)
log_sk = qmc.scale(sample, -1.5, 1.5)
sk = qmc.scale(sample, 0.22, 4.48) 
sk = np.log(sk)

# plt
plt.hist(log_sk, bins=50, alpha=0.6, color='red', label='Sample LOG(S/K) directly')
plt.hist(sk, bins=50, alpha=0.6, label='Sample S/K then log(S/K)')
plt.xlabel("Moneyness")
plt.ylabel("Frequency")
plt.show()

# %%
# sampling T and then taking root vs sampling root T and then applying sqaure
# this method increases the sampling for short dated maturities
sampler = qmc.Sobol(d=1, scramble=True, seed=42)
sample = sampler.random_base2(m=10)
l_roott = np.sqrt(0.01)
u_roott = np.sqrt(2)
troot = qmc.scale(sample, l_roott, u_roott)
t = qmc.scale(sample, 0.01, 2)
T = troot**2

# plt 
plt.hist(T, bins=50, alpha=0.6, color='red', label='sampled Root T then Square')
plt.hist(t, bins=50, alpha=0.6, label='Sampled T directly')
plt.xlabel("Time to Maturity in Years")
plt.ylabel("")
plt.legend()
plt.show()

# %% [markdown]
# ## Synthetic Data Genration using closed form BlackScholes
#
# We are using sobol sequence to generate uniform samples whcih can be used to create data samples using closed form blackscholes for the supervise learning problem
#
# - **Input** $X \in (M, T, \sigma)$
# - **Target** $y = C/K$ (option price normalized by the strike)
#
#
# ##### Components:
#
# 1. `BlackScholesPricer`: analytical BS pricing
# 2. `LogMoneynessPricer`: this enforce homogenity by K = 1 and setting up $S=\exp(M)$
# 3. `SobolSampler`: it generates uniform low-descrepency samples over $x \in (M, \sqrt{T}, \sigma)$
# 4. `BSDataGenerator`:  converts the data into X and y for training

# %%
# blackscholes implementation 
class BlackScholesPricer: 
    def __init__(self, r: float):
        self.r = r                                            # since r is a model parameter we initialize this seperately      

    def price(self, S, K, T, sigma, option_type='C'):
        """
        Calculates the blackscholes option price for call and put options 
        Args:
            S (float): Stock price       
            K (float): Strike price                
            T (float): Time to maturity in years 
            r (float): risk free rate 
            sigma (float): volatility of the underlying 
        Returns:
            option price (float)
        Raises:
            ValueError: if sigma < 0 and T <= 0 
        """
        # input casting and vectorize
        S, K, T, sigma = map(np.asarray, (S, K, T, sigma))
        
        # Input validation 
        if np.any(sigma < 0):
            raise ValueError("Volatility cannot be negative")
        if np.any(T <= 0):
            raise ValueError("Expiry must be > 0")
        
        # black scholes variables 
        sqrt_T = np.sqrt(T)
        d1 = (np.log(S / K) + (self.r + 0.5 * sigma**2) * T) / (sigma * sqrt_T)
        d2 = d1 - sigma * sqrt_T
        
        # dic factor
        disc = np.exp(-self.r * T)
        
        # black scholes pricing formula 
        if option_type == 'C':
            price = S * norm.cdf(d1) - K * disc * norm.cdf(d2) 
        elif option_type == 'P':
            price = K * disc * norm.cdf(-d2) - S * norm.cdf(-d1) 
        else:
            raise ValueError(f"option type must be 'C' or P got{option_type}")
            
        return price

# %% [markdown]
# ## Homogenity and Model Target
# Under Black-Scholes model, the European option price is homogeneous of degree one for the stock price $S$ and strike price $K$ meaning $C(\lambda F, \lambda S, K) = \lambda C(S, K)$ the price of an option is affected by the ratio of S and K rather their absolute values. Options, Futures and Derivatives Hull (2018). We exploit this property by training the neural network on normalized price target C/K, thus removing the scale dependence and improves numerical conditioning.
#
# This is an effective strategy in training the nerual network as this reduce the input space into relative moneyness rather than learning abosolute prices (e.g. learning a Amazon option with strike 150 and stock 239 vs Ford strike of 5 with stock 13). This

# %%
# since the blacksholes is homogenous of degree one we can price options in the unit of K 
# check the derivation at
class LogMoneynessPricer:
    
    def __init__(self, bs_pricer: BlackScholesPricer):           
        self.bs_pricer = bs_pricer
        
    def price(self, M, T, sigma, option_type='C'):
        M, T, sigma = map(np.asarray, (M, T, sigma))
        
        K = 1.0                                           # price in units of K                 
        S = np.exp(M) * K                                 # M = log(S/K) => exp(M) = S/K => exp(M)*K = S 
        
        C = self.bs_pricer.price(S, K, T, sigma, option_type)
        return C / K

# %%
# data Generator 
# Sobol sampler 
class SobolSampler:
    def __init__(self, l_bounds, u_bounds, seed=42):
        self.l_bounds = l_bounds 
        self.u_bounds = u_bounds
        self.sampler = qmc.Sobol(d=3, scramble=True, seed=seed)                         # unit qube  [0,1]^3
        
    def sample(self, m):
        unit_cube = self.sampler.random_base2(m=m)                          # base2 for reproducibility 
        return qmc.scale(unit_cube, self.l_bounds, self.u_bounds)           # .scale(sample, l_bounds, u_bounds)

# Data generator 
class BSDataGenerator:
    def __init__(self, sampler: SobolSampler, pricer: LogMoneynessPricer):
        self.sampler = sampler 
        self.pricer = pricer 
    
    def generate(self, m, option_type='C'):
        sample = self.sampler.sample(m)
        
        M, sqrt_T, sigma = sample.T                                         #transposing the sample
        T = sqrt_T**2                                                       #convert back sqrt(T) -> T 
        
        X = np.column_stack([M, T, sigma])                                 
        y = self.pricer.price(M, T, sigma, option_type)                    # price the options
        return X, y

# %% [markdown]
# ### Sampling
# Considering rate of interest r=0.04

# %%
# define the bounds
l_bounds = [-1.5, np.sqrt(0.01), 0.05]              # lower bounds for sobol sample [lower_moneyness, lower_T, lower_sigma]
u_bounds = [1.5, np.sqrt(2), 0.90]                  # upper bounds for sobol

# %%
bs = BlackScholesPricer(r=0.04)                     # define rate 
sample = SobolSampler(l_bounds, u_bounds)           # call SobolSampler 
logm_pricer = LogMoneynessPricer(bs)                # wrap bs to logmoneyness 
gen = BSDataGenerator(sample, logm_pricer)          # generate data 
X, y = gen.generate(m=18)

# %% [markdown]
# ##### Converting input and target into Tensor

# %%
X = torch.tensor(X, dtype=torch.float32)
y = torch.tensor(y, dtype=torch.float32)
print(X.shape)
print(y.shape) 
print(f"target option price:", y)
# Out:
# torch.Size([262144, 3])
# torch.Size([262144])
# target option price: tensor([0.2305, 2.0507, 0.3978,  ..., 0.4003, 2.0562, 0.0282])

# %%
# plt frquency of strike normalized option price generated by sobol - BS Analystical Solution 
y_ck = y
plt.hist(y_ck, bins=40, density=True, alpha=0.7)
plt.xlabel("Strike Noramlized Option Price")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
print("X shape:", X.shape)
print("y shape:", y.shape)
print("X dtype:", X.dtype)
print("y dtype:", y.dtype)

# Ensure y is 1D
y = y.squeeze()
# Out:
# X shape: torch.Size([262144, 3])
# y shape: torch.Size([262144])
# X dtype: torch.float32
# y dtype: torch.float32

# %% [markdown]
# Thus we have more options which are worthless, meaning they finished OTM, which represents the real market conditions.

# %% [markdown]
# ## Baseline and Gaussian Weighted Training (On Synthetic Blackscholes data)
# We train 2 idential MLPs on the synthetic BlackScholes dataset:
# 1. **Baseline model:** minimized standard mean sqaured error over all samples
# 2. **Gaussian-weighted (WMSE)** minimizes loss around ATM and Short datad options
#
# This section trains two identical neural networks on the same synthetic dataset:
# 1. Baseline model trained with MSE.
# 2. Weighted model trained with WMSE.
#
# We then compare overall error, error specifically on at the money options, and basic constraint diagnostics

# %% [markdown]
# #### Train Val Test Split
# - Random split for better optimization as the data is generated using sobol
# - Split 70:15:15

# %%
# Random split (Sobol is structured thus random split helps optimisation)
torch.manual_seed(42)

# 70:15:15; Train:Val:Test split 
n = len(X)
indices = torch.randperm(n)
train_end = int(0.70 * n)
val_end = int(0.85 * n)

# create indx from the random sample 
train_idx = indices[:train_end]
val_idx = indices[train_end:val_end]
test_idx = indices[val_end:]

# use idx to create split 
# train 
x_train = X[train_idx]
y_train = y[train_idx]

# val
x_val = X[val_idx]
y_val = y[val_idx]

# test 
x_test = X[test_idx]
y_test = y[test_idx]

# split checks
print(indices[0])
print(f"Train: {len(x_train)}, Val: {len(x_val)}, Test: {len(x_test)}")
# Out:
# tensor(121958)
# Train: 183500, Val: 39322, Test: 39322

# %% [markdown]
# #### Neural Net Design
# - A simple 3 layer feed forward network is choosen with 64 neurons and ELU activation for the Layer 1 and 2

# %%
# option neural network
# 3 layer simple feed forward network with ELU activation at layer 1 and 2 
class OptionPricer(nn.Module):
    def __init__(self):
        super().__init__()
        self.layer1 = nn.Linear(3, 64)
        self.activation = nn.ELU()
        self.layer2 = nn.Linear(64, 64)
        self.layer3 = nn.Linear(64, 1)

    def forward(self, x):
        x = self.activation(self.layer1(x))
        x = self.activation(self.layer2(x))
        x = self.layer3(x)
        return x

# %% [markdown]
# ______________________________________

# %% [markdown]
# ### Loss Function Design
#
# We introduce a Gaussian kernel-based weighting scheme that prioritizes
# accuracy in economically important regions of the parameter space i.e. (Short dated and ATM Options) The
# weight assigned to each training sample is defined as:
#
# $$w_i = \exp\left(-\frac{M_i^2}{2\lambda^2} - \beta T_i \right), \tag{1}$$
#
# where $M_i$ represents the log-moneyness, $T_i$ is the time to maturity,
# $\lambda$ controls the width of the Gaussian kernel around at-the-money
# options, and $\beta$ governs the emphasis on near-expiry contracts.
#
# Moneyness is a quadratic term which creates a symetric bell curve at M=0 that is ATM options, and decays equally for in-the-money and out-of-money options. The Time component is linerly penalized meaning meaning as we come closer to near expiry options the error are more penalized compared to the errors at long dated securities.
#
# The weighted mean squared error loss function is then given by:
#
# $$L_{\text{WMSE}} = \frac{\sum_{i=1}^N w_i\, (y_i-\hat{y}_i)^2}{\sum_{i=1}^N w_i}, \tag{2}$$
#
# where $y_i$ denotes the true option price and $\hat{y}_i$ is the neural
# network prediction. The denominator normalizes the weights to prevent
# biasing the overall loss magnitude.
#
# For comparison, we also train a baseline model using the standard unweighted
# mean squared error:
#
# $$L_{\text{MSE}} = \frac{1}{N}\sum_{i=1}^N (y_i-\hat{y}_i)^2 \tag{3}$$

# %% [markdown]
# #### Understanding Gaussian Loss Function
# **Next 3 code blocks we will try to understand the behaviour of gaussian weighted loss function in terms of Moneyness and Time to Maturity**. The objective of the loss function is to penalize heavily on the ATM and Short-dated maturities for accuracy near the delta important region.
#
# Important Considerations:
# 1. Loss function must be smooth - so that the gradient does not get stuck in abrupt change
# 2. Symmetric aroud ATM - so that delta of option changes symmetrically arround the mean (M=0), where $M=ln(S/K), note delta symmetrically decreases as option price moves away from the ATM (theoretically)
# 3. Weight must be bounded between $(0,1]$, i.e. $ 0 < w_i(M,T) < 1$ - this makes it meaningful for traing the neural net, the objectve is to have $w_i(0,T)=1$ - that is for a ATM, near expiry option the weight must be $\sim 1$

# %%
# defining weighted loss functionn 
def weight_function(M, T, lambda_m=1, beta=0.5):
    """
    Inputs
    M: moneyness (log(S/K) or S/K - 1)
    T: time to maturity
    lambda_m: bandwidth for moneyness Gaussian
    beta: decay rate for time
    
    Output 
    w_i: weights for the loss function 
    """
    M = np.asarray(M, dtype=float)         # vectorize M and T
    T = np.asarray(T, dtype=float)
    
    penalty_M = M**2 / (2 * lambda_m**2) # penalty for Moneyness error 
    penalty_T = beta * T                 # penalty for Time to Maturity 
    return np.exp(-penalty_M - penalty_T) # gaussian weighted loss function with exp-gaussian (penalty_m) and exp penalty on time
 
# Test single point
M_test= [0, 0, 1, -1.5, 1.5] 
T_test = [0, 0.8, 0, 2, 2] 

# weights 
w_test = weight_function(M_test, 
                         T_test,
                         lambda_m=1, 
                         beta=0.5)

for m, t, w in zip(M_test, T_test, w_test):
    print(f"M={m},T={t}: Weights={w:.6f}")
print("For ATM-ODTE Option Weights is one")
# Out:
# M=0,T=0: Weights=1.000000
# M=0,T=0.8: Weights=0.670320
# M=1,T=0: Weights=0.606531
# M=-1.5,T=2: Weights=0.119433
# M=1.5,T=2: Weights=0.119433
# For ATM-ODTE Option Weights is one

# %% [markdown]
# #### 2d Weights Function

# %%
# Parameter
lambda_m = 1
beta = 0.5

# 1D Slices
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

# Weight vs Moneyness
M = np.linspace(-1.5, 1.5, 200)                              
for T in [0.1, 0.25, 0.5, 1.0]:                              # for all Time to maturity 
    w = weight_function(M, T, lambda_m, beta)
    ax1.plot(M, w, label=f'T = {T:.2f}', linewidth=2)

ax1.axvline(0, color='red', linestyle='--', alpha=0.5)
ax1.set_xlabel('Log-Moneyness (M)', fontsize=12)
ax1.set_ylabel('Weight', fontsize=12)
ax1.set_title(f'Weight vs Log-Moneyness (λ_m={lambda_m}, β={beta})', fontsize=13)
ax1.legend()
# Weight vs Time   
                   
T = np.linspace(0, 1.5, 200)
for M in [0.0, 0.1, 0.5, 1, 1.5]:
    w = weight_function(M, T, lambda_m, beta)
    print(f"{M:<8.1f} {w.min():<12.6f} {w.max():<12.6f} {w.mean():<12.6f} {w.std():<12.6f}")
    label = 'ATM' if M == 0 else f'M = {M:.1f}'
    ax2.plot(T, w, label=label, linewidth=2)

half_life = np.log(2) / beta
ax2.axvline(half_life, color='orange', linestyle='--', alpha=0.5)
ax2.text(half_life + 0.05, 0.5, f'Half-life\n({half_life:.2f}y)', 
         fontsize=9, color='orange')
ax2.set_xlabel('Time to Maturity (years)', fontsize=12)
ax2.set_ylabel('Weight', fontsize=12)
ax2.set_title(f'Weight vs Time (λ_m={lambda_m}, β={beta})', fontsize=13)
ax2.legend()
ax2.grid(alpha=0.3)
ax2.set_ylim([0, 1.05])
plt.show()
# Out:
# 0.0      0.472367     1.000000     0.703675     0.152397
# 0.1      0.470011     0.995012     0.700166     0.151637
# 0.5      0.416862     0.882497     0.620991     0.134490
# 1.0      0.286505     0.606531     0.426801     0.092433
# 1.5      0.153355     0.324652     0.228450     0.049476

# %% [markdown]
# >Left:
# >- The weights in the gaussian moneyness decreases smoothly and symmetrically when moved away from ATM (M=0)
# >- The peak of the curve reduces as T increases, therefore the weights of the loss function increases as the option reaches near-expiry.
# >- the weights decay is controled by lambda_m which controls the width of the curve
#
# >Right:
# >- Weights decreases monotonically with increase in Time to Maturity, focusing on short dated maturities
# >- Decay is smooth, controlled by time decay parameter $\beta$

# %% [markdown]
# ##### Gaussian Loss Weights Visualization: Heat Map

# %%
# Heatmap
fig, ax = plt.subplots(figsize=(8, 5))

# Create grid
M = np.linspace(-1.5, 1.5, 150)
T = np.linspace(0.01, 2, 150)
M_grid, T_grid = np.meshgrid(M, T)
W = weight_function(M_grid, T_grid, lambda_m, beta)

# plt heatmap
im = ax.contourf(M_grid, T_grid, W, levels=20, cmap='RdYlGn')
cs = ax.contour(M_grid, T_grid, W, levels=[0.2, 0.4, 0.6, 0.8], 
                colors='black', linewidths=1, alpha=0.4)
ax.clabel(cs, inline=True, fontsize=9, fmt='%.1f')

# Mark ATM and priority region
ax.axvline(0, color='blue', linestyle='--', linewidth=2, alpha=0.7, label='ATM')
rect = plt.Rectangle((-0.15, 0), 0.3, 0.6, fill=False, edgecolor='red', 
                     linewidth=2, linestyle='--', label='High-weight region')
ax.add_patch(rect)

# Style
plt.figure(figsize=(8,5))
plt.colorbar(im, ax=ax, label='Weight')
ax.set_xlabel('Log-moneyness (M)', fontsize=12, fontweight='bold')
ax.set_ylabel('Time to Maturity (years)', fontsize=12, fontweight='bold')
ax.set_title(f'Weight Function: w(M,T) \nλ_m={lambda_m}, β={beta}',
             fontsize=13, fontweight='bold')
ax.legend(loc='upper right', fontsize=10)
ax.grid(alpha=0.3, linestyle=':')
plt.tight_layout()
plt.savefig('weight_heatmap.pdf', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# /var/folders/_v/vfbxc80973l9zq3s4w559dzm0000gn/T/ipykernel_34062/2113950392.py:24: UserWarning: Adding colorbar to a different Figure <Figure size 800x500 with 2 Axes> than <Figure size 800x500 with 0 Axes> which fig.colorbar is called on.
#   plt.colorbar(im, ax=ax, label='Weight')

# %% [markdown]
# ______________________________________________

# %% [markdown]
# ## Model Training using Gaussian Weighted Loss Function

# %%
# hyperparameters  
lambda_m = 1                 # increase to increase the width of the moneyness focus 
beta = 0.5                  # increase to focus on short term maturities 
 
# gaussian moneyness and time weights:                          w_i(M,T)
def gaussian_time_weights(x, lambda_m=0.25, beta=2.0):
    M = x[:, 0]        
    T = x[:, 1]                     
    w = torch.exp(-(M**2) / (2 * lambda_m**2) - beta * T)        
    return w

# normalized weighed mse : 1/n ∑ w_i(y - ycap)^2 / ∑ w_i
def weighted_mse(predictions, targets, weights):                           
    squared_errors = (targets - predictions) ** 2
    return torch.sum(weights * squared_errors) / torch.sum(weights)

# %%
# comptue weights for the train/val/test
weights_train = gaussian_time_weights(x_train, lambda_m=lambda_m, beta=beta)
weights_val   = gaussian_time_weights(x_val,   lambda_m=lambda_m, beta=beta)
weights_test  = gaussian_time_weights(x_test,  lambda_m=lambda_m, beta=beta)

print("Train weights:",
      f"min={weights_train.min().item():.4e},",
      f"max={weights_train.max().item():.4e},",
      f"mean={weights_train.mean().item():.4e},",
      f"median={weights_train.median().item():.4e}")

# diagnosis 
print(type(x_train), type(x_train[0,0]))
# Out:
# Train weights: min=1.1992e-01, max=9.9493e-01, mean=5.2675e-01, median=4.9496e-01
# <class 'torch.Tensor'> <class 'torch.Tensor'>

# %% [markdown]
# #### Baseline MSE MODEL (MSE)

# %% [markdown]
# ##### ADAM Optimizer
# For each parameter w:
# Maintain running averages:
# - m = β1 × m + (1-β1) × grad            # Momentum
# - v = β2 × v + (1-β2) × (grad)**2       # Variance
#
# Update:
# w = w - lr × m / (√v + ε)
#
# Benefits:
# - Faster than SGD
# - Adapts learning rate per parameter
# - Less sensitive to lr choice

# %%
# training baseline MSE Model 
EPOCHS = 1000
LR = 1e-3

# loss 
train_losses = []
val_losses = []

torch.manual_seed(42)
model_mse = OptionPricer()
opt_mse = torch.optim.Adam(model_mse.parameters(), lr=LR)
mse_loss = nn.MSELoss()

for epoch in range(EPOCHS):
    model_mse.train()
    pred = model_mse(x_train).squeeze()         
    loss = mse_loss(pred, y_train)

    opt_mse.zero_grad()
    loss.backward()
    opt_mse.step()
    
    train_losses.append(loss.item())
    
    
    model_mse.eval()
    with torch.no_grad():
        val_pred = model_mse(x_val).squeeze()
        val_loss = mse_loss(val_pred, y_val)
        val_losses.append(val_loss.item())
    print(f"[MSE]  Epoch {epoch:4d} | Train={loss.item():.6f} | Val={val_loss.item():.6f}")
# Out:
# [MSE]  Epoch    0 | Train=1.492273 | Val=1.350636
# [MSE]  Epoch    1 | Train=1.336076 | Val=1.208844
# [MSE]  Epoch    2 | Train=1.195809 | Val=1.082549
# [MSE]  Epoch    3 | Train=1.070945 | Val=0.970824
# [MSE]  Epoch    4 | Train=0.960553 | Val=0.872483
# [MSE]  Epoch    5 | Train=0.863447 | Val=0.786307
# [MSE]  Epoch    6 | Train=0.778411 | Val=0.711085
# [MSE]  Epoch    7 | Train=0.704237 | Val=0.645584
# [MSE]  Epoch    8 | Train=0.639693 | Val=0.588557
# [MSE]  Epoch    9 | Train=0.583532 | Val=0.538788
# [MSE]  Epoch   10 | Train=0.534542 | Val=0.495162
# [MSE]  Epoch   11 | Train=0.491610 | Val=0.456728
# [MSE]  Epoch   12 | Train=0.453792 | Val=0.422762
# [MSE]  Epoch   13 | Train=0.420367 | Val=0.392778
# [MSE]  Epoch   14 | Train=0.390858 | Val=0.366520
# [MSE]  Epoch   15 | Train=0.365014 | Val=0.343918
# [MSE]  Epoch   16 | Train=0.342771 | Val=0.325021
# [MSE]  Epoch   17 | Train=0.324186 | Val=0.309916
# [MSE]  Epoch   18 | Train=0.309352 | Val=0.298644
# [MSE]  Epoch   19 | Train=0.298315 | Val=0.291118
# [MSE]  Epoch   20 | Train=0.290992 | Val=0.287054
# [MSE]  Epoch   21 | Train=0.287105 | Val=0.285948
# [MSE]  Epoch   22 | Train=0.286152 | Val=0.287084
# [MSE]  Epoch   23 | Train=0.287423 | Val=0.289610
# [MSE]  Epoch   24 | Train=0.290068 | Val=0.292642
# [MSE]  Epoch   25 | Train=0.293205 | Val=0.295389
# [MSE]  Epoch   26 | Train=0.296046 | Val=0.297256
# [MSE]  Epoch   27 | Train=0.297998 | Val=0.297902
# [MSE]  Epoch   28 | Train=0.298719 | Val=0.297237
# [MSE]  Epoch   29 | Train=0.298121 | Val=0.295380
# [MSE]  Epoch   30 | Train=0.296321 | Val=0.292584
# [MSE]  Epoch   31 | Train=0.293571 | Val=0.289160
# [MSE]  Epoch   32 | Train=0.290180 | Val=0.285408
# [MSE]  Epoch   33 | Train=0.286447 | Val=0.281571
# [MSE]  Epoch   34 | Train=0.282615 | Val=0.277819
# [MSE]  Epoch   35 | Train=0.278849 | Val=0.274241
# [MSE]  Epoch   36 | Train=0.275240 | Val=0.270874
# [MSE]  Epoch   37 | Train=0.271823 | Val=0.267720
# [MSE]  Epoch   38 | Train=0.268601 | Val=0.264775
# [MSE]  Epoch   39 | Train=0.265570 | Val=0.262040
# [MSE]  Epoch   40 | Train=0.262736 | Val=0.259529
# [MSE]  Epoch   41 | Train=0.260112 | Val=0.257260
# [MSE]  Epoch   42 | Train=0.257723 | Val=0.255249
# [MSE]  Epoch   43 | Train=0.255587 | Val=0.253498
# [MSE]  Epoch   44 | Train=0.253712 | Val=0.251988
# [MSE]  Epoch   45 | Train=0.252082 | Val=0.250674
# [MSE]  Epoch   46 | Train=0.250657 | Val=0.249494
# [MSE]  Epoch   47 | Train=0.249378 | Val=0.248374
# [MSE]  Epoch   48 | Train=0.248173 | Val=0.247240
# [MSE]  Epoch   49 | Train=0.246972 | Val=0.246029
# [MSE]  Epoch   50 | Train=0.245712 | Val=0.244698
# [MSE]  Epoch   51 | Train=0.244351 | Val=0.243226
# [MSE]  Epoch   52 | Train=0.242866 | Val=0.241615
# [MSE]  Epoch   53 | Train=0.241258 | Val=0.239884
# [MSE]  Epoch   54 | Train=0.239545 | Val=0.238063
# [MSE]  Epoch   55 | Train=0.237752 | Val=0.236185
# [MSE]  Epoch   56 | Train=0.235913 | Val=0.234284
# [MSE]  Epoch   57 | Train=0.234056 | Val=0.232382
# [MSE]  Epoch   58 | Train=0.232201 | Val=0.230494
# [MSE]  Epoch   59 | Train=0.230361 | Val=0.228628
# [MSE]  Epoch   60 | Train=0.228541 | Val=0.226785
# [MSE]  Epoch   61 | Train=0.226741 | Val=0.224962
# [MSE]  Epoch   62 | Train=0.224957 | Val=0.223158
# [MSE]  Epoch   63 | Train=0.223187 | Val=0.221372
# [MSE]  Epoch   64 | Train=0.221428 | Val=0.219605
# [MSE]  Epoch   65 | Train=0.219684 | Val=0.217859
# [MSE]  Epoch   66 | Train=0.217955 | Val=0.216134
# [MSE]  Epoch   67 | Train=0.216243 | Val=0.214427
# [MSE]  Epoch   68 | Train=0.214546 | Val=0.212734
# [MSE]  Epoch   69 | Train=0.212859 | Val=0.211045
# [MSE]  Epoch   70 | Train=0.211175 | Val=0.209350
# [MSE]  Epoch   71 | Train=0.209483 | Val=0.207639
# [MSE]  Epoch   72 | Train=0.207775 | Val=0.205904
# [MSE]  Epoch   73 | Train=0.206043 | Val=0.204141
# [MSE]  Epoch   74 | Train=0.204283 | Val=0.202350
# [MSE]  Epoch   75 | Train=0.202495 | Val=0.200535
# [MSE]  Epoch   76 | Train=0.200683 | Val=0.198701
# [MSE]  Epoch   77 | Train=0.198851 | Val=0.196854
# [MSE]  Epoch   78 | Train=0.197006 | Val=0.195000
# [MSE]  Epoch   79 | Train=0.195152 | Val=0.193142
# [MSE]  Epoch   80 | Train=0.193293 | Val=0.191283
# [MSE]  Epoch   81 | Train=0.191430 | Val=0.189422
# [MSE]  Epoch   82 | Train=0.189563 | Val=0.187559
# [MSE]  Epoch   83 | Train=0.187692 | Val=0.185693
# [MSE]  Epoch   84 | Train=0.185816 | Val=0.183825
# [MSE]  Epoch   85 | Train=0.183935 | Val=0.181953
# [MSE]  Epoch   86 | Train=0.182050 | Val=0.180076
# [MSE]  Epoch   87 | Train=0.180160 | Val=0.178195
# [MSE]  Epoch   88 | Train=0.178265 | Val=0.176308
# [MSE]  Epoch   89 | Train=0.176365 | Val=0.174412
# [MSE]  Epoch   90 | Train=0.174458 | Val=0.172508
# [MSE]  Epoch   91 | Train=0.172544 | Val=0.170591
# [MSE]  Epoch   92 | Train=0.170621 | Val=0.168663
# [MSE]  Epoch   93 | Train=0.168687 | Val=0.166721
# [MSE]  Epoch   94 | Train=0.166743 | Val=0.164768
# [MSE]  Epoch   95 | Train=0.164789 | Val=0.162803
# [MSE]  Epoch   96 | Train=0.162825 | Val=0.160829
# [MSE]  Epoch   97 | Train=0.160854 | Val=0.158848
# [MSE]  Epoch   98 | Train=0.158876 | Val=0.156860
# [MSE]  Epoch   99 | Train=0.156892 | Val=0.154868
# [MSE]  Epoch  100 | Train=0.154903 | Val=0.152871
# [MSE]  Epoch  101 | Train=0.152909 | Val=0.150871
# [MSE]  Epoch  102 | Train=0.150911 | Val=0.148867
# [MSE]  Epoch  103 | Train=0.148908 | Val=0.146859
# [MSE]  Epoch  104 | Train=0.146900 | Val=0.144849
# [MSE]  Epoch  105 | Train=0.144889 | Val=0.142836
# [MSE]  Epoch  106 | Train=0.142874 | Val=0.140819
# [MSE]  Epoch  107 | Train=0.140855 | Val=0.138801
# [MSE]  Epoch  108 | Train=0.138833 | Val=0.136779
# [MSE]  Epoch  109 | Train=0.136809 | Val=0.134754
# [MSE]  Epoch  110 | Train=0.134781 | Val=0.132727
# [MSE]  Epoch  111 | Train=0.132750 | Val=0.130697
# [MSE]  Epoch  112 | Train=0.130717 | Val=0.128665
# [MSE]  Epoch  113 | Train=0.128682 | Val=0.126631
# [MSE]  Epoch  114 | Train=0.126645 | Val=0.124597
# [MSE]  Epoch  115 | Train=0.124608 | Val=0.122564
# [MSE]  Epoch  116 | Train=0.122572 | Val=0.120531
# [MSE]  Epoch  117 | Train=0.120536 | Val=0.118500
# [MSE]  Epoch  118 | Train=0.118501 | Val=0.116472
# [MSE]  Epoch  119 | Train=0.116469 | Val=0.114446
# [MSE]  Epoch  120 | Train=0.114439 | Val=0.112424
# [MSE]  Epoch  121 | Train=0.112413 | Val=0.110406
# [MSE]  Epoch  122 | Train=0.110390 | Val=0.108392
# [MSE]  Epoch  123 | Train=0.108372 | Val=0.106383
# [MSE]  Epoch  124 | Train=0.106359 | Val=0.104380
# [MSE]  Epoch  125 | Train=0.104352 | Val=0.102383
# [MSE]  Epoch  126 | Train=0.102350 | Val=0.100392
# [MSE]  Epoch  127 | Train=0.100356 | Val=0.098409
# [MSE]  Epoch  128 | Train=0.098370 | Val=0.096434
# [MSE]  Epoch  129 | Train=0.096392 | Val=0.094467
# [MSE]  Epoch  130 | Train=0.094422 | Val=0.092510
# [MSE]  Epoch  131 | Train=0.092463 | Val=0.090564
# [MSE]  Epoch  132 | Train=0.090515 | Val=0.088629
# [MSE]  Epoch  133 | Train=0.088578 | Val=0.086706
# [MSE]  Epoch  134 | Train=0.086653 | Val=0.084796
# [MSE]  Epoch  135 | Train=0.084741 | Val=0.082900
# [MSE]  Epoch  136 | Train=0.082843 | Val=0.081019
# [MSE]  Epoch  137 | Train=0.080960 | Val=0.079154
# [MSE]  Epoch  138 | Train=0.079091 | Val=0.077304
# [MSE]  Epoch  139 | Train=0.077239 | Val=0.075472
# [MSE]  Epoch  140 | Train=0.075404 | Val=0.073657
# [MSE]  Epoch  141 | Train=0.073586 | Val=0.071861
# [MSE]  Epoch  142 | Train=0.071787 | Val=0.070084
# [MSE]  Epoch  143 | Train=0.070007 | Val=0.068327
# [MSE]  Epoch  144 | Train=0.068247 | Val=0.066590
# [MSE]  Epoch  145 | Train=0.066507 | Val=0.064875
# [MSE]  Epoch  146 | Train=0.064789 | Val=0.063182
# [MSE]  Epoch  147 | Train=0.063093 | Val=0.061512
# [MSE]  Epoch  148 | Train=0.061421 | Val=0.059866
# [MSE]  Epoch  149 | Train=0.059771 | Val=0.058243
# [MSE]  Epoch  150 | Train=0.058146 | Val=0.056646
# [MSE]  Epoch  151 | Train=0.056547 | Val=0.055075
# [MSE]  Epoch  152 | Train=0.054973 | Val=0.053530
# [MSE]  Epoch  153 | Train=0.053425 | Val=0.052012
# [MSE]  Epoch  154 | Train=0.051905 | Val=0.050521
# [MSE]  Epoch  155 | Train=0.050412 | Val=0.049059
# [MSE]  Epoch  156 | Train=0.048947 | Val=0.047625
# [MSE]  Epoch  157 | Train=0.047511 | Val=0.046220
# [MSE]  Epoch  158 | Train=0.046104 | Val=0.044845
# [MSE]  Epoch  159 | Train=0.044727 | Val=0.043500
# [MSE]  Epoch  160 | Train=0.043380 | Val=0.042186
# [MSE]  Epoch  161 | Train=0.042064 | Val=0.040902
# [MSE]  Epoch  162 | Train=0.040778 | Val=0.039649
# [MSE]  Epoch  163 | Train=0.039524 | Val=0.038428
# [MSE]  Epoch  164 | Train=0.038301 | Val=0.037238
# [MSE]  Epoch  165 | Train=0.037110 | Val=0.036080
# [MSE]  Epoch  166 | Train=0.035951 | Val=0.034955
# [MSE]  Epoch  167 | Train=0.034824 | Val=0.033861
# [MSE]  Epoch  168 | Train=0.033729 | Val=0.032800
# [MSE]  Epoch  169 | Train=0.032666 | Val=0.031770
# [MSE]  Epoch  170 | Train=0.031636 | Val=0.030773
# [MSE]  Epoch  171 | Train=0.030637 | Val=0.029808
# [MSE]  Epoch  172 | Train=0.029671 | Val=0.028874
# [MSE]  Epoch  173 | Train=0.028736 | Val=0.027972
# [MSE]  Epoch  174 | Train=0.027833 | Val=0.027102
# [MSE]  Epoch  175 | Train=0.026962 | Val=0.026262
# [MSE]  Epoch  176 | Train=0.026122 | Val=0.025454
# [MSE]  Epoch  177 | Train=0.025312 | Val=0.024675
# [MSE]  Epoch  178 | Train=0.024533 | Val=0.023927
# [MSE]  Epoch  179 | Train=0.023784 | Val=0.023208
# [MSE]  Epoch  180 | Train=0.023065 | Val=0.022519
# [MSE]  Epoch  181 | Train=0.022376 | Val=0.021859
# [MSE]  Epoch  182 | Train=0.021715 | Val=0.021226
# [MSE]  Epoch  183 | Train=0.021083 | Val=0.020622
# [MSE]  Epoch  184 | Train=0.020478 | Val=0.020044
# [MSE]  Epoch  185 | Train=0.019900 | Val=0.019492
# [MSE]  Epoch  186 | Train=0.019348 | Val=0.018966
# [MSE]  Epoch  187 | Train=0.018822 | Val=0.018465
# [MSE]  Epoch  188 | Train=0.018321 | Val=0.017988
# [MSE]  Epoch  189 | Train=0.017844 | Val=0.017534
# [MSE]  Epoch  190 | Train=0.017390 | Val=0.017102
# [MSE]  Epoch  191 | Train=0.016959 | Val=0.016692
# [MSE]  Epoch  192 | Train=0.016549 | Val=0.016303
# [MSE]  Epoch  193 | Train=0.016160 | Val=0.015933
# [MSE]  Epoch  194 | Train=0.015791 | Val=0.015583
# [MSE]  Epoch  195 | Train=0.015441 | Val=0.015251
# [MSE]  Epoch  196 | Train=0.015109 | Val=0.014936
# [MSE]  Epoch  197 | Train=0.014795 | Val=0.014637
# [MSE]  Epoch  198 | Train=0.014497 | Val=0.014354
# [MSE]  Epoch  199 | Train=0.014215 | Val=0.014086
# [MSE]  Epoch  200 | Train=0.013947 | Val=0.013833
# [MSE]  Epoch  201 | Train=0.013694 | Val=0.013592
# [MSE]  Epoch  202 | Train=0.013454 | Val=0.013364
# [MSE]  Epoch  203 | Train=0.013227 | Val=0.013148
# [MSE]  Epoch  204 | Train=0.013011 | Val=0.012943
# [MSE]  Epoch  205 | Train=0.012807 | Val=0.012748
# [MSE]  Epoch  206 | Train=0.012613 | Val=0.012563
# [MSE]  Epoch  207 | Train=0.012429 | Val=0.012387
# [MSE]  Epoch  208 | Train=0.012254 | Val=0.012220
# [MSE]  Epoch  209 | Train=0.012087 | Val=0.012061
# [MSE]  Epoch  210 | Train=0.011928 | Val=0.011909
# [MSE]  Epoch  211 | Train=0.011777 | Val=0.011763
# [MSE]  Epoch  212 | Train=0.011632 | Val=0.011624
# [MSE]  Epoch  213 | Train=0.011494 | Val=0.011491
# [MSE]  Epoch  214 | Train=0.011362 | Val=0.011364
# [MSE]  Epoch  215 | Train=0.011235 | Val=0.011241
# [MSE]  Epoch  216 | Train=0.011113 | Val=0.011123
# [MSE]  Epoch  217 | Train=0.010995 | Val=0.011009
# [MSE]  Epoch  218 | Train=0.010882 | Val=0.010898
# [MSE]  Epoch  219 | Train=0.010772 | Val=0.010792
# [MSE]  Epoch  220 | Train=0.010666 | Val=0.010688
# [MSE]  Epoch  221 | Train=0.010564 | Val=0.010588
# [MSE]  Epoch  222 | Train=0.010464 | Val=0.010490
# [MSE]  Epoch  223 | Train=0.010367 | Val=0.010395
# [MSE]  Epoch  224 | Train=0.010272 | Val=0.010302
# [MSE]  Epoch  225 | Train=0.010180 | Val=0.010211
# [MSE]  Epoch  226 | Train=0.010090 | Val=0.010123
# [MSE]  Epoch  227 | Train=0.010001 | Val=0.010035
# [MSE]  Epoch  228 | Train=0.009915 | Val=0.009950
# [MSE]  Epoch  229 | Train=0.009830 | Val=0.009866
# [MSE]  Epoch  230 | Train=0.009746 | Val=0.009783
# [MSE]  Epoch  231 | Train=0.009664 | Val=0.009702
# [MSE]  Epoch  232 | Train=0.009583 | Val=0.009621
# [MSE]  Epoch  233 | Train=0.009503 | Val=0.009542
# [MSE]  Epoch  234 | Train=0.009425 | Val=0.009464
# [MSE]  Epoch  235 | Train=0.009347 | Val=0.009387
# [MSE]  Epoch  236 | Train=0.009270 | Val=0.009311
# [MSE]  Epoch  237 | Train=0.009195 | Val=0.009236
# [MSE]  Epoch  238 | Train=0.009120 | Val=0.009161
# [MSE]  Epoch  239 | Train=0.009046 | Val=0.009088
# [MSE]  Epoch  240 | Train=0.008973 | Val=0.009015
# [MSE]  Epoch  241 | Train=0.008900 | Val=0.008943
# [MSE]  Epoch  242 | Train=0.008828 | Val=0.008871
# [MSE]  Epoch  243 | Train=0.008757 | Val=0.008800
# [MSE]  Epoch  244 | Train=0.008687 | Val=0.008730
# [MSE]  Epoch  245 | Train=0.008617 | Val=0.008661
# [MSE]  Epoch  246 | Train=0.008549 | Val=0.008592
# [MSE]  Epoch  247 | Train=0.008480 | Val=0.008524
# [MSE]  Epoch  248 | Train=0.008413 | Val=0.008457
# [MSE]  Epoch  249 | Train=0.008346 | Val=0.008390
# [MSE]  Epoch  250 | Train=0.008279 | Val=0.008324
# [MSE]  Epoch  251 | Train=0.008214 | Val=0.008259
# [MSE]  Epoch  252 | Train=0.008149 | Val=0.008194
# [MSE]  Epoch  253 | Train=0.008084 | Val=0.008130
# [MSE]  Epoch  254 | Train=0.008021 | Val=0.008067
# [MSE]  Epoch  255 | Train=0.007957 | Val=0.008004
# [MSE]  Epoch  256 | Train=0.007895 | Val=0.007941
# [MSE]  Epoch  257 | Train=0.007833 | Val=0.007880
# [MSE]  Epoch  258 | Train=0.007771 | Val=0.007818
# [MSE]  Epoch  259 | Train=0.007711 | Val=0.007758
# [MSE]  Epoch  260 | Train=0.007650 | Val=0.007698
# [MSE]  Epoch  261 | Train=0.007591 | Val=0.007638
# [MSE]  Epoch  262 | Train=0.007532 | Val=0.007579
# [MSE]  Epoch  263 | Train=0.007473 | Val=0.007521
# [MSE]  Epoch  264 | Train=0.007415 | Val=0.007463
# [MSE]  Epoch  265 | Train=0.007358 | Val=0.007406
# [MSE]  Epoch  266 | Train=0.007301 | Val=0.007349
# [MSE]  Epoch  267 | Train=0.007244 | Val=0.007293
# [MSE]  Epoch  268 | Train=0.007188 | Val=0.007237
# [MSE]  Epoch  269 | Train=0.007133 | Val=0.007182
# [MSE]  Epoch  270 | Train=0.007078 | Val=0.007127
# [MSE]  Epoch  271 | Train=0.007023 | Val=0.007072
# [MSE]  Epoch  272 | Train=0.006970 | Val=0.007019
# [MSE]  Epoch  273 | Train=0.006916 | Val=0.006965
# [MSE]  Epoch  274 | Train=0.006863 | Val=0.006912
# [MSE]  Epoch  275 | Train=0.006811 | Val=0.006860
# [MSE]  Epoch  276 | Train=0.006759 | Val=0.006808
# [MSE]  Epoch  277 | Train=0.006707 | Val=0.006757
# [MSE]  Epoch  278 | Train=0.006656 | Val=0.006706
# [MSE]  Epoch  279 | Train=0.006606 | Val=0.006655
# [MSE]  Epoch  280 | Train=0.006555 | Val=0.006605
# [MSE]  Epoch  281 | Train=0.006506 | Val=0.006555
# [MSE]  Epoch  282 | Train=0.006456 | Val=0.006506
# [MSE]  Epoch  283 | Train=0.006408 | Val=0.006458
# [MSE]  Epoch  284 | Train=0.006359 | Val=0.006409
# [MSE]  Epoch  285 | Train=0.006311 | Val=0.006361
# [MSE]  Epoch  286 | Train=0.006264 | Val=0.006314
# [MSE]  Epoch  287 | Train=0.006217 | Val=0.006267
# [MSE]  Epoch  288 | Train=0.006170 | Val=0.006220
# [MSE]  Epoch  289 | Train=0.006124 | Val=0.006174
# [MSE]  Epoch  290 | Train=0.006078 | Val=0.006128
# [MSE]  Epoch  291 | Train=0.006033 | Val=0.006083
# [MSE]  Epoch  292 | Train=0.005988 | Val=0.006038
# [MSE]  Epoch  293 | Train=0.005943 | Val=0.005993
# [MSE]  Epoch  294 | Train=0.005899 | Val=0.005949
# [MSE]  Epoch  295 | Train=0.005855 | Val=0.005905
# [MSE]  Epoch  296 | Train=0.005812 | Val=0.005862
# [MSE]  Epoch  297 | Train=0.005769 | Val=0.005819
# [MSE]  Epoch  298 | Train=0.005726 | Val=0.005777
# [MSE]  Epoch  299 | Train=0.005684 | Val=0.005734
# [MSE]  Epoch  300 | Train=0.005642 | Val=0.005693
# [MSE]  Epoch  301 | Train=0.005601 | Val=0.005651
# [MSE]  Epoch  302 | Train=0.005560 | Val=0.005610
# [MSE]  Epoch  303 | Train=0.005519 | Val=0.005569
# [MSE]  Epoch  304 | Train=0.005479 | Val=0.005529
# [MSE]  Epoch  305 | Train=0.005439 | Val=0.005489
# [MSE]  Epoch  306 | Train=0.005400 | Val=0.005450
# [MSE]  Epoch  307 | Train=0.005360 | Val=0.005410
# [MSE]  Epoch  308 | Train=0.005322 | Val=0.005372
# [MSE]  Epoch  309 | Train=0.005283 | Val=0.005333
# [MSE]  Epoch  310 | Train=0.005245 | Val=0.005295
# [MSE]  Epoch  311 | Train=0.005207 | Val=0.005257
# [MSE]  Epoch  312 | Train=0.005170 | Val=0.005220
# [MSE]  Epoch  313 | Train=0.005133 | Val=0.005183
# [MSE]  Epoch  314 | Train=0.005096 | Val=0.005146
# [MSE]  Epoch  315 | Train=0.005060 | Val=0.005110
# [MSE]  Epoch  316 | Train=0.005024 | Val=0.005073
# [MSE]  Epoch  317 | Train=0.004988 | Val=0.005038
# [MSE]  Epoch  318 | Train=0.004953 | Val=0.005002
# [MSE]  Epoch  319 | Train=0.004918 | Val=0.004967
# [MSE]  Epoch  320 | Train=0.004883 | Val=0.004933
# [MSE]  Epoch  321 | Train=0.004849 | Val=0.004898
# [MSE]  Epoch  322 | Train=0.004815 | Val=0.004864
# [MSE]  Epoch  323 | Train=0.004781 | Val=0.004830
# [MSE]  Epoch  324 | Train=0.004748 | Val=0.004797
# [MSE]  Epoch  325 | Train=0.004715 | Val=0.004764
# [MSE]  Epoch  326 | Train=0.004682 | Val=0.004731
# [MSE]  Epoch  327 | Train=0.004650 | Val=0.004699
# [MSE]  Epoch  328 | Train=0.004618 | Val=0.004667
# [MSE]  Epoch  329 | Train=0.004586 | Val=0.004635
# [MSE]  Epoch  330 | Train=0.004555 | Val=0.004603
# [MSE]  Epoch  331 | Train=0.004523 | Val=0.004572
# [MSE]  Epoch  332 | Train=0.004492 | Val=0.004541
# [MSE]  Epoch  333 | Train=0.004462 | Val=0.004510
# [MSE]  Epoch  334 | Train=0.004432 | Val=0.004480
# [MSE]  Epoch  335 | Train=0.004402 | Val=0.004450
# [MSE]  Epoch  336 | Train=0.004372 | Val=0.004420
# [MSE]  Epoch  337 | Train=0.004343 | Val=0.004391
# [MSE]  Epoch  338 | Train=0.004314 | Val=0.004362
# [MSE]  Epoch  339 | Train=0.004285 | Val=0.004333
# [MSE]  Epoch  340 | Train=0.004256 | Val=0.004304
# [MSE]  Epoch  341 | Train=0.004228 | Val=0.004276
# [MSE]  Epoch  342 | Train=0.004200 | Val=0.004248
# [MSE]  Epoch  343 | Train=0.004172 | Val=0.004220
# [MSE]  Epoch  344 | Train=0.004145 | Val=0.004192
# [MSE]  Epoch  345 | Train=0.004118 | Val=0.004165
# [MSE]  Epoch  346 | Train=0.004091 | Val=0.004138
# [MSE]  Epoch  347 | Train=0.004064 | Val=0.004111
# [MSE]  Epoch  348 | Train=0.004038 | Val=0.004085
# [MSE]  Epoch  349 | Train=0.004012 | Val=0.004059
# [MSE]  Epoch  350 | Train=0.003986 | Val=0.004033
# [MSE]  Epoch  351 | Train=0.003961 | Val=0.004007
# [MSE]  Epoch  352 | Train=0.003935 | Val=0.003982
# [MSE]  Epoch  353 | Train=0.003910 | Val=0.003957
# [MSE]  Epoch  354 | Train=0.003885 | Val=0.003932
# [MSE]  Epoch  355 | Train=0.003861 | Val=0.003907
# [MSE]  Epoch  356 | Train=0.003837 | Val=0.003883
# [MSE]  Epoch  357 | Train=0.003813 | Val=0.003859
# [MSE]  Epoch  358 | Train=0.003789 | Val=0.003835
# [MSE]  Epoch  359 | Train=0.003765 | Val=0.003811
# [MSE]  Epoch  360 | Train=0.003742 | Val=0.003788
# [MSE]  Epoch  361 | Train=0.003719 | Val=0.003764
# [MSE]  Epoch  362 | Train=0.003696 | Val=0.003742
# [MSE]  Epoch  363 | Train=0.003673 | Val=0.003719
# [MSE]  Epoch  364 | Train=0.003651 | Val=0.003696
# [MSE]  Epoch  365 | Train=0.003629 | Val=0.003674
# [MSE]  Epoch  366 | Train=0.003607 | Val=0.003652
# [MSE]  Epoch  367 | Train=0.003585 | Val=0.003630
# [MSE]  Epoch  368 | Train=0.003564 | Val=0.003609
# [MSE]  Epoch  369 | Train=0.003543 | Val=0.003587
# [MSE]  Epoch  370 | Train=0.003521 | Val=0.003566
# [MSE]  Epoch  371 | Train=0.003501 | Val=0.003545
# [MSE]  Epoch  372 | Train=0.003480 | Val=0.003524
# [MSE]  Epoch  373 | Train=0.003460 | Val=0.003504
# [MSE]  Epoch  374 | Train=0.003439 | Val=0.003484
# [MSE]  Epoch  375 | Train=0.003420 | Val=0.003464
# [MSE]  Epoch  376 | Train=0.003400 | Val=0.003444
# [MSE]  Epoch  377 | Train=0.003380 | Val=0.003424
# [MSE]  Epoch  378 | Train=0.003361 | Val=0.003404
# [MSE]  Epoch  379 | Train=0.003342 | Val=0.003385
# [MSE]  Epoch  380 | Train=0.003323 | Val=0.003366
# [MSE]  Epoch  381 | Train=0.003304 | Val=0.003347
# [MSE]  Epoch  382 | Train=0.003285 | Val=0.003329
# [MSE]  Epoch  383 | Train=0.003267 | Val=0.003310
# [MSE]  Epoch  384 | Train=0.003249 | Val=0.003292
# [MSE]  Epoch  385 | Train=0.003231 | Val=0.003274
# [MSE]  Epoch  386 | Train=0.003213 | Val=0.003256
# [MSE]  Epoch  387 | Train=0.003196 | Val=0.003238
# [MSE]  Epoch  388 | Train=0.003178 | Val=0.003220
# [MSE]  Epoch  389 | Train=0.003161 | Val=0.003203
# [MSE]  Epoch  390 | Train=0.003144 | Val=0.003186
# [MSE]  Epoch  391 | Train=0.003127 | Val=0.003169
# [MSE]  Epoch  392 | Train=0.003110 | Val=0.003152
# [MSE]  Epoch  393 | Train=0.003094 | Val=0.003135
# [MSE]  Epoch  394 | Train=0.003077 | Val=0.003119
# [MSE]  Epoch  395 | Train=0.003061 | Val=0.003103
# [MSE]  Epoch  396 | Train=0.003045 | Val=0.003086
# [MSE]  Epoch  397 | Train=0.003029 | Val=0.003070
# [MSE]  Epoch  398 | Train=0.003014 | Val=0.003055
# [MSE]  Epoch  399 | Train=0.002998 | Val=0.003039
# [MSE]  Epoch  400 | Train=0.002983 | Val=0.003024
# [MSE]  Epoch  401 | Train=0.002968 | Val=0.003008
# [MSE]  Epoch  402 | Train=0.002953 | Val=0.002993
# [MSE]  Epoch  403 | Train=0.002938 | Val=0.002978
# [MSE]  Epoch  404 | Train=0.002923 | Val=0.002963
# [MSE]  Epoch  405 | Train=0.002908 | Val=0.002949
# [MSE]  Epoch  406 | Train=0.002894 | Val=0.002934
# [MSE]  Epoch  407 | Train=0.002880 | Val=0.002920
# [MSE]  Epoch  408 | Train=0.002866 | Val=0.002905
# [MSE]  Epoch  409 | Train=0.002852 | Val=0.002891
# [MSE]  Epoch  410 | Train=0.002838 | Val=0.002877
# [MSE]  Epoch  411 | Train=0.002824 | Val=0.002864
# [MSE]  Epoch  412 | Train=0.002811 | Val=0.002850
# [MSE]  Epoch  413 | Train=0.002797 | Val=0.002836
# [MSE]  Epoch  414 | Train=0.002784 | Val=0.002823
# [MSE]  Epoch  415 | Train=0.002771 | Val=0.002810
# [MSE]  Epoch  416 | Train=0.002758 | Val=0.002797
# [MSE]  Epoch  417 | Train=0.002745 | Val=0.002784
# [MSE]  Epoch  418 | Train=0.002733 | Val=0.002771
# [MSE]  Epoch  419 | Train=0.002720 | Val=0.002758
# [MSE]  Epoch  420 | Train=0.002708 | Val=0.002746
# [MSE]  Epoch  421 | Train=0.002696 | Val=0.002733
# [MSE]  Epoch  422 | Train=0.002683 | Val=0.002721
# [MSE]  Epoch  423 | Train=0.002671 | Val=0.002709
# [MSE]  Epoch  424 | Train=0.002659 | Val=0.002697
# [MSE]  Epoch  425 | Train=0.002648 | Val=0.002685
# [MSE]  Epoch  426 | Train=0.002636 | Val=0.002673
# [MSE]  Epoch  427 | Train=0.002625 | Val=0.002662
# [MSE]  Epoch  428 | Train=0.002613 | Val=0.002650
# [MSE]  Epoch  429 | Train=0.002602 | Val=0.002639
# [MSE]  Epoch  430 | Train=0.002591 | Val=0.002627
# [MSE]  Epoch  431 | Train=0.002580 | Val=0.002616
# [MSE]  Epoch  432 | Train=0.002569 | Val=0.002605
# [MSE]  Epoch  433 | Train=0.002558 | Val=0.002594
# [MSE]  Epoch  434 | Train=0.002547 | Val=0.002583
# [MSE]  Epoch  435 | Train=0.002537 | Val=0.002573
# [MSE]  Epoch  436 | Train=0.002526 | Val=0.002562
# [MSE]  Epoch  437 | Train=0.002516 | Val=0.002551
# [MSE]  Epoch  438 | Train=0.002506 | Val=0.002541
# [MSE]  Epoch  439 | Train=0.002495 | Val=0.002531
# [MSE]  Epoch  440 | Train=0.002485 | Val=0.002521
# [MSE]  Epoch  441 | Train=0.002475 | Val=0.002510
# [MSE]  Epoch  442 | Train=0.002466 | Val=0.002501
# [MSE]  Epoch  443 | Train=0.002456 | Val=0.002491
# [MSE]  Epoch  444 | Train=0.002446 | Val=0.002481
# [MSE]  Epoch  445 | Train=0.002437 | Val=0.002471
# [MSE]  Epoch  446 | Train=0.002427 | Val=0.002462
# [MSE]  Epoch  447 | Train=0.002418 | Val=0.002452
# [MSE]  Epoch  448 | Train=0.002409 | Val=0.002443
# [MSE]  Epoch  449 | Train=0.002400 | Val=0.002433
# [MSE]  Epoch  450 | Train=0.002390 | Val=0.002424
# [MSE]  Epoch  451 | Train=0.002381 | Val=0.002415
# [MSE]  Epoch  452 | Train=0.002373 | Val=0.002406
# [MSE]  Epoch  453 | Train=0.002364 | Val=0.002397
# [MSE]  Epoch  454 | Train=0.002355 | Val=0.002388
# [MSE]  Epoch  455 | Train=0.002347 | Val=0.002380
# [MSE]  Epoch  456 | Train=0.002338 | Val=0.002371
# [MSE]  Epoch  457 | Train=0.002330 | Val=0.002363
# [MSE]  Epoch  458 | Train=0.002321 | Val=0.002354
# [MSE]  Epoch  459 | Train=0.002313 | Val=0.002346
# [MSE]  Epoch  460 | Train=0.002305 | Val=0.002337
# [MSE]  Epoch  461 | Train=0.002297 | Val=0.002329
# [MSE]  Epoch  462 | Train=0.002289 | Val=0.002321
# [MSE]  Epoch  463 | Train=0.002281 | Val=0.002313
# [MSE]  Epoch  464 | Train=0.002273 | Val=0.002305
# [MSE]  Epoch  465 | Train=0.002265 | Val=0.002297
# [MSE]  Epoch  466 | Train=0.002258 | Val=0.002289
# [MSE]  Epoch  467 | Train=0.002250 | Val=0.002281
# [MSE]  Epoch  468 | Train=0.002242 | Val=0.002274
# [MSE]  Epoch  469 | Train=0.002235 | Val=0.002266
# [MSE]  Epoch  470 | Train=0.002227 | Val=0.002259
# [MSE]  Epoch  471 | Train=0.002220 | Val=0.002251
# [MSE]  Epoch  472 | Train=0.002213 | Val=0.002244
# [MSE]  Epoch  473 | Train=0.002206 | Val=0.002237
# [MSE]  Epoch  474 | Train=0.002199 | Val=0.002229
# [MSE]  Epoch  475 | Train=0.002192 | Val=0.002222
# [MSE]  Epoch  476 | Train=0.002185 | Val=0.002215
# [MSE]  Epoch  477 | Train=0.002178 | Val=0.002208
# [MSE]  Epoch  478 | Train=0.002171 | Val=0.002201
# [MSE]  Epoch  479 | Train=0.002164 | Val=0.002194
# [MSE]  Epoch  480 | Train=0.002157 | Val=0.002187
# [MSE]  Epoch  481 | Train=0.002151 | Val=0.002181
# [MSE]  Epoch  482 | Train=0.002144 | Val=0.002174
# [MSE]  Epoch  483 | Train=0.002138 | Val=0.002167
# [MSE]  Epoch  484 | Train=0.002131 | Val=0.002161
# [MSE]  Epoch  485 | Train=0.002125 | Val=0.002154
# [MSE]  Epoch  486 | Train=0.002119 | Val=0.002148
# [MSE]  Epoch  487 | Train=0.002112 | Val=0.002141
# [MSE]  Epoch  488 | Train=0.002106 | Val=0.002135
# [MSE]  Epoch  489 | Train=0.002100 | Val=0.002129
# [MSE]  Epoch  490 | Train=0.002094 | Val=0.002122
# [MSE]  Epoch  491 | Train=0.002088 | Val=0.002116
# [MSE]  Epoch  492 | Train=0.002082 | Val=0.002110
# [MSE]  Epoch  493 | Train=0.002076 | Val=0.002104
# [MSE]  Epoch  494 | Train=0.002070 | Val=0.002098
# [MSE]  Epoch  495 | Train=0.002064 | Val=0.002092
# [MSE]  Epoch  496 | Train=0.002058 | Val=0.002086
# [MSE]  Epoch  497 | Train=0.002053 | Val=0.002081
# [MSE]  Epoch  498 | Train=0.002047 | Val=0.002075
# [MSE]  Epoch  499 | Train=0.002042 | Val=0.002069
# [MSE]  Epoch  500 | Train=0.002036 | Val=0.002063
# [MSE]  Epoch  501 | Train=0.002030 | Val=0.002058
# [MSE]  Epoch  502 | Train=0.002025 | Val=0.002052
# [MSE]  Epoch  503 | Train=0.002020 | Val=0.002047
# [MSE]  Epoch  504 | Train=0.002014 | Val=0.002041
# [MSE]  Epoch  505 | Train=0.002009 | Val=0.002036
# [MSE]  Epoch  506 | Train=0.002004 | Val=0.002030
# [MSE]  Epoch  507 | Train=0.001998 | Val=0.002025
# [MSE]  Epoch  508 | Train=0.001993 | Val=0.002020
# [MSE]  Epoch  509 | Train=0.001988 | Val=0.002015
# [MSE]  Epoch  510 | Train=0.001983 | Val=0.002009
# [MSE]  Epoch  511 | Train=0.001978 | Val=0.002004
# [MSE]  Epoch  512 | Train=0.001973 | Val=0.001999
# [MSE]  Epoch  513 | Train=0.001968 | Val=0.001994
# [MSE]  Epoch  514 | Train=0.001963 | Val=0.001989
# [MSE]  Epoch  515 | Train=0.001958 | Val=0.001984
# [MSE]  Epoch  516 | Train=0.001954 | Val=0.001979
# [MSE]  Epoch  517 | Train=0.001949 | Val=0.001974
# [MSE]  Epoch  518 | Train=0.001944 | Val=0.001969
# [MSE]  Epoch  519 | Train=0.001939 | Val=0.001965
# [MSE]  Epoch  520 | Train=0.001935 | Val=0.001960
# [MSE]  Epoch  521 | Train=0.001930 | Val=0.001955
# [MSE]  Epoch  522 | Train=0.001925 | Val=0.001950
# [MSE]  Epoch  523 | Train=0.001921 | Val=0.001946
# [MSE]  Epoch  524 | Train=0.001916 | Val=0.001941
# [MSE]  Epoch  525 | Train=0.001912 | Val=0.001936
# [MSE]  Epoch  526 | Train=0.001907 | Val=0.001932
# [MSE]  Epoch  527 | Train=0.001903 | Val=0.001927
# [MSE]  Epoch  528 | Train=0.001899 | Val=0.001923
# [MSE]  Epoch  529 | Train=0.001894 | Val=0.001918
# [MSE]  Epoch  530 | Train=0.001890 | Val=0.001914
# [MSE]  Epoch  531 | Train=0.001886 | Val=0.001910
# [MSE]  Epoch  532 | Train=0.001882 | Val=0.001905
# [MSE]  Epoch  533 | Train=0.001877 | Val=0.001901
# [MSE]  Epoch  534 | Train=0.001873 | Val=0.001897
# [MSE]  Epoch  535 | Train=0.001869 | Val=0.001893
# [MSE]  Epoch  536 | Train=0.001865 | Val=0.001888
# [MSE]  Epoch  537 | Train=0.001861 | Val=0.001884
# [MSE]  Epoch  538 | Train=0.001857 | Val=0.001880
# [MSE]  Epoch  539 | Train=0.001853 | Val=0.001876
# [MSE]  Epoch  540 | Train=0.001849 | Val=0.001872
# [MSE]  Epoch  541 | Train=0.001845 | Val=0.001868
# [MSE]  Epoch  542 | Train=0.001841 | Val=0.001864
# [MSE]  Epoch  543 | Train=0.001837 | Val=0.001860
# [MSE]  Epoch  544 | Train=0.001833 | Val=0.001856
# [MSE]  Epoch  545 | Train=0.001829 | Val=0.001852
# [MSE]  Epoch  546 | Train=0.001826 | Val=0.001848
# [MSE]  Epoch  547 | Train=0.001822 | Val=0.001844
# [MSE]  Epoch  548 | Train=0.001818 | Val=0.001840
# [MSE]  Epoch  549 | Train=0.001814 | Val=0.001836
# [MSE]  Epoch  550 | Train=0.001811 | Val=0.001833
# [MSE]  Epoch  551 | Train=0.001807 | Val=0.001829
# [MSE]  Epoch  552 | Train=0.001803 | Val=0.001825
# [MSE]  Epoch  553 | Train=0.001800 | Val=0.001821
# [MSE]  Epoch  554 | Train=0.001796 | Val=0.001818
# [MSE]  Epoch  555 | Train=0.001793 | Val=0.001814
# [MSE]  Epoch  556 | Train=0.001789 | Val=0.001810
# [MSE]  Epoch  557 | Train=0.001785 | Val=0.001807
# [MSE]  Epoch  558 | Train=0.001782 | Val=0.001803
# [MSE]  Epoch  559 | Train=0.001779 | Val=0.001800
# [MSE]  Epoch  560 | Train=0.001775 | Val=0.001796
# [MSE]  Epoch  561 | Train=0.001772 | Val=0.001793
# [MSE]  Epoch  562 | Train=0.001768 | Val=0.001789
# [MSE]  Epoch  563 | Train=0.001765 | Val=0.001786
# [MSE]  Epoch  564 | Train=0.001762 | Val=0.001782
# [MSE]  Epoch  565 | Train=0.001758 | Val=0.001779
# [MSE]  Epoch  566 | Train=0.001755 | Val=0.001775
# [MSE]  Epoch  567 | Train=0.001752 | Val=0.001772
# [MSE]  Epoch  568 | Train=0.001748 | Val=0.001769
# [MSE]  Epoch  569 | Train=0.001745 | Val=0.001765
# [MSE]  Epoch  570 | Train=0.001742 | Val=0.001762
# [MSE]  Epoch  571 | Train=0.001739 | Val=0.001759
# [MSE]  Epoch  572 | Train=0.001735 | Val=0.001755
# [MSE]  Epoch  573 | Train=0.001732 | Val=0.001752
# [MSE]  Epoch  574 | Train=0.001729 | Val=0.001749
# [MSE]  Epoch  575 | Train=0.001726 | Val=0.001746
# [MSE]  Epoch  576 | Train=0.001723 | Val=0.001743
# [MSE]  Epoch  577 | Train=0.001720 | Val=0.001739
# [MSE]  Epoch  578 | Train=0.001717 | Val=0.001736
# [MSE]  Epoch  579 | Train=0.001714 | Val=0.001733
# [MSE]  Epoch  580 | Train=0.001711 | Val=0.001730
# [MSE]  Epoch  581 | Train=0.001708 | Val=0.001727
# [MSE]  Epoch  582 | Train=0.001705 | Val=0.001724
# [MSE]  Epoch  583 | Train=0.001702 | Val=0.001721
# [MSE]  Epoch  584 | Train=0.001699 | Val=0.001718
# [MSE]  Epoch  585 | Train=0.001696 | Val=0.001715
# [MSE]  Epoch  586 | Train=0.001693 | Val=0.001712
# [MSE]  Epoch  587 | Train=0.001690 | Val=0.001709
# [MSE]  Epoch  588 | Train=0.001687 | Val=0.001706
# [MSE]  Epoch  589 | Train=0.001684 | Val=0.001703
# [MSE]  Epoch  590 | Train=0.001681 | Val=0.001700
# [MSE]  Epoch  591 | Train=0.001678 | Val=0.001697
# [MSE]  Epoch  592 | Train=0.001675 | Val=0.001694
# [MSE]  Epoch  593 | Train=0.001673 | Val=0.001691
# [MSE]  Epoch  594 | Train=0.001670 | Val=0.001688
# [MSE]  Epoch  595 | Train=0.001667 | Val=0.001685
# [MSE]  Epoch  596 | Train=0.001664 | Val=0.001682
# [MSE]  Epoch  597 | Train=0.001661 | Val=0.001680
# [MSE]  Epoch  598 | Train=0.001659 | Val=0.001677
# [MSE]  Epoch  599 | Train=0.001656 | Val=0.001674
# [MSE]  Epoch  600 | Train=0.001653 | Val=0.001671
# [MSE]  Epoch  601 | Train=0.001651 | Val=0.001668
# [MSE]  Epoch  602 | Train=0.001648 | Val=0.001666
# [MSE]  Epoch  603 | Train=0.001645 | Val=0.001663
# [MSE]  Epoch  604 | Train=0.001643 | Val=0.001660
# [MSE]  Epoch  605 | Train=0.001640 | Val=0.001657
# [MSE]  Epoch  606 | Train=0.001637 | Val=0.001655
# [MSE]  Epoch  607 | Train=0.001635 | Val=0.001652
# [MSE]  Epoch  608 | Train=0.001632 | Val=0.001649
# [MSE]  Epoch  609 | Train=0.001629 | Val=0.001647
# [MSE]  Epoch  610 | Train=0.001627 | Val=0.001644
# [MSE]  Epoch  611 | Train=0.001624 | Val=0.001641
# [MSE]  Epoch  612 | Train=0.001622 | Val=0.001639
# [MSE]  Epoch  613 | Train=0.001619 | Val=0.001636
# [MSE]  Epoch  614 | Train=0.001617 | Val=0.001633
# [MSE]  Epoch  615 | Train=0.001614 | Val=0.001631
# [MSE]  Epoch  616 | Train=0.001612 | Val=0.001628
# [MSE]  Epoch  617 | Train=0.001609 | Val=0.001626
# [MSE]  Epoch  618 | Train=0.001607 | Val=0.001623
# [MSE]  Epoch  619 | Train=0.001604 | Val=0.001621
# [MSE]  Epoch  620 | Train=0.001602 | Val=0.001618
# [MSE]  Epoch  621 | Train=0.001599 | Val=0.001616
# [MSE]  Epoch  622 | Train=0.001597 | Val=0.001613
# [MSE]  Epoch  623 | Train=0.001594 | Val=0.001611
# [MSE]  Epoch  624 | Train=0.001592 | Val=0.001608
# [MSE]  Epoch  625 | Train=0.001589 | Val=0.001606
# [MSE]  Epoch  626 | Train=0.001587 | Val=0.001603
# [MSE]  Epoch  627 | Train=0.001585 | Val=0.001601
# [MSE]  Epoch  628 | Train=0.001582 | Val=0.001598
# [MSE]  Epoch  629 | Train=0.001580 | Val=0.001596
# [MSE]  Epoch  630 | Train=0.001577 | Val=0.001593
# [MSE]  Epoch  631 | Train=0.001575 | Val=0.001591
# [MSE]  Epoch  632 | Train=0.001573 | Val=0.001588
# [MSE]  Epoch  633 | Train=0.001570 | Val=0.001586
# [MSE]  Epoch  634 | Train=0.001568 | Val=0.001584
# [MSE]  Epoch  635 | Train=0.001566 | Val=0.001581
# [MSE]  Epoch  636 | Train=0.001563 | Val=0.001579
# [MSE]  Epoch  637 | Train=0.001561 | Val=0.001577
# [MSE]  Epoch  638 | Train=0.001559 | Val=0.001574
# [MSE]  Epoch  639 | Train=0.001557 | Val=0.001572
# [MSE]  Epoch  640 | Train=0.001554 | Val=0.001570
# [MSE]  Epoch  641 | Train=0.001552 | Val=0.001567
# [MSE]  Epoch  642 | Train=0.001550 | Val=0.001565
# [MSE]  Epoch  643 | Train=0.001548 | Val=0.001563
# [MSE]  Epoch  644 | Train=0.001545 | Val=0.001560
# [MSE]  Epoch  645 | Train=0.001543 | Val=0.001558
# [MSE]  Epoch  646 | Train=0.001541 | Val=0.001556
# [MSE]  Epoch  647 | Train=0.001539 | Val=0.001554
# [MSE]  Epoch  648 | Train=0.001536 | Val=0.001551
# [MSE]  Epoch  649 | Train=0.001534 | Val=0.001549
# [MSE]  Epoch  650 | Train=0.001532 | Val=0.001547
# [MSE]  Epoch  651 | Train=0.001530 | Val=0.001545
# [MSE]  Epoch  652 | Train=0.001528 | Val=0.001542
# [MSE]  Epoch  653 | Train=0.001526 | Val=0.001540
# [MSE]  Epoch  654 | Train=0.001523 | Val=0.001538
# [MSE]  Epoch  655 | Train=0.001521 | Val=0.001536
# [MSE]  Epoch  656 | Train=0.001519 | Val=0.001533
# [MSE]  Epoch  657 | Train=0.001517 | Val=0.001531
# [MSE]  Epoch  658 | Train=0.001515 | Val=0.001529
# [MSE]  Epoch  659 | Train=0.001513 | Val=0.001527
# [MSE]  Epoch  660 | Train=0.001511 | Val=0.001525
# [MSE]  Epoch  661 | Train=0.001508 | Val=0.001523
# [MSE]  Epoch  662 | Train=0.001506 | Val=0.001520
# [MSE]  Epoch  663 | Train=0.001504 | Val=0.001518
# [MSE]  Epoch  664 | Train=0.001502 | Val=0.001516
# [MSE]  Epoch  665 | Train=0.001500 | Val=0.001514
# [MSE]  Epoch  666 | Train=0.001498 | Val=0.001512
# [MSE]  Epoch  667 | Train=0.001496 | Val=0.001510
# [MSE]  Epoch  668 | Train=0.001494 | Val=0.001508
# [MSE]  Epoch  669 | Train=0.001492 | Val=0.001506
# [MSE]  Epoch  670 | Train=0.001490 | Val=0.001503
# [MSE]  Epoch  671 | Train=0.001488 | Val=0.001501
# [MSE]  Epoch  672 | Train=0.001486 | Val=0.001499
# [MSE]  Epoch  673 | Train=0.001484 | Val=0.001497
# [MSE]  Epoch  674 | Train=0.001482 | Val=0.001495
# [MSE]  Epoch  675 | Train=0.001480 | Val=0.001493
# [MSE]  Epoch  676 | Train=0.001478 | Val=0.001491
# [MSE]  Epoch  677 | Train=0.001476 | Val=0.001489
# [MSE]  Epoch  678 | Train=0.001474 | Val=0.001487
# [MSE]  Epoch  679 | Train=0.001472 | Val=0.001485
# [MSE]  Epoch  680 | Train=0.001470 | Val=0.001483
# [MSE]  Epoch  681 | Train=0.001468 | Val=0.001481
# [MSE]  Epoch  682 | Train=0.001466 | Val=0.001479
# [MSE]  Epoch  683 | Train=0.001464 | Val=0.001477
# [MSE]  Epoch  684 | Train=0.001462 | Val=0.001475
# [MSE]  Epoch  685 | Train=0.001460 | Val=0.001473
# [MSE]  Epoch  686 | Train=0.001458 | Val=0.001471
# [MSE]  Epoch  687 | Train=0.001456 | Val=0.001469
# [MSE]  Epoch  688 | Train=0.001454 | Val=0.001467
# [MSE]  Epoch  689 | Train=0.001452 | Val=0.001465
# [MSE]  Epoch  690 | Train=0.001450 | Val=0.001463
# [MSE]  Epoch  691 | Train=0.001448 | Val=0.001461
# [MSE]  Epoch  692 | Train=0.001446 | Val=0.001459
# [MSE]  Epoch  693 | Train=0.001445 | Val=0.001457
# [MSE]  Epoch  694 | Train=0.001443 | Val=0.001455
# [MSE]  Epoch  695 | Train=0.001441 | Val=0.001453
# [MSE]  Epoch  696 | Train=0.001439 | Val=0.001451
# [MSE]  Epoch  697 | Train=0.001437 | Val=0.001449
# [MSE]  Epoch  698 | Train=0.001435 | Val=0.001447
# [MSE]  Epoch  699 | Train=0.001433 | Val=0.001446
# [MSE]  Epoch  700 | Train=0.001431 | Val=0.001444
# [MSE]  Epoch  701 | Train=0.001429 | Val=0.001442
# [MSE]  Epoch  702 | Train=0.001428 | Val=0.001440
# [MSE]  Epoch  703 | Train=0.001426 | Val=0.001438
# [MSE]  Epoch  704 | Train=0.001424 | Val=0.001436
# [MSE]  Epoch  705 | Train=0.001422 | Val=0.001434
# [MSE]  Epoch  706 | Train=0.001420 | Val=0.001432
# [MSE]  Epoch  707 | Train=0.001418 | Val=0.001430
# [MSE]  Epoch  708 | Train=0.001417 | Val=0.001428
# [MSE]  Epoch  709 | Train=0.001415 | Val=0.001427
# [MSE]  Epoch  710 | Train=0.001413 | Val=0.001425
# [MSE]  Epoch  711 | Train=0.001411 | Val=0.001423
# [MSE]  Epoch  712 | Train=0.001409 | Val=0.001421
# [MSE]  Epoch  713 | Train=0.001407 | Val=0.001419
# [MSE]  Epoch  714 | Train=0.001406 | Val=0.001417
# [MSE]  Epoch  715 | Train=0.001404 | Val=0.001416
# [MSE]  Epoch  716 | Train=0.001402 | Val=0.001414
# [MSE]  Epoch  717 | Train=0.001400 | Val=0.001412
# [MSE]  Epoch  718 | Train=0.001399 | Val=0.001410
# [MSE]  Epoch  719 | Train=0.001397 | Val=0.001408
# [MSE]  Epoch  720 | Train=0.001395 | Val=0.001406
# [MSE]  Epoch  721 | Train=0.001393 | Val=0.001405
# [MSE]  Epoch  722 | Train=0.001391 | Val=0.001403
# [MSE]  Epoch  723 | Train=0.001390 | Val=0.001401
# [MSE]  Epoch  724 | Train=0.001388 | Val=0.001399
# [MSE]  Epoch  725 | Train=0.001386 | Val=0.001397
# [MSE]  Epoch  726 | Train=0.001384 | Val=0.001396
# [MSE]  Epoch  727 | Train=0.001383 | Val=0.001394
# [MSE]  Epoch  728 | Train=0.001381 | Val=0.001392
# [MSE]  Epoch  729 | Train=0.001379 | Val=0.001390
# [MSE]  Epoch  730 | Train=0.001377 | Val=0.001389
# [MSE]  Epoch  731 | Train=0.001376 | Val=0.001387
# [MSE]  Epoch  732 | Train=0.001374 | Val=0.001385
# [MSE]  Epoch  733 | Train=0.001372 | Val=0.001383
# [MSE]  Epoch  734 | Train=0.001371 | Val=0.001382
# [MSE]  Epoch  735 | Train=0.001369 | Val=0.001380
# [MSE]  Epoch  736 | Train=0.001367 | Val=0.001378
# [MSE]  Epoch  737 | Train=0.001365 | Val=0.001376
# [MSE]  Epoch  738 | Train=0.001364 | Val=0.001375
# [MSE]  Epoch  739 | Train=0.001362 | Val=0.001373
# [MSE]  Epoch  740 | Train=0.001360 | Val=0.001371
# [MSE]  Epoch  741 | Train=0.001359 | Val=0.001369
# [MSE]  Epoch  742 | Train=0.001357 | Val=0.001368
# [MSE]  Epoch  743 | Train=0.001355 | Val=0.001366
# [MSE]  Epoch  744 | Train=0.001354 | Val=0.001364
# [MSE]  Epoch  745 | Train=0.001352 | Val=0.001363
# [MSE]  Epoch  746 | Train=0.001350 | Val=0.001361
# [MSE]  Epoch  747 | Train=0.001349 | Val=0.001359
# [MSE]  Epoch  748 | Train=0.001347 | Val=0.001357
# [MSE]  Epoch  749 | Train=0.001345 | Val=0.001356
# [MSE]  Epoch  750 | Train=0.001344 | Val=0.001354
# [MSE]  Epoch  751 | Train=0.001342 | Val=0.001352
# [MSE]  Epoch  752 | Train=0.001340 | Val=0.001351
# [MSE]  Epoch  753 | Train=0.001339 | Val=0.001349
# [MSE]  Epoch  754 | Train=0.001337 | Val=0.001347
# [MSE]  Epoch  755 | Train=0.001336 | Val=0.001346
# [MSE]  Epoch  756 | Train=0.001334 | Val=0.001344
# [MSE]  Epoch  757 | Train=0.001332 | Val=0.001342
# [MSE]  Epoch  758 | Train=0.001331 | Val=0.001341
# [MSE]  Epoch  759 | Train=0.001329 | Val=0.001339
# [MSE]  Epoch  760 | Train=0.001327 | Val=0.001338
# [MSE]  Epoch  761 | Train=0.001326 | Val=0.001336
# [MSE]  Epoch  762 | Train=0.001324 | Val=0.001334
# [MSE]  Epoch  763 | Train=0.001323 | Val=0.001333
# [MSE]  Epoch  764 | Train=0.001321 | Val=0.001331
# [MSE]  Epoch  765 | Train=0.001319 | Val=0.001329
# [MSE]  Epoch  766 | Train=0.001318 | Val=0.001328
# [MSE]  Epoch  767 | Train=0.001316 | Val=0.001326
# [MSE]  Epoch  768 | Train=0.001315 | Val=0.001325
# [MSE]  Epoch  769 | Train=0.001313 | Val=0.001323
# [MSE]  Epoch  770 | Train=0.001312 | Val=0.001321
# [MSE]  Epoch  771 | Train=0.001310 | Val=0.001320
# [MSE]  Epoch  772 | Train=0.001308 | Val=0.001318
# [MSE]  Epoch  773 | Train=0.001307 | Val=0.001317
# [MSE]  Epoch  774 | Train=0.001305 | Val=0.001315
# [MSE]  Epoch  775 | Train=0.001304 | Val=0.001313
# [MSE]  Epoch  776 | Train=0.001302 | Val=0.001312
# [MSE]  Epoch  777 | Train=0.001301 | Val=0.001310
# [MSE]  Epoch  778 | Train=0.001299 | Val=0.001309
# [MSE]  Epoch  779 | Train=0.001297 | Val=0.001307
# [MSE]  Epoch  780 | Train=0.001296 | Val=0.001305
# [MSE]  Epoch  781 | Train=0.001294 | Val=0.001304
# [MSE]  Epoch  782 | Train=0.001293 | Val=0.001302
# [MSE]  Epoch  783 | Train=0.001291 | Val=0.001301
# [MSE]  Epoch  784 | Train=0.001290 | Val=0.001299
# [MSE]  Epoch  785 | Train=0.001288 | Val=0.001298
# [MSE]  Epoch  786 | Train=0.001287 | Val=0.001296
# [MSE]  Epoch  787 | Train=0.001285 | Val=0.001295
# [MSE]  Epoch  788 | Train=0.001284 | Val=0.001293
# [MSE]  Epoch  789 | Train=0.001282 | Val=0.001291
# [MSE]  Epoch  790 | Train=0.001281 | Val=0.001290
# [MSE]  Epoch  791 | Train=0.001279 | Val=0.001288
# [MSE]  Epoch  792 | Train=0.001278 | Val=0.001287
# [MSE]  Epoch  793 | Train=0.001276 | Val=0.001285
# [MSE]  Epoch  794 | Train=0.001275 | Val=0.001284
# [MSE]  Epoch  795 | Train=0.001273 | Val=0.001282
# [MSE]  Epoch  796 | Train=0.001272 | Val=0.001281
# [MSE]  Epoch  797 | Train=0.001270 | Val=0.001279
# [MSE]  Epoch  798 | Train=0.001269 | Val=0.001278
# [MSE]  Epoch  799 | Train=0.001267 | Val=0.001276
# [MSE]  Epoch  800 | Train=0.001266 | Val=0.001275
# [MSE]  Epoch  801 | Train=0.001264 | Val=0.001273
# [MSE]  Epoch  802 | Train=0.001263 | Val=0.001272
# [MSE]  Epoch  803 | Train=0.001261 | Val=0.001270
# [MSE]  Epoch  804 | Train=0.001260 | Val=0.001269
# [MSE]  Epoch  805 | Train=0.001259 | Val=0.001267
# [MSE]  Epoch  806 | Train=0.001257 | Val=0.001266
# [MSE]  Epoch  807 | Train=0.001256 | Val=0.001264
# [MSE]  Epoch  808 | Train=0.001254 | Val=0.001263
# [MSE]  Epoch  809 | Train=0.001253 | Val=0.001261
# [MSE]  Epoch  810 | Train=0.001251 | Val=0.001260
# [MSE]  Epoch  811 | Train=0.001250 | Val=0.001259
# [MSE]  Epoch  812 | Train=0.001248 | Val=0.001257
# [MSE]  Epoch  813 | Train=0.001247 | Val=0.001256
# [MSE]  Epoch  814 | Train=0.001246 | Val=0.001254
# [MSE]  Epoch  815 | Train=0.001244 | Val=0.001253
# [MSE]  Epoch  816 | Train=0.001243 | Val=0.001251
# [MSE]  Epoch  817 | Train=0.001241 | Val=0.001250
# [MSE]  Epoch  818 | Train=0.001240 | Val=0.001248
# [MSE]  Epoch  819 | Train=0.001238 | Val=0.001247
# [MSE]  Epoch  820 | Train=0.001237 | Val=0.001246
# [MSE]  Epoch  821 | Train=0.001236 | Val=0.001244
# [MSE]  Epoch  822 | Train=0.001234 | Val=0.001243
# [MSE]  Epoch  823 | Train=0.001233 | Val=0.001241
# [MSE]  Epoch  824 | Train=0.001231 | Val=0.001240
# [MSE]  Epoch  825 | Train=0.001230 | Val=0.001238
# [MSE]  Epoch  826 | Train=0.001229 | Val=0.001237
# [MSE]  Epoch  827 | Train=0.001227 | Val=0.001236
# [MSE]  Epoch  828 | Train=0.001226 | Val=0.001234
# [MSE]  Epoch  829 | Train=0.001225 | Val=0.001233
# [MSE]  Epoch  830 | Train=0.001223 | Val=0.001231
# [MSE]  Epoch  831 | Train=0.001222 | Val=0.001230
# [MSE]  Epoch  832 | Train=0.001220 | Val=0.001229
# [MSE]  Epoch  833 | Train=0.001219 | Val=0.001227
# [MSE]  Epoch  834 | Train=0.001218 | Val=0.001226
# [MSE]  Epoch  835 | Train=0.001216 | Val=0.001224
# [MSE]  Epoch  836 | Train=0.001215 | Val=0.001223
# [MSE]  Epoch  837 | Train=0.001214 | Val=0.001222
# [MSE]  Epoch  838 | Train=0.001212 | Val=0.001220
# [MSE]  Epoch  839 | Train=0.001211 | Val=0.001219
# [MSE]  Epoch  840 | Train=0.001210 | Val=0.001218
# [MSE]  Epoch  841 | Train=0.001208 | Val=0.001216
# [MSE]  Epoch  842 | Train=0.001207 | Val=0.001215
# [MSE]  Epoch  843 | Train=0.001206 | Val=0.001213
# [MSE]  Epoch  844 | Train=0.001204 | Val=0.001212
# [MSE]  Epoch  845 | Train=0.001203 | Val=0.001211
# [MSE]  Epoch  846 | Train=0.001201 | Val=0.001209
# [MSE]  Epoch  847 | Train=0.001200 | Val=0.001208
# [MSE]  Epoch  848 | Train=0.001199 | Val=0.001207
# [MSE]  Epoch  849 | Train=0.001197 | Val=0.001205
# [MSE]  Epoch  850 | Train=0.001196 | Val=0.001204
# [MSE]  Epoch  851 | Train=0.001195 | Val=0.001203
# [MSE]  Epoch  852 | Train=0.001194 | Val=0.001201
# [MSE]  Epoch  853 | Train=0.001192 | Val=0.001200
# [MSE]  Epoch  854 | Train=0.001191 | Val=0.001199
# [MSE]  Epoch  855 | Train=0.001190 | Val=0.001197
# [MSE]  Epoch  856 | Train=0.001188 | Val=0.001196
# [MSE]  Epoch  857 | Train=0.001187 | Val=0.001195
# [MSE]  Epoch  858 | Train=0.001186 | Val=0.001193
# [MSE]  Epoch  859 | Train=0.001184 | Val=0.001192
# [MSE]  Epoch  860 | Train=0.001183 | Val=0.001191
# [MSE]  Epoch  861 | Train=0.001182 | Val=0.001189
# [MSE]  Epoch  862 | Train=0.001180 | Val=0.001188
# [MSE]  Epoch  863 | Train=0.001179 | Val=0.001187
# [MSE]  Epoch  864 | Train=0.001178 | Val=0.001185
# [MSE]  Epoch  865 | Train=0.001176 | Val=0.001184
# [MSE]  Epoch  866 | Train=0.001175 | Val=0.001183
# [MSE]  Epoch  867 | Train=0.001174 | Val=0.001181
# [MSE]  Epoch  868 | Train=0.001173 | Val=0.001180
# [MSE]  Epoch  869 | Train=0.001171 | Val=0.001179
# [MSE]  Epoch  870 | Train=0.001170 | Val=0.001177
# [MSE]  Epoch  871 | Train=0.001169 | Val=0.001176
# [MSE]  Epoch  872 | Train=0.001167 | Val=0.001175
# [MSE]  Epoch  873 | Train=0.001166 | Val=0.001173
# [MSE]  Epoch  874 | Train=0.001165 | Val=0.001172
# [MSE]  Epoch  875 | Train=0.001164 | Val=0.001171
# [MSE]  Epoch  876 | Train=0.001162 | Val=0.001170
# [MSE]  Epoch  877 | Train=0.001161 | Val=0.001168
# [MSE]  Epoch  878 | Train=0.001160 | Val=0.001167
# [MSE]  Epoch  879 | Train=0.001158 | Val=0.001166
# [MSE]  Epoch  880 | Train=0.001157 | Val=0.001164
# [MSE]  Epoch  881 | Train=0.001156 | Val=0.001163
# [MSE]  Epoch  882 | Train=0.001155 | Val=0.001162
# [MSE]  Epoch  883 | Train=0.001153 | Val=0.001160
# [MSE]  Epoch  884 | Train=0.001152 | Val=0.001159
# [MSE]  Epoch  885 | Train=0.001151 | Val=0.001158
# [MSE]  Epoch  886 | Train=0.001150 | Val=0.001157
# [MSE]  Epoch  887 | Train=0.001148 | Val=0.001155
# [MSE]  Epoch  888 | Train=0.001147 | Val=0.001154
# [MSE]  Epoch  889 | Train=0.001146 | Val=0.001153
# [MSE]  Epoch  890 | Train=0.001144 | Val=0.001152
# [MSE]  Epoch  891 | Train=0.001143 | Val=0.001150
# [MSE]  Epoch  892 | Train=0.001142 | Val=0.001149
# [MSE]  Epoch  893 | Train=0.001141 | Val=0.001148
# [MSE]  Epoch  894 | Train=0.001139 | Val=0.001146
# [MSE]  Epoch  895 | Train=0.001138 | Val=0.001145
# [MSE]  Epoch  896 | Train=0.001137 | Val=0.001144
# [MSE]  Epoch  897 | Train=0.001136 | Val=0.001143
# [MSE]  Epoch  898 | Train=0.001135 | Val=0.001141
# [MSE]  Epoch  899 | Train=0.001133 | Val=0.001140
# [MSE]  Epoch  900 | Train=0.001132 | Val=0.001139
# [MSE]  Epoch  901 | Train=0.001131 | Val=0.001138
# [MSE]  Epoch  902 | Train=0.001130 | Val=0.001136
# [MSE]  Epoch  903 | Train=0.001128 | Val=0.001135
# [MSE]  Epoch  904 | Train=0.001127 | Val=0.001134
# [MSE]  Epoch  905 | Train=0.001126 | Val=0.001133
# [MSE]  Epoch  906 | Train=0.001125 | Val=0.001132
# [MSE]  Epoch  907 | Train=0.001124 | Val=0.001130
# [MSE]  Epoch  908 | Train=0.001122 | Val=0.001129
# [MSE]  Epoch  909 | Train=0.001121 | Val=0.001128
# [MSE]  Epoch  910 | Train=0.001120 | Val=0.001127
# [MSE]  Epoch  911 | Train=0.001119 | Val=0.001126
# [MSE]  Epoch  912 | Train=0.001118 | Val=0.001124
# [MSE]  Epoch  913 | Train=0.001116 | Val=0.001123
# [MSE]  Epoch  914 | Train=0.001115 | Val=0.001122
# [MSE]  Epoch  915 | Train=0.001114 | Val=0.001121
# [MSE]  Epoch  916 | Train=0.001113 | Val=0.001120
# [MSE]  Epoch  917 | Train=0.001112 | Val=0.001118
# [MSE]  Epoch  918 | Train=0.001111 | Val=0.001117
# [MSE]  Epoch  919 | Train=0.001109 | Val=0.001116
# [MSE]  Epoch  920 | Train=0.001108 | Val=0.001115
# [MSE]  Epoch  921 | Train=0.001107 | Val=0.001114
# [MSE]  Epoch  922 | Train=0.001106 | Val=0.001113
# [MSE]  Epoch  923 | Train=0.001105 | Val=0.001111
# [MSE]  Epoch  924 | Train=0.001104 | Val=0.001110
# [MSE]  Epoch  925 | Train=0.001103 | Val=0.001109
# [MSE]  Epoch  926 | Train=0.001101 | Val=0.001108
# [MSE]  Epoch  927 | Train=0.001100 | Val=0.001107
# [MSE]  Epoch  928 | Train=0.001099 | Val=0.001106
# [MSE]  Epoch  929 | Train=0.001098 | Val=0.001105
# [MSE]  Epoch  930 | Train=0.001097 | Val=0.001104
# [MSE]  Epoch  931 | Train=0.001096 | Val=0.001102
# [MSE]  Epoch  932 | Train=0.001095 | Val=0.001101
# [MSE]  Epoch  933 | Train=0.001094 | Val=0.001100
# [MSE]  Epoch  934 | Train=0.001093 | Val=0.001099
# [MSE]  Epoch  935 | Train=0.001092 | Val=0.001098
# [MSE]  Epoch  936 | Train=0.001090 | Val=0.001097
# [MSE]  Epoch  937 | Train=0.001089 | Val=0.001096
# [MSE]  Epoch  938 | Train=0.001088 | Val=0.001095
# [MSE]  Epoch  939 | Train=0.001087 | Val=0.001094
# [MSE]  Epoch  940 | Train=0.001086 | Val=0.001093
# [MSE]  Epoch  941 | Train=0.001085 | Val=0.001091
# [MSE]  Epoch  942 | Train=0.001084 | Val=0.001090
# [MSE]  Epoch  943 | Train=0.001083 | Val=0.001089
# [MSE]  Epoch  944 | Train=0.001082 | Val=0.001088
# [MSE]  Epoch  945 | Train=0.001081 | Val=0.001087
# [MSE]  Epoch  946 | Train=0.001080 | Val=0.001086
# [MSE]  Epoch  947 | Train=0.001079 | Val=0.001085
# [MSE]  Epoch  948 | Train=0.001078 | Val=0.001084
# [MSE]  Epoch  949 | Train=0.001077 | Val=0.001083
# [MSE]  Epoch  950 | Train=0.001076 | Val=0.001082
# [MSE]  Epoch  951 | Train=0.001074 | Val=0.001081
# [MSE]  Epoch  952 | Train=0.001073 | Val=0.001080
# [MSE]  Epoch  953 | Train=0.001072 | Val=0.001079
# [MSE]  Epoch  954 | Train=0.001071 | Val=0.001078
# [MSE]  Epoch  955 | Train=0.001070 | Val=0.001077
# [MSE]  Epoch  956 | Train=0.001069 | Val=0.001076
# [MSE]  Epoch  957 | Train=0.001068 | Val=0.001075
# [MSE]  Epoch  958 | Train=0.001067 | Val=0.001073
# [MSE]  Epoch  959 | Train=0.001066 | Val=0.001072
# [MSE]  Epoch  960 | Train=0.001065 | Val=0.001071
# [MSE]  Epoch  961 | Train=0.001064 | Val=0.001070
# [MSE]  Epoch  962 | Train=0.001063 | Val=0.001069
# [MSE]  Epoch  963 | Train=0.001062 | Val=0.001068
# [MSE]  Epoch  964 | Train=0.001061 | Val=0.001067
# [MSE]  Epoch  965 | Train=0.001060 | Val=0.001066
# [MSE]  Epoch  966 | Train=0.001059 | Val=0.001065
# [MSE]  Epoch  967 | Train=0.001058 | Val=0.001064
# [MSE]  Epoch  968 | Train=0.001057 | Val=0.001063
# [MSE]  Epoch  969 | Train=0.001056 | Val=0.001062
# [MSE]  Epoch  970 | Train=0.001055 | Val=0.001061
# [MSE]  Epoch  971 | Train=0.001054 | Val=0.001060
# [MSE]  Epoch  972 | Train=0.001053 | Val=0.001059
# [MSE]  Epoch  973 | Train=0.001052 | Val=0.001058
# [MSE]  Epoch  974 | Train=0.001051 | Val=0.001057
# [MSE]  Epoch  975 | Train=0.001050 | Val=0.001056
# [MSE]  Epoch  976 | Train=0.001049 | Val=0.001055
# [MSE]  Epoch  977 | Train=0.001048 | Val=0.001054
# [MSE]  Epoch  978 | Train=0.001047 | Val=0.001053
# [MSE]  Epoch  979 | Train=0.001046 | Val=0.001052
# [MSE]  Epoch  980 | Train=0.001045 | Val=0.001051
# [MSE]  Epoch  981 | Train=0.001044 | Val=0.001050
# [MSE]  Epoch  982 | Train=0.001043 | Val=0.001049
# [MSE]  Epoch  983 | Train=0.001042 | Val=0.001048
# [MSE]  Epoch  984 | Train=0.001041 | Val=0.001047
# [MSE]  Epoch  985 | Train=0.001040 | Val=0.001046
# [MSE]  Epoch  986 | Train=0.001039 | Val=0.001045
# [MSE]  Epoch  987 | Train=0.001038 | Val=0.001044
# [MSE]  Epoch  988 | Train=0.001037 | Val=0.001043
# [MSE]  Epoch  989 | Train=0.001036 | Val=0.001042
# [MSE]  Epoch  990 | Train=0.001035 | Val=0.001041
# [MSE]  Epoch  991 | Train=0.001034 | Val=0.001040
# [MSE]  Epoch  992 | Train=0.001034 | Val=0.001039
# [MSE]  Epoch  993 | Train=0.001033 | Val=0.001038
# [MSE]  Epoch  994 | Train=0.001032 | Val=0.001037
# [MSE]  Epoch  995 | Train=0.001031 | Val=0.001036
# [MSE]  Epoch  996 | Train=0.001030 | Val=0.001036
# [MSE]  Epoch  997 | Train=0.001029 | Val=0.001035
# [MSE]  Epoch  998 | Train=0.001028 | Val=0.001034
# [MSE]  Epoch  999 | Train=0.001027 | Val=0.001033

# %% [markdown]
# #### Weighted MSE Model (WMSE)

# %%
# training weighted WMSE Model
torch.manual_seed(42)
model_wmse = OptionPricer()
opt_wmse = torch.optim.Adam(model_wmse.parameters(), lr=LR)

wmse_train_losses = []
wmse_val_losses = []

for epoch in range(EPOCHS):                                # full batch training; change to smaller batches later
    model_wmse.train()
    pred = model_wmse(x_train).squeeze()
    loss = weighted_mse(pred, y_train, weights_train)       # using the precalculated weigthed loss 

    opt_wmse.zero_grad()                                   # clean the gradients from the previous batch 
    loss.backward()                                        # gradients computation with the weighted loss 
    opt_wmse.step()                                        # weights are updated based on the weighted gradients 
    wmse_train_losses.append(loss.item())

 
    model_wmse.eval()                                        
    with torch.no_grad():
        val_pred = model_wmse(x_val).squeeze()                                   # forward pass for val 
        val_loss = weighted_mse(val_pred, y_val, weights_val)                    # calcualte loss 
        wmse_val_losses.append(val_loss.item())
    print(f"[WMSE]  Epoch {epoch:4d} | Train={loss.item():.6f} | Val={val_loss.item():.6f}")
# Out:
# [WMSE]  Epoch    0 | Train=1.003754 | Val=0.897660
# [WMSE]  Epoch    1 | Train=0.889203 | Val=0.796532
# [WMSE]  Epoch    2 | Train=0.789039 | Val=0.709194
# [WMSE]  Epoch    3 | Train=0.702616 | Val=0.634425
# [WMSE]  Epoch    4 | Train=0.628709 | Val=0.570839
# [WMSE]  Epoch    5 | Train=0.565931 | Val=0.516941
# [WMSE]  Epoch    6 | Train=0.512786 | Val=0.471155
# [WMSE]  Epoch    7 | Train=0.467691 | Val=0.431892
# [WMSE]  Epoch    8 | Train=0.429056 | Val=0.397692
# [WMSE]  Epoch    9 | Train=0.395415 | Val=0.367352
# [WMSE]  Epoch   10 | Train=0.365566 | Val=0.340021
# [WMSE]  Epoch   11 | Train=0.338655 | Val=0.315218
# [WMSE]  Epoch   12 | Train=0.314203 | Val=0.292792
# [WMSE]  Epoch   13 | Train=0.292062 | Val=0.272847
# [WMSE]  Epoch   14 | Train=0.272339 | Val=0.255637
# [WMSE]  Epoch   15 | Train=0.255295 | Val=0.241464
# [WMSE]  Epoch   16 | Train=0.241235 | Val=0.230568
# [WMSE]  Epoch   17 | Train=0.230408 | Val=0.223035
# [WMSE]  Epoch   18 | Train=0.222908 | Val=0.218726
# [WMSE]  Epoch   19 | Train=0.218604 | Val=0.217238
# [WMSE]  Epoch   20 | Train=0.217107 | Val=0.217929
# [WMSE]  Epoch   21 | Train=0.217782 | Val=0.219993
# [WMSE]  Epoch   22 | Train=0.219836 | Val=0.222595
# [WMSE]  Epoch   23 | Train=0.222441 | Val=0.225007
# [WMSE]  Epoch   24 | Train=0.224874 | Val=0.226718
# [WMSE]  Epoch   25 | Train=0.226629 | Val=0.227476
# [WMSE]  Epoch   26 | Train=0.227453 | Val=0.227264
# [WMSE]  Epoch   27 | Train=0.227324 | Val=0.226228
# [WMSE]  Epoch   28 | Train=0.226385 | Val=0.224592
# [WMSE]  Epoch   29 | Train=0.224850 | Val=0.222578
# [WMSE]  Epoch   30 | Train=0.222935 | Val=0.220352
# [WMSE]  Epoch   31 | Train=0.220799 | Val=0.218010
# [WMSE]  Epoch   32 | Train=0.218529 | Val=0.215582
# [WMSE]  Epoch   33 | Train=0.216152 | Val=0.213069
# [WMSE]  Epoch   34 | Train=0.213665 | Val=0.210474
# [WMSE]  Epoch   35 | Train=0.211069 | Val=0.207828
# [WMSE]  Epoch   36 | Train=0.208396 | Val=0.205195
# [WMSE]  Epoch   37 | Train=0.205712 | Val=0.202667
# [WMSE]  Epoch   38 | Train=0.203113 | Val=0.200342
# [WMSE]  Epoch   39 | Train=0.200702 | Val=0.198298
# [WMSE]  Epoch   40 | Train=0.198563 | Val=0.196578
# [WMSE]  Epoch   41 | Train=0.196743 | Val=0.195178
# [WMSE]  Epoch   42 | Train=0.195246 | Val=0.194052
# [WMSE]  Epoch   43 | Train=0.194028 | Val=0.193119
# [WMSE]  Epoch   44 | Train=0.193016 | Val=0.192290
# [WMSE]  Epoch   45 | Train=0.192121 | Val=0.191478
# [WMSE]  Epoch   46 | Train=0.191259 | Val=0.190616
# [WMSE]  Epoch   47 | Train=0.190365 | Val=0.189665
# [WMSE]  Epoch   48 | Train=0.189397 | Val=0.188614
# [WMSE]  Epoch   49 | Train=0.188345 | Val=0.187471
# [WMSE]  Epoch   50 | Train=0.187213 | Val=0.186258
# [WMSE]  Epoch   51 | Train=0.186021 | Val=0.184997
# [WMSE]  Epoch   52 | Train=0.184788 | Val=0.183705
# [WMSE]  Epoch   53 | Train=0.183528 | Val=0.182392
# [WMSE]  Epoch   54 | Train=0.182248 | Val=0.181059
# [WMSE]  Epoch   55 | Train=0.180946 | Val=0.179702
# [WMSE]  Epoch   56 | Train=0.179616 | Val=0.178318
# [WMSE]  Epoch   57 | Train=0.178253 | Val=0.176909
# [WMSE]  Epoch   58 | Train=0.176859 | Val=0.175481
# [WMSE]  Epoch   59 | Train=0.175440 | Val=0.174049
# [WMSE]  Epoch   60 | Train=0.174012 | Val=0.172628
# [WMSE]  Epoch   61 | Train=0.172589 | Val=0.171233
# [WMSE]  Epoch   62 | Train=0.171189 | Val=0.169869
# [WMSE]  Epoch   63 | Train=0.169819 | Val=0.168538
# [WMSE]  Epoch   64 | Train=0.168481 | Val=0.167232
# [WMSE]  Epoch   65 | Train=0.167170 | Val=0.165939
# [WMSE]  Epoch   66 | Train=0.165874 | Val=0.164645
# [WMSE]  Epoch   67 | Train=0.164581 | Val=0.163339
# [WMSE]  Epoch   68 | Train=0.163280 | Val=0.162015
# [WMSE]  Epoch   69 | Train=0.161964 | Val=0.160670
# [WMSE]  Epoch   70 | Train=0.160630 | Val=0.159308
# [WMSE]  Epoch   71 | Train=0.159281 | Val=0.157931
# [WMSE]  Epoch   72 | Train=0.157917 | Val=0.156543
# [WMSE]  Epoch   73 | Train=0.156542 | Val=0.155146
# [WMSE]  Epoch   74 | Train=0.155155 | Val=0.153738
# [WMSE]  Epoch   75 | Train=0.153755 | Val=0.152320
# [WMSE]  Epoch   76 | Train=0.152340 | Val=0.150890
# [WMSE]  Epoch   77 | Train=0.150909 | Val=0.149449
# [WMSE]  Epoch   78 | Train=0.149463 | Val=0.147999
# [WMSE]  Epoch   79 | Train=0.148004 | Val=0.146542
# [WMSE]  Epoch   80 | Train=0.146536 | Val=0.145082
# [WMSE]  Epoch   81 | Train=0.145062 | Val=0.143620
# [WMSE]  Epoch   82 | Train=0.143586 | Val=0.142155
# [WMSE]  Epoch   83 | Train=0.142107 | Val=0.140687
# [WMSE]  Epoch   84 | Train=0.140625 | Val=0.139212
# [WMSE]  Epoch   85 | Train=0.139140 | Val=0.137728
# [WMSE]  Epoch   86 | Train=0.137647 | Val=0.136233
# [WMSE]  Epoch   87 | Train=0.136147 | Val=0.134727
# [WMSE]  Epoch   88 | Train=0.134637 | Val=0.133210
# [WMSE]  Epoch   89 | Train=0.133119 | Val=0.131683
# [WMSE]  Epoch   90 | Train=0.131593 | Val=0.130148
# [WMSE]  Epoch   91 | Train=0.130059 | Val=0.128604
# [WMSE]  Epoch   92 | Train=0.128516 | Val=0.127053
# [WMSE]  Epoch   93 | Train=0.126966 | Val=0.125494
# [WMSE]  Epoch   94 | Train=0.125407 | Val=0.123927
# [WMSE]  Epoch   95 | Train=0.123839 | Val=0.122353
# [WMSE]  Epoch   96 | Train=0.122262 | Val=0.120772
# [WMSE]  Epoch   97 | Train=0.120678 | Val=0.119185
# [WMSE]  Epoch   98 | Train=0.119087 | Val=0.117593
# [WMSE]  Epoch   99 | Train=0.117491 | Val=0.115996
# [WMSE]  Epoch  100 | Train=0.115889 | Val=0.114393
# [WMSE]  Epoch  101 | Train=0.114282 | Val=0.112785
# [WMSE]  Epoch  102 | Train=0.112671 | Val=0.111171
# [WMSE]  Epoch  103 | Train=0.111054 | Val=0.109551
# [WMSE]  Epoch  104 | Train=0.109433 | Val=0.107925
# [WMSE]  Epoch  105 | Train=0.107806 | Val=0.106295
# [WMSE]  Epoch  106 | Train=0.106176 | Val=0.104660
# [WMSE]  Epoch  107 | Train=0.104541 | Val=0.103022
# [WMSE]  Epoch  108 | Train=0.102902 | Val=0.101380
# [WMSE]  Epoch  109 | Train=0.101260 | Val=0.099736
# [WMSE]  Epoch  110 | Train=0.099615 | Val=0.098090
# [WMSE]  Epoch  111 | Train=0.097967 | Val=0.096443
# [WMSE]  Epoch  112 | Train=0.096317 | Val=0.094794
# [WMSE]  Epoch  113 | Train=0.094664 | Val=0.093145
# [WMSE]  Epoch  114 | Train=0.093011 | Val=0.091495
# [WMSE]  Epoch  115 | Train=0.091357 | Val=0.089846
# [WMSE]  Epoch  116 | Train=0.089703 | Val=0.088197
# [WMSE]  Epoch  117 | Train=0.088050 | Val=0.086548
# [WMSE]  Epoch  118 | Train=0.086398 | Val=0.084901
# [WMSE]  Epoch  119 | Train=0.084748 | Val=0.083256
# [WMSE]  Epoch  120 | Train=0.083100 | Val=0.081613
# [WMSE]  Epoch  121 | Train=0.081454 | Val=0.079973
# [WMSE]  Epoch  122 | Train=0.079813 | Val=0.078338
# [WMSE]  Epoch  123 | Train=0.078175 | Val=0.076706
# [WMSE]  Epoch  124 | Train=0.076542 | Val=0.075080
# [WMSE]  Epoch  125 | Train=0.074915 | Val=0.073461
# [WMSE]  Epoch  126 | Train=0.073293 | Val=0.071848
# [WMSE]  Epoch  127 | Train=0.071678 | Val=0.070242
# [WMSE]  Epoch  128 | Train=0.070070 | Val=0.068645
# [WMSE]  Epoch  129 | Train=0.068471 | Val=0.067057
# [WMSE]  Epoch  130 | Train=0.066880 | Val=0.065479
# [WMSE]  Epoch  131 | Train=0.065299 | Val=0.063910
# [WMSE]  Epoch  132 | Train=0.063728 | Val=0.062353
# [WMSE]  Epoch  133 | Train=0.062169 | Val=0.060808
# [WMSE]  Epoch  134 | Train=0.060622 | Val=0.059275
# [WMSE]  Epoch  135 | Train=0.059088 | Val=0.057756
# [WMSE]  Epoch  136 | Train=0.057568 | Val=0.056251
# [WMSE]  Epoch  137 | Train=0.056061 | Val=0.054761
# [WMSE]  Epoch  138 | Train=0.054571 | Val=0.053287
# [WMSE]  Epoch  139 | Train=0.053096 | Val=0.051831
# [WMSE]  Epoch  140 | Train=0.051638 | Val=0.050392
# [WMSE]  Epoch  141 | Train=0.050198 | Val=0.048972
# [WMSE]  Epoch  142 | Train=0.048777 | Val=0.047571
# [WMSE]  Epoch  143 | Train=0.047375 | Val=0.046191
# [WMSE]  Epoch  144 | Train=0.045993 | Val=0.044831
# [WMSE]  Epoch  145 | Train=0.044632 | Val=0.043493
# [WMSE]  Epoch  146 | Train=0.043293 | Val=0.042177
# [WMSE]  Epoch  147 | Train=0.041976 | Val=0.040884
# [WMSE]  Epoch  148 | Train=0.040682 | Val=0.039615
# [WMSE]  Epoch  149 | Train=0.039413 | Val=0.038370
# [WMSE]  Epoch  150 | Train=0.038168 | Val=0.037151
# [WMSE]  Epoch  151 | Train=0.036948 | Val=0.035957
# [WMSE]  Epoch  152 | Train=0.035755 | Val=0.034790
# [WMSE]  Epoch  153 | Train=0.034588 | Val=0.033650
# [WMSE]  Epoch  154 | Train=0.033448 | Val=0.032538
# [WMSE]  Epoch  155 | Train=0.032335 | Val=0.031453
# [WMSE]  Epoch  156 | Train=0.031251 | Val=0.030397
# [WMSE]  Epoch  157 | Train=0.030195 | Val=0.029370
# [WMSE]  Epoch  158 | Train=0.029169 | Val=0.028372
# [WMSE]  Epoch  159 | Train=0.028171 | Val=0.027403
# [WMSE]  Epoch  160 | Train=0.027203 | Val=0.026464
# [WMSE]  Epoch  161 | Train=0.026264 | Val=0.025554
# [WMSE]  Epoch  162 | Train=0.025355 | Val=0.024675
# [WMSE]  Epoch  163 | Train=0.024477 | Val=0.023825
# [WMSE]  Epoch  164 | Train=0.023628 | Val=0.023005
# [WMSE]  Epoch  165 | Train=0.022809 | Val=0.022215
# [WMSE]  Epoch  166 | Train=0.022021 | Val=0.021455
# [WMSE]  Epoch  167 | Train=0.021262 | Val=0.020725
# [WMSE]  Epoch  168 | Train=0.020532 | Val=0.020023
# [WMSE]  Epoch  169 | Train=0.019833 | Val=0.019351
# [WMSE]  Epoch  170 | Train=0.019162 | Val=0.018708
# [WMSE]  Epoch  171 | Train=0.018520 | Val=0.018092
# [WMSE]  Epoch  172 | Train=0.017906 | Val=0.017505
# [WMSE]  Epoch  173 | Train=0.017320 | Val=0.016945
# [WMSE]  Epoch  174 | Train=0.016762 | Val=0.016411
# [WMSE]  Epoch  175 | Train=0.016230 | Val=0.015904
# [WMSE]  Epoch  176 | Train=0.015725 | Val=0.015423
# [WMSE]  Epoch  177 | Train=0.015245 | Val=0.014966
# [WMSE]  Epoch  178 | Train=0.014791 | Val=0.014534
# [WMSE]  Epoch  179 | Train=0.014360 | Val=0.014125
# [WMSE]  Epoch  180 | Train=0.013953 | Val=0.013739
# [WMSE]  Epoch  181 | Train=0.013569 | Val=0.013374
# [WMSE]  Epoch  182 | Train=0.013206 | Val=0.013030
# [WMSE]  Epoch  183 | Train=0.012865 | Val=0.012707
# [WMSE]  Epoch  184 | Train=0.012543 | Val=0.012402
# [WMSE]  Epoch  185 | Train=0.012240 | Val=0.012115
# [WMSE]  Epoch  186 | Train=0.011955 | Val=0.011846
# [WMSE]  Epoch  187 | Train=0.011688 | Val=0.011592
# [WMSE]  Epoch  188 | Train=0.011437 | Val=0.011354
# [WMSE]  Epoch  189 | Train=0.011201 | Val=0.011131
# [WMSE]  Epoch  190 | Train=0.010979 | Val=0.010921
# [WMSE]  Epoch  191 | Train=0.010771 | Val=0.010723
# [WMSE]  Epoch  192 | Train=0.010575 | Val=0.010538
# [WMSE]  Epoch  193 | Train=0.010392 | Val=0.010363
# [WMSE]  Epoch  194 | Train=0.010219 | Val=0.010199
# [WMSE]  Epoch  195 | Train=0.010057 | Val=0.010044
# [WMSE]  Epoch  196 | Train=0.009903 | Val=0.009898
# [WMSE]  Epoch  197 | Train=0.009759 | Val=0.009760
# [WMSE]  Epoch  198 | Train=0.009623 | Val=0.009630
# [WMSE]  Epoch  199 | Train=0.009494 | Val=0.009506
# [WMSE]  Epoch  200 | Train=0.009371 | Val=0.009388
# [WMSE]  Epoch  201 | Train=0.009255 | Val=0.009276
# [WMSE]  Epoch  202 | Train=0.009145 | Val=0.009169
# [WMSE]  Epoch  203 | Train=0.009039 | Val=0.009067
# [WMSE]  Epoch  204 | Train=0.008938 | Val=0.008968
# [WMSE]  Epoch  205 | Train=0.008841 | Val=0.008874
# [WMSE]  Epoch  206 | Train=0.008748 | Val=0.008783
# [WMSE]  Epoch  207 | Train=0.008658 | Val=0.008695
# [WMSE]  Epoch  208 | Train=0.008572 | Val=0.008610
# [WMSE]  Epoch  209 | Train=0.008488 | Val=0.008527
# [WMSE]  Epoch  210 | Train=0.008406 | Val=0.008447
# [WMSE]  Epoch  211 | Train=0.008327 | Val=0.008368
# [WMSE]  Epoch  212 | Train=0.008249 | Val=0.008292
# [WMSE]  Epoch  213 | Train=0.008173 | Val=0.008216
# [WMSE]  Epoch  214 | Train=0.008099 | Val=0.008143
# [WMSE]  Epoch  215 | Train=0.008027 | Val=0.008070
# [WMSE]  Epoch  216 | Train=0.007955 | Val=0.007999
# [WMSE]  Epoch  217 | Train=0.007885 | Val=0.007929
# [WMSE]  Epoch  218 | Train=0.007815 | Val=0.007860
# [WMSE]  Epoch  219 | Train=0.007747 | Val=0.007792
# [WMSE]  Epoch  220 | Train=0.007680 | Val=0.007724
# [WMSE]  Epoch  221 | Train=0.007613 | Val=0.007658
# [WMSE]  Epoch  222 | Train=0.007547 | Val=0.007592
# [WMSE]  Epoch  223 | Train=0.007482 | Val=0.007527
# [WMSE]  Epoch  224 | Train=0.007417 | Val=0.007463
# [WMSE]  Epoch  225 | Train=0.007354 | Val=0.007399
# [WMSE]  Epoch  226 | Train=0.007291 | Val=0.007336
# [WMSE]  Epoch  227 | Train=0.007228 | Val=0.007273
# [WMSE]  Epoch  228 | Train=0.007166 | Val=0.007211
# [WMSE]  Epoch  229 | Train=0.007105 | Val=0.007150
# [WMSE]  Epoch  230 | Train=0.007044 | Val=0.007090
# [WMSE]  Epoch  231 | Train=0.006984 | Val=0.007030
# [WMSE]  Epoch  232 | Train=0.006925 | Val=0.006970
# [WMSE]  Epoch  233 | Train=0.006866 | Val=0.006911
# [WMSE]  Epoch  234 | Train=0.006807 | Val=0.006853
# [WMSE]  Epoch  235 | Train=0.006750 | Val=0.006796
# [WMSE]  Epoch  236 | Train=0.006693 | Val=0.006739
# [WMSE]  Epoch  237 | Train=0.006636 | Val=0.006682
# [WMSE]  Epoch  238 | Train=0.006580 | Val=0.006626
# [WMSE]  Epoch  239 | Train=0.006524 | Val=0.006571
# [WMSE]  Epoch  240 | Train=0.006470 | Val=0.006516
# [WMSE]  Epoch  241 | Train=0.006415 | Val=0.006462
# [WMSE]  Epoch  242 | Train=0.006361 | Val=0.006408
# [WMSE]  Epoch  243 | Train=0.006308 | Val=0.006355
# [WMSE]  Epoch  244 | Train=0.006255 | Val=0.006302
# [WMSE]  Epoch  245 | Train=0.006203 | Val=0.006250
# [WMSE]  Epoch  246 | Train=0.006152 | Val=0.006199
# [WMSE]  Epoch  247 | Train=0.006100 | Val=0.006148
# [WMSE]  Epoch  248 | Train=0.006050 | Val=0.006097
# [WMSE]  Epoch  249 | Train=0.006000 | Val=0.006047
# [WMSE]  Epoch  250 | Train=0.005950 | Val=0.005998
# [WMSE]  Epoch  251 | Train=0.005901 | Val=0.005949
# [WMSE]  Epoch  252 | Train=0.005852 | Val=0.005900
# [WMSE]  Epoch  253 | Train=0.005804 | Val=0.005852
# [WMSE]  Epoch  254 | Train=0.005757 | Val=0.005804
# [WMSE]  Epoch  255 | Train=0.005709 | Val=0.005757
# [WMSE]  Epoch  256 | Train=0.005663 | Val=0.005711
# [WMSE]  Epoch  257 | Train=0.005617 | Val=0.005665
# [WMSE]  Epoch  258 | Train=0.005571 | Val=0.005619
# [WMSE]  Epoch  259 | Train=0.005526 | Val=0.005574
# [WMSE]  Epoch  260 | Train=0.005481 | Val=0.005529
# [WMSE]  Epoch  261 | Train=0.005437 | Val=0.005485
# [WMSE]  Epoch  262 | Train=0.005393 | Val=0.005441
# [WMSE]  Epoch  263 | Train=0.005349 | Val=0.005398
# [WMSE]  Epoch  264 | Train=0.005306 | Val=0.005355
# [WMSE]  Epoch  265 | Train=0.005264 | Val=0.005312
# [WMSE]  Epoch  266 | Train=0.005222 | Val=0.005270
# [WMSE]  Epoch  267 | Train=0.005180 | Val=0.005228
# [WMSE]  Epoch  268 | Train=0.005139 | Val=0.005187
# [WMSE]  Epoch  269 | Train=0.005098 | Val=0.005146
# [WMSE]  Epoch  270 | Train=0.005057 | Val=0.005106
# [WMSE]  Epoch  271 | Train=0.005017 | Val=0.005066
# [WMSE]  Epoch  272 | Train=0.004978 | Val=0.005026
# [WMSE]  Epoch  273 | Train=0.004939 | Val=0.004987
# [WMSE]  Epoch  274 | Train=0.004900 | Val=0.004948
# [WMSE]  Epoch  275 | Train=0.004862 | Val=0.004910
# [WMSE]  Epoch  276 | Train=0.004824 | Val=0.004872
# [WMSE]  Epoch  277 | Train=0.004786 | Val=0.004834
# [WMSE]  Epoch  278 | Train=0.004749 | Val=0.004797
# [WMSE]  Epoch  279 | Train=0.004712 | Val=0.004760
# [WMSE]  Epoch  280 | Train=0.004675 | Val=0.004724
# [WMSE]  Epoch  281 | Train=0.004639 | Val=0.004687
# [WMSE]  Epoch  282 | Train=0.004604 | Val=0.004652
# [WMSE]  Epoch  283 | Train=0.004568 | Val=0.004616
# [WMSE]  Epoch  284 | Train=0.004533 | Val=0.004581
# [WMSE]  Epoch  285 | Train=0.004499 | Val=0.004547
# [WMSE]  Epoch  286 | Train=0.004465 | Val=0.004512
# [WMSE]  Epoch  287 | Train=0.004431 | Val=0.004479
# [WMSE]  Epoch  288 | Train=0.004397 | Val=0.004445
# [WMSE]  Epoch  289 | Train=0.004364 | Val=0.004412
# [WMSE]  Epoch  290 | Train=0.004331 | Val=0.004379
# [WMSE]  Epoch  291 | Train=0.004299 | Val=0.004346
# [WMSE]  Epoch  292 | Train=0.004267 | Val=0.004314
# [WMSE]  Epoch  293 | Train=0.004235 | Val=0.004282
# [WMSE]  Epoch  294 | Train=0.004203 | Val=0.004251
# [WMSE]  Epoch  295 | Train=0.004172 | Val=0.004220
# [WMSE]  Epoch  296 | Train=0.004142 | Val=0.004189
# [WMSE]  Epoch  297 | Train=0.004111 | Val=0.004158
# [WMSE]  Epoch  298 | Train=0.004081 | Val=0.004128
# [WMSE]  Epoch  299 | Train=0.004051 | Val=0.004098
# [WMSE]  Epoch  300 | Train=0.004022 | Val=0.004069
# [WMSE]  Epoch  301 | Train=0.003993 | Val=0.004039
# [WMSE]  Epoch  302 | Train=0.003964 | Val=0.004011
# [WMSE]  Epoch  303 | Train=0.003935 | Val=0.003982
# [WMSE]  Epoch  304 | Train=0.003907 | Val=0.003954
# [WMSE]  Epoch  305 | Train=0.003879 | Val=0.003926
# [WMSE]  Epoch  306 | Train=0.003851 | Val=0.003898
# [WMSE]  Epoch  307 | Train=0.003824 | Val=0.003870
# [WMSE]  Epoch  308 | Train=0.003797 | Val=0.003843
# [WMSE]  Epoch  309 | Train=0.003770 | Val=0.003817
# [WMSE]  Epoch  310 | Train=0.003744 | Val=0.003790
# [WMSE]  Epoch  311 | Train=0.003718 | Val=0.003764
# [WMSE]  Epoch  312 | Train=0.003692 | Val=0.003738
# [WMSE]  Epoch  313 | Train=0.003666 | Val=0.003712
# [WMSE]  Epoch  314 | Train=0.003641 | Val=0.003687
# [WMSE]  Epoch  315 | Train=0.003616 | Val=0.003662
# [WMSE]  Epoch  316 | Train=0.003591 | Val=0.003637
# [WMSE]  Epoch  317 | Train=0.003567 | Val=0.003612
# [WMSE]  Epoch  318 | Train=0.003542 | Val=0.003588
# [WMSE]  Epoch  319 | Train=0.003519 | Val=0.003564
# [WMSE]  Epoch  320 | Train=0.003495 | Val=0.003540
# [WMSE]  Epoch  321 | Train=0.003471 | Val=0.003517
# [WMSE]  Epoch  322 | Train=0.003448 | Val=0.003493
# [WMSE]  Epoch  323 | Train=0.003425 | Val=0.003470
# [WMSE]  Epoch  324 | Train=0.003403 | Val=0.003448
# [WMSE]  Epoch  325 | Train=0.003380 | Val=0.003425
# [WMSE]  Epoch  326 | Train=0.003358 | Val=0.003403
# [WMSE]  Epoch  327 | Train=0.003336 | Val=0.003381
# [WMSE]  Epoch  328 | Train=0.003315 | Val=0.003359
# [WMSE]  Epoch  329 | Train=0.003293 | Val=0.003338
# [WMSE]  Epoch  330 | Train=0.003272 | Val=0.003316
# [WMSE]  Epoch  331 | Train=0.003251 | Val=0.003295
# [WMSE]  Epoch  332 | Train=0.003231 | Val=0.003275
# [WMSE]  Epoch  333 | Train=0.003210 | Val=0.003254
# [WMSE]  Epoch  334 | Train=0.003190 | Val=0.003234
# [WMSE]  Epoch  335 | Train=0.003170 | Val=0.003214
# [WMSE]  Epoch  336 | Train=0.003150 | Val=0.003194
# [WMSE]  Epoch  337 | Train=0.003131 | Val=0.003174
# [WMSE]  Epoch  338 | Train=0.003111 | Val=0.003155
# [WMSE]  Epoch  339 | Train=0.003092 | Val=0.003136
# [WMSE]  Epoch  340 | Train=0.003074 | Val=0.003117
# [WMSE]  Epoch  341 | Train=0.003055 | Val=0.003098
# [WMSE]  Epoch  342 | Train=0.003036 | Val=0.003079
# [WMSE]  Epoch  343 | Train=0.003018 | Val=0.003061
# [WMSE]  Epoch  344 | Train=0.003000 | Val=0.003043
# [WMSE]  Epoch  345 | Train=0.002982 | Val=0.003025
# [WMSE]  Epoch  346 | Train=0.002965 | Val=0.003007
# [WMSE]  Epoch  347 | Train=0.002947 | Val=0.002990
# [WMSE]  Epoch  348 | Train=0.002930 | Val=0.002972
# [WMSE]  Epoch  349 | Train=0.002913 | Val=0.002955
# [WMSE]  Epoch  350 | Train=0.002896 | Val=0.002938
# [WMSE]  Epoch  351 | Train=0.002880 | Val=0.002921
# [WMSE]  Epoch  352 | Train=0.002863 | Val=0.002905
# [WMSE]  Epoch  353 | Train=0.002847 | Val=0.002889
# [WMSE]  Epoch  354 | Train=0.002831 | Val=0.002872
# [WMSE]  Epoch  355 | Train=0.002815 | Val=0.002856
# [WMSE]  Epoch  356 | Train=0.002799 | Val=0.002841
# [WMSE]  Epoch  357 | Train=0.002784 | Val=0.002825
# [WMSE]  Epoch  358 | Train=0.002769 | Val=0.002810
# [WMSE]  Epoch  359 | Train=0.002753 | Val=0.002794
# [WMSE]  Epoch  360 | Train=0.002738 | Val=0.002779
# [WMSE]  Epoch  361 | Train=0.002724 | Val=0.002764
# [WMSE]  Epoch  362 | Train=0.002709 | Val=0.002750
# [WMSE]  Epoch  363 | Train=0.002695 | Val=0.002735
# [WMSE]  Epoch  364 | Train=0.002680 | Val=0.002721
# [WMSE]  Epoch  365 | Train=0.002666 | Val=0.002706
# [WMSE]  Epoch  366 | Train=0.002652 | Val=0.002692
# [WMSE]  Epoch  367 | Train=0.002638 | Val=0.002678
# [WMSE]  Epoch  368 | Train=0.002625 | Val=0.002665
# [WMSE]  Epoch  369 | Train=0.002611 | Val=0.002651
# [WMSE]  Epoch  370 | Train=0.002598 | Val=0.002637
# [WMSE]  Epoch  371 | Train=0.002585 | Val=0.002624
# [WMSE]  Epoch  372 | Train=0.002572 | Val=0.002611
# [WMSE]  Epoch  373 | Train=0.002559 | Val=0.002598
# [WMSE]  Epoch  374 | Train=0.002546 | Val=0.002585
# [WMSE]  Epoch  375 | Train=0.002534 | Val=0.002573
# [WMSE]  Epoch  376 | Train=0.002521 | Val=0.002560
# [WMSE]  Epoch  377 | Train=0.002509 | Val=0.002548
# [WMSE]  Epoch  378 | Train=0.002497 | Val=0.002535
# [WMSE]  Epoch  379 | Train=0.002485 | Val=0.002523
# [WMSE]  Epoch  380 | Train=0.002473 | Val=0.002511
# [WMSE]  Epoch  381 | Train=0.002461 | Val=0.002499
# [WMSE]  Epoch  382 | Train=0.002450 | Val=0.002488
# [WMSE]  Epoch  383 | Train=0.002438 | Val=0.002476
# [WMSE]  Epoch  384 | Train=0.002427 | Val=0.002465
# [WMSE]  Epoch  385 | Train=0.002416 | Val=0.002453
# [WMSE]  Epoch  386 | Train=0.002405 | Val=0.002442
# [WMSE]  Epoch  387 | Train=0.002394 | Val=0.002431
# [WMSE]  Epoch  388 | Train=0.002383 | Val=0.002420
# [WMSE]  Epoch  389 | Train=0.002372 | Val=0.002409
# [WMSE]  Epoch  390 | Train=0.002362 | Val=0.002399
# [WMSE]  Epoch  391 | Train=0.002351 | Val=0.002388
# [WMSE]  Epoch  392 | Train=0.002341 | Val=0.002378
# [WMSE]  Epoch  393 | Train=0.002331 | Val=0.002368
# [WMSE]  Epoch  394 | Train=0.002321 | Val=0.002357
# [WMSE]  Epoch  395 | Train=0.002311 | Val=0.002347
# [WMSE]  Epoch  396 | Train=0.002301 | Val=0.002337
# [WMSE]  Epoch  397 | Train=0.002291 | Val=0.002327
# [WMSE]  Epoch  398 | Train=0.002282 | Val=0.002318
# [WMSE]  Epoch  399 | Train=0.002272 | Val=0.002308
# [WMSE]  Epoch  400 | Train=0.002263 | Val=0.002299
# [WMSE]  Epoch  401 | Train=0.002254 | Val=0.002289
# [WMSE]  Epoch  402 | Train=0.002244 | Val=0.002280
# [WMSE]  Epoch  403 | Train=0.002235 | Val=0.002271
# [WMSE]  Epoch  404 | Train=0.002226 | Val=0.002262
# [WMSE]  Epoch  405 | Train=0.002217 | Val=0.002253
# [WMSE]  Epoch  406 | Train=0.002209 | Val=0.002244
# [WMSE]  Epoch  407 | Train=0.002200 | Val=0.002235
# [WMSE]  Epoch  408 | Train=0.002191 | Val=0.002226
# [WMSE]  Epoch  409 | Train=0.002183 | Val=0.002218
# [WMSE]  Epoch  410 | Train=0.002175 | Val=0.002209
# [WMSE]  Epoch  411 | Train=0.002166 | Val=0.002201
# [WMSE]  Epoch  412 | Train=0.002158 | Val=0.002192
# [WMSE]  Epoch  413 | Train=0.002150 | Val=0.002184
# [WMSE]  Epoch  414 | Train=0.002142 | Val=0.002176
# [WMSE]  Epoch  415 | Train=0.002134 | Val=0.002168
# [WMSE]  Epoch  416 | Train=0.002126 | Val=0.002160
# [WMSE]  Epoch  417 | Train=0.002119 | Val=0.002152
# [WMSE]  Epoch  418 | Train=0.002111 | Val=0.002144
# [WMSE]  Epoch  419 | Train=0.002103 | Val=0.002137
# [WMSE]  Epoch  420 | Train=0.002096 | Val=0.002129
# [WMSE]  Epoch  421 | Train=0.002088 | Val=0.002122
# [WMSE]  Epoch  422 | Train=0.002081 | Val=0.002114
# [WMSE]  Epoch  423 | Train=0.002074 | Val=0.002107
# [WMSE]  Epoch  424 | Train=0.002067 | Val=0.002100
# [WMSE]  Epoch  425 | Train=0.002060 | Val=0.002092
# [WMSE]  Epoch  426 | Train=0.002053 | Val=0.002085
# [WMSE]  Epoch  427 | Train=0.002046 | Val=0.002078
# [WMSE]  Epoch  428 | Train=0.002039 | Val=0.002071
# [WMSE]  Epoch  429 | Train=0.002032 | Val=0.002064
# [WMSE]  Epoch  430 | Train=0.002025 | Val=0.002057
# [WMSE]  Epoch  431 | Train=0.002019 | Val=0.002051
# [WMSE]  Epoch  432 | Train=0.002012 | Val=0.002044
# [WMSE]  Epoch  433 | Train=0.002006 | Val=0.002037
# [WMSE]  Epoch  434 | Train=0.001999 | Val=0.002031
# [WMSE]  Epoch  435 | Train=0.001993 | Val=0.002024
# [WMSE]  Epoch  436 | Train=0.001987 | Val=0.002018
# [WMSE]  Epoch  437 | Train=0.001980 | Val=0.002012
# [WMSE]  Epoch  438 | Train=0.001974 | Val=0.002005
# [WMSE]  Epoch  439 | Train=0.001968 | Val=0.001999
# [WMSE]  Epoch  440 | Train=0.001962 | Val=0.001993
# [WMSE]  Epoch  441 | Train=0.001956 | Val=0.001987
# [WMSE]  Epoch  442 | Train=0.001950 | Val=0.001981
# [WMSE]  Epoch  443 | Train=0.001944 | Val=0.001975
# [WMSE]  Epoch  444 | Train=0.001939 | Val=0.001969
# [WMSE]  Epoch  445 | Train=0.001933 | Val=0.001963
# [WMSE]  Epoch  446 | Train=0.001927 | Val=0.001958
# [WMSE]  Epoch  447 | Train=0.001922 | Val=0.001952
# [WMSE]  Epoch  448 | Train=0.001916 | Val=0.001946
# [WMSE]  Epoch  449 | Train=0.001911 | Val=0.001941
# [WMSE]  Epoch  450 | Train=0.001905 | Val=0.001935
# [WMSE]  Epoch  451 | Train=0.001900 | Val=0.001930
# [WMSE]  Epoch  452 | Train=0.001895 | Val=0.001924
# [WMSE]  Epoch  453 | Train=0.001889 | Val=0.001919
# [WMSE]  Epoch  454 | Train=0.001884 | Val=0.001913
# [WMSE]  Epoch  455 | Train=0.001879 | Val=0.001908
# [WMSE]  Epoch  456 | Train=0.001874 | Val=0.001903
# [WMSE]  Epoch  457 | Train=0.001869 | Val=0.001898
# [WMSE]  Epoch  458 | Train=0.001864 | Val=0.001893
# [WMSE]  Epoch  459 | Train=0.001859 | Val=0.001888
# [WMSE]  Epoch  460 | Train=0.001854 | Val=0.001883
# [WMSE]  Epoch  461 | Train=0.001849 | Val=0.001878
# [WMSE]  Epoch  462 | Train=0.001844 | Val=0.001873
# [WMSE]  Epoch  463 | Train=0.001839 | Val=0.001868
# [WMSE]  Epoch  464 | Train=0.001835 | Val=0.001863
# [WMSE]  Epoch  465 | Train=0.001830 | Val=0.001858
# [WMSE]  Epoch  466 | Train=0.001825 | Val=0.001853
# [WMSE]  Epoch  467 | Train=0.001821 | Val=0.001849
# [WMSE]  Epoch  468 | Train=0.001816 | Val=0.001844
# [WMSE]  Epoch  469 | Train=0.001812 | Val=0.001839
# [WMSE]  Epoch  470 | Train=0.001807 | Val=0.001835
# [WMSE]  Epoch  471 | Train=0.001803 | Val=0.001830
# [WMSE]  Epoch  472 | Train=0.001798 | Val=0.001826
# [WMSE]  Epoch  473 | Train=0.001794 | Val=0.001821
# [WMSE]  Epoch  474 | Train=0.001790 | Val=0.001817
# [WMSE]  Epoch  475 | Train=0.001785 | Val=0.001813
# [WMSE]  Epoch  476 | Train=0.001781 | Val=0.001808
# [WMSE]  Epoch  477 | Train=0.001777 | Val=0.001804
# [WMSE]  Epoch  478 | Train=0.001773 | Val=0.001800
# [WMSE]  Epoch  479 | Train=0.001769 | Val=0.001795
# [WMSE]  Epoch  480 | Train=0.001765 | Val=0.001791
# [WMSE]  Epoch  481 | Train=0.001761 | Val=0.001787
# [WMSE]  Epoch  482 | Train=0.001757 | Val=0.001783
# [WMSE]  Epoch  483 | Train=0.001753 | Val=0.001779
# [WMSE]  Epoch  484 | Train=0.001749 | Val=0.001775
# [WMSE]  Epoch  485 | Train=0.001745 | Val=0.001771
# [WMSE]  Epoch  486 | Train=0.001741 | Val=0.001767
# [WMSE]  Epoch  487 | Train=0.001737 | Val=0.001763
# [WMSE]  Epoch  488 | Train=0.001733 | Val=0.001759
# [WMSE]  Epoch  489 | Train=0.001729 | Val=0.001755
# [WMSE]  Epoch  490 | Train=0.001726 | Val=0.001751
# [WMSE]  Epoch  491 | Train=0.001722 | Val=0.001747
# [WMSE]  Epoch  492 | Train=0.001718 | Val=0.001744
# [WMSE]  Epoch  493 | Train=0.001715 | Val=0.001740
# [WMSE]  Epoch  494 | Train=0.001711 | Val=0.001736
# [WMSE]  Epoch  495 | Train=0.001707 | Val=0.001732
# [WMSE]  Epoch  496 | Train=0.001704 | Val=0.001729
# [WMSE]  Epoch  497 | Train=0.001700 | Val=0.001725
# [WMSE]  Epoch  498 | Train=0.001697 | Val=0.001721
# [WMSE]  Epoch  499 | Train=0.001693 | Val=0.001718
# [WMSE]  Epoch  500 | Train=0.001690 | Val=0.001714
# [WMSE]  Epoch  501 | Train=0.001686 | Val=0.001711
# [WMSE]  Epoch  502 | Train=0.001683 | Val=0.001707
# [WMSE]  Epoch  503 | Train=0.001679 | Val=0.001704
# [WMSE]  Epoch  504 | Train=0.001676 | Val=0.001700
# [WMSE]  Epoch  505 | Train=0.001673 | Val=0.001697
# [WMSE]  Epoch  506 | Train=0.001669 | Val=0.001694
# [WMSE]  Epoch  507 | Train=0.001666 | Val=0.001690
# [WMSE]  Epoch  508 | Train=0.001663 | Val=0.001687
# [WMSE]  Epoch  509 | Train=0.001660 | Val=0.001683
# [WMSE]  Epoch  510 | Train=0.001656 | Val=0.001680
# [WMSE]  Epoch  511 | Train=0.001653 | Val=0.001677
# [WMSE]  Epoch  512 | Train=0.001650 | Val=0.001674
# [WMSE]  Epoch  513 | Train=0.001647 | Val=0.001670
# [WMSE]  Epoch  514 | Train=0.001644 | Val=0.001667
# [WMSE]  Epoch  515 | Train=0.001641 | Val=0.001664
# [WMSE]  Epoch  516 | Train=0.001637 | Val=0.001661
# [WMSE]  Epoch  517 | Train=0.001634 | Val=0.001658
# [WMSE]  Epoch  518 | Train=0.001631 | Val=0.001654
# [WMSE]  Epoch  519 | Train=0.001628 | Val=0.001651
# [WMSE]  Epoch  520 | Train=0.001625 | Val=0.001648
# [WMSE]  Epoch  521 | Train=0.001622 | Val=0.001645
# [WMSE]  Epoch  522 | Train=0.001619 | Val=0.001642
# [WMSE]  Epoch  523 | Train=0.001616 | Val=0.001639
# [WMSE]  Epoch  524 | Train=0.001613 | Val=0.001636
# [WMSE]  Epoch  525 | Train=0.001611 | Val=0.001633
# [WMSE]  Epoch  526 | Train=0.001608 | Val=0.001630
# [WMSE]  Epoch  527 | Train=0.001605 | Val=0.001627
# [WMSE]  Epoch  528 | Train=0.001602 | Val=0.001624
# [WMSE]  Epoch  529 | Train=0.001599 | Val=0.001621
# [WMSE]  Epoch  530 | Train=0.001596 | Val=0.001618
# [WMSE]  Epoch  531 | Train=0.001593 | Val=0.001616
# [WMSE]  Epoch  532 | Train=0.001591 | Val=0.001613
# [WMSE]  Epoch  533 | Train=0.001588 | Val=0.001610
# [WMSE]  Epoch  534 | Train=0.001585 | Val=0.001607
# [WMSE]  Epoch  535 | Train=0.001582 | Val=0.001604
# [WMSE]  Epoch  536 | Train=0.001580 | Val=0.001601
# [WMSE]  Epoch  537 | Train=0.001577 | Val=0.001599
# [WMSE]  Epoch  538 | Train=0.001574 | Val=0.001596
# [WMSE]  Epoch  539 | Train=0.001572 | Val=0.001593
# [WMSE]  Epoch  540 | Train=0.001569 | Val=0.001590
# [WMSE]  Epoch  541 | Train=0.001566 | Val=0.001588
# [WMSE]  Epoch  542 | Train=0.001564 | Val=0.001585
# [WMSE]  Epoch  543 | Train=0.001561 | Val=0.001582
# [WMSE]  Epoch  544 | Train=0.001558 | Val=0.001580
# [WMSE]  Epoch  545 | Train=0.001556 | Val=0.001577
# [WMSE]  Epoch  546 | Train=0.001553 | Val=0.001574
# [WMSE]  Epoch  547 | Train=0.001551 | Val=0.001572
# [WMSE]  Epoch  548 | Train=0.001548 | Val=0.001569
# [WMSE]  Epoch  549 | Train=0.001545 | Val=0.001566
# [WMSE]  Epoch  550 | Train=0.001543 | Val=0.001564
# [WMSE]  Epoch  551 | Train=0.001540 | Val=0.001561
# [WMSE]  Epoch  552 | Train=0.001538 | Val=0.001559
# [WMSE]  Epoch  553 | Train=0.001535 | Val=0.001556
# [WMSE]  Epoch  554 | Train=0.001533 | Val=0.001554
# [WMSE]  Epoch  555 | Train=0.001530 | Val=0.001551
# [WMSE]  Epoch  556 | Train=0.001528 | Val=0.001548
# [WMSE]  Epoch  557 | Train=0.001526 | Val=0.001546
# [WMSE]  Epoch  558 | Train=0.001523 | Val=0.001543
# [WMSE]  Epoch  559 | Train=0.001521 | Val=0.001541
# [WMSE]  Epoch  560 | Train=0.001518 | Val=0.001539
# [WMSE]  Epoch  561 | Train=0.001516 | Val=0.001536
# [WMSE]  Epoch  562 | Train=0.001514 | Val=0.001534
# [WMSE]  Epoch  563 | Train=0.001511 | Val=0.001531
# [WMSE]  Epoch  564 | Train=0.001509 | Val=0.001529
# [WMSE]  Epoch  565 | Train=0.001506 | Val=0.001526
# [WMSE]  Epoch  566 | Train=0.001504 | Val=0.001524
# [WMSE]  Epoch  567 | Train=0.001502 | Val=0.001522
# [WMSE]  Epoch  568 | Train=0.001499 | Val=0.001519
# [WMSE]  Epoch  569 | Train=0.001497 | Val=0.001517
# [WMSE]  Epoch  570 | Train=0.001495 | Val=0.001514
# [WMSE]  Epoch  571 | Train=0.001493 | Val=0.001512
# [WMSE]  Epoch  572 | Train=0.001490 | Val=0.001510
# [WMSE]  Epoch  573 | Train=0.001488 | Val=0.001507
# [WMSE]  Epoch  574 | Train=0.001486 | Val=0.001505
# [WMSE]  Epoch  575 | Train=0.001483 | Val=0.001503
# [WMSE]  Epoch  576 | Train=0.001481 | Val=0.001500
# [WMSE]  Epoch  577 | Train=0.001479 | Val=0.001498
# [WMSE]  Epoch  578 | Train=0.001477 | Val=0.001496
# [WMSE]  Epoch  579 | Train=0.001475 | Val=0.001494
# [WMSE]  Epoch  580 | Train=0.001472 | Val=0.001491
# [WMSE]  Epoch  581 | Train=0.001470 | Val=0.001489
# [WMSE]  Epoch  582 | Train=0.001468 | Val=0.001487
# [WMSE]  Epoch  583 | Train=0.001466 | Val=0.001485
# [WMSE]  Epoch  584 | Train=0.001464 | Val=0.001482
# [WMSE]  Epoch  585 | Train=0.001461 | Val=0.001480
# [WMSE]  Epoch  586 | Train=0.001459 | Val=0.001478
# [WMSE]  Epoch  587 | Train=0.001457 | Val=0.001476
# [WMSE]  Epoch  588 | Train=0.001455 | Val=0.001474
# [WMSE]  Epoch  589 | Train=0.001453 | Val=0.001471
# [WMSE]  Epoch  590 | Train=0.001451 | Val=0.001469
# [WMSE]  Epoch  591 | Train=0.001449 | Val=0.001467
# [WMSE]  Epoch  592 | Train=0.001446 | Val=0.001465
# [WMSE]  Epoch  593 | Train=0.001444 | Val=0.001463
# [WMSE]  Epoch  594 | Train=0.001442 | Val=0.001461
# [WMSE]  Epoch  595 | Train=0.001440 | Val=0.001458
# [WMSE]  Epoch  596 | Train=0.001438 | Val=0.001456
# [WMSE]  Epoch  597 | Train=0.001436 | Val=0.001454
# [WMSE]  Epoch  598 | Train=0.001434 | Val=0.001452
# [WMSE]  Epoch  599 | Train=0.001432 | Val=0.001450
# [WMSE]  Epoch  600 | Train=0.001430 | Val=0.001448
# [WMSE]  Epoch  601 | Train=0.001428 | Val=0.001446
# [WMSE]  Epoch  602 | Train=0.001426 | Val=0.001444
# [WMSE]  Epoch  603 | Train=0.001424 | Val=0.001442
# [WMSE]  Epoch  604 | Train=0.001422 | Val=0.001440
# [WMSE]  Epoch  605 | Train=0.001420 | Val=0.001437
# [WMSE]  Epoch  606 | Train=0.001418 | Val=0.001435
# [WMSE]  Epoch  607 | Train=0.001416 | Val=0.001433
# [WMSE]  Epoch  608 | Train=0.001414 | Val=0.001431
# [WMSE]  Epoch  609 | Train=0.001412 | Val=0.001429
# [WMSE]  Epoch  610 | Train=0.001410 | Val=0.001427
# [WMSE]  Epoch  611 | Train=0.001408 | Val=0.001425
# [WMSE]  Epoch  612 | Train=0.001406 | Val=0.001423
# [WMSE]  Epoch  613 | Train=0.001404 | Val=0.001421
# [WMSE]  Epoch  614 | Train=0.001402 | Val=0.001419
# [WMSE]  Epoch  615 | Train=0.001400 | Val=0.001417
# [WMSE]  Epoch  616 | Train=0.001398 | Val=0.001415
# [WMSE]  Epoch  617 | Train=0.001396 | Val=0.001413
# [WMSE]  Epoch  618 | Train=0.001394 | Val=0.001411
# [WMSE]  Epoch  619 | Train=0.001392 | Val=0.001409
# [WMSE]  Epoch  620 | Train=0.001390 | Val=0.001407
# [WMSE]  Epoch  621 | Train=0.001388 | Val=0.001405
# [WMSE]  Epoch  622 | Train=0.001386 | Val=0.001403
# [WMSE]  Epoch  623 | Train=0.001384 | Val=0.001401
# [WMSE]  Epoch  624 | Train=0.001382 | Val=0.001400
# [WMSE]  Epoch  625 | Train=0.001381 | Val=0.001398
# [WMSE]  Epoch  626 | Train=0.001379 | Val=0.001396
# [WMSE]  Epoch  627 | Train=0.001377 | Val=0.001394
# [WMSE]  Epoch  628 | Train=0.001375 | Val=0.001392
# [WMSE]  Epoch  629 | Train=0.001373 | Val=0.001390
# [WMSE]  Epoch  630 | Train=0.001371 | Val=0.001388
# [WMSE]  Epoch  631 | Train=0.001369 | Val=0.001386
# [WMSE]  Epoch  632 | Train=0.001367 | Val=0.001384
# [WMSE]  Epoch  633 | Train=0.001366 | Val=0.001382
# [WMSE]  Epoch  634 | Train=0.001364 | Val=0.001380
# [WMSE]  Epoch  635 | Train=0.001362 | Val=0.001379
# [WMSE]  Epoch  636 | Train=0.001360 | Val=0.001377
# [WMSE]  Epoch  637 | Train=0.001358 | Val=0.001375
# [WMSE]  Epoch  638 | Train=0.001356 | Val=0.001373
# [WMSE]  Epoch  639 | Train=0.001355 | Val=0.001371
# [WMSE]  Epoch  640 | Train=0.001353 | Val=0.001369
# [WMSE]  Epoch  641 | Train=0.001351 | Val=0.001367
# [WMSE]  Epoch  642 | Train=0.001349 | Val=0.001366
# [WMSE]  Epoch  643 | Train=0.001347 | Val=0.001364
# [WMSE]  Epoch  644 | Train=0.001346 | Val=0.001362
# [WMSE]  Epoch  645 | Train=0.001344 | Val=0.001360
# [WMSE]  Epoch  646 | Train=0.001342 | Val=0.001358
# [WMSE]  Epoch  647 | Train=0.001340 | Val=0.001356
# [WMSE]  Epoch  648 | Train=0.001338 | Val=0.001355
# [WMSE]  Epoch  649 | Train=0.001337 | Val=0.001353
# [WMSE]  Epoch  650 | Train=0.001335 | Val=0.001351
# [WMSE]  Epoch  651 | Train=0.001333 | Val=0.001349
# [WMSE]  Epoch  652 | Train=0.001331 | Val=0.001347
# [WMSE]  Epoch  653 | Train=0.001330 | Val=0.001346
# [WMSE]  Epoch  654 | Train=0.001328 | Val=0.001344
# [WMSE]  Epoch  655 | Train=0.001326 | Val=0.001342
# [WMSE]  Epoch  656 | Train=0.001324 | Val=0.001340
# [WMSE]  Epoch  657 | Train=0.001323 | Val=0.001339
# [WMSE]  Epoch  658 | Train=0.001321 | Val=0.001337
# [WMSE]  Epoch  659 | Train=0.001319 | Val=0.001335
# [WMSE]  Epoch  660 | Train=0.001317 | Val=0.001333
# [WMSE]  Epoch  661 | Train=0.001316 | Val=0.001332
# [WMSE]  Epoch  662 | Train=0.001314 | Val=0.001330
# [WMSE]  Epoch  663 | Train=0.001312 | Val=0.001328
# [WMSE]  Epoch  664 | Train=0.001311 | Val=0.001326
# [WMSE]  Epoch  665 | Train=0.001309 | Val=0.001325
# [WMSE]  Epoch  666 | Train=0.001307 | Val=0.001323
# [WMSE]  Epoch  667 | Train=0.001306 | Val=0.001321
# [WMSE]  Epoch  668 | Train=0.001304 | Val=0.001319
# [WMSE]  Epoch  669 | Train=0.001302 | Val=0.001318
# [WMSE]  Epoch  670 | Train=0.001301 | Val=0.001316
# [WMSE]  Epoch  671 | Train=0.001299 | Val=0.001314
# [WMSE]  Epoch  672 | Train=0.001297 | Val=0.001313
# [WMSE]  Epoch  673 | Train=0.001296 | Val=0.001311
# [WMSE]  Epoch  674 | Train=0.001294 | Val=0.001309
# [WMSE]  Epoch  675 | Train=0.001292 | Val=0.001308
# [WMSE]  Epoch  676 | Train=0.001291 | Val=0.001306
# [WMSE]  Epoch  677 | Train=0.001289 | Val=0.001304
# [WMSE]  Epoch  678 | Train=0.001287 | Val=0.001303
# [WMSE]  Epoch  679 | Train=0.001286 | Val=0.001301
# [WMSE]  Epoch  680 | Train=0.001284 | Val=0.001299
# [WMSE]  Epoch  681 | Train=0.001282 | Val=0.001298
# [WMSE]  Epoch  682 | Train=0.001281 | Val=0.001296
# [WMSE]  Epoch  683 | Train=0.001279 | Val=0.001294
# [WMSE]  Epoch  684 | Train=0.001278 | Val=0.001293
# [WMSE]  Epoch  685 | Train=0.001276 | Val=0.001291
# [WMSE]  Epoch  686 | Train=0.001274 | Val=0.001289
# [WMSE]  Epoch  687 | Train=0.001273 | Val=0.001288
# [WMSE]  Epoch  688 | Train=0.001271 | Val=0.001286
# [WMSE]  Epoch  689 | Train=0.001270 | Val=0.001285
# [WMSE]  Epoch  690 | Train=0.001268 | Val=0.001283
# [WMSE]  Epoch  691 | Train=0.001266 | Val=0.001281
# [WMSE]  Epoch  692 | Train=0.001265 | Val=0.001280
# [WMSE]  Epoch  693 | Train=0.001263 | Val=0.001278
# [WMSE]  Epoch  694 | Train=0.001262 | Val=0.001277
# [WMSE]  Epoch  695 | Train=0.001260 | Val=0.001275
# [WMSE]  Epoch  696 | Train=0.001258 | Val=0.001273
# [WMSE]  Epoch  697 | Train=0.001257 | Val=0.001272
# [WMSE]  Epoch  698 | Train=0.001255 | Val=0.001270
# [WMSE]  Epoch  699 | Train=0.001254 | Val=0.001269
# [WMSE]  Epoch  700 | Train=0.001252 | Val=0.001267
# [WMSE]  Epoch  701 | Train=0.001251 | Val=0.001265
# [WMSE]  Epoch  702 | Train=0.001249 | Val=0.001264
# [WMSE]  Epoch  703 | Train=0.001248 | Val=0.001262
# [WMSE]  Epoch  704 | Train=0.001246 | Val=0.001261
# [WMSE]  Epoch  705 | Train=0.001245 | Val=0.001259
# [WMSE]  Epoch  706 | Train=0.001243 | Val=0.001258
# [WMSE]  Epoch  707 | Train=0.001242 | Val=0.001256
# [WMSE]  Epoch  708 | Train=0.001240 | Val=0.001255
# [WMSE]  Epoch  709 | Train=0.001239 | Val=0.001253
# [WMSE]  Epoch  710 | Train=0.001237 | Val=0.001252
# [WMSE]  Epoch  711 | Train=0.001236 | Val=0.001250
# [WMSE]  Epoch  712 | Train=0.001234 | Val=0.001249
# [WMSE]  Epoch  713 | Train=0.001233 | Val=0.001247
# [WMSE]  Epoch  714 | Train=0.001231 | Val=0.001246
# [WMSE]  Epoch  715 | Train=0.001230 | Val=0.001244
# [WMSE]  Epoch  716 | Train=0.001228 | Val=0.001243
# [WMSE]  Epoch  717 | Train=0.001227 | Val=0.001241
# [WMSE]  Epoch  718 | Train=0.001225 | Val=0.001240
# [WMSE]  Epoch  719 | Train=0.001224 | Val=0.001238
# [WMSE]  Epoch  720 | Train=0.001222 | Val=0.001237
# [WMSE]  Epoch  721 | Train=0.001221 | Val=0.001235
# [WMSE]  Epoch  722 | Train=0.001219 | Val=0.001234
# [WMSE]  Epoch  723 | Train=0.001218 | Val=0.001232
# [WMSE]  Epoch  724 | Train=0.001216 | Val=0.001231
# [WMSE]  Epoch  725 | Train=0.001215 | Val=0.001229
# [WMSE]  Epoch  726 | Train=0.001213 | Val=0.001228
# [WMSE]  Epoch  727 | Train=0.001212 | Val=0.001226
# [WMSE]  Epoch  728 | Train=0.001211 | Val=0.001225
# [WMSE]  Epoch  729 | Train=0.001209 | Val=0.001223
# [WMSE]  Epoch  730 | Train=0.001208 | Val=0.001222
# [WMSE]  Epoch  731 | Train=0.001206 | Val=0.001220
# [WMSE]  Epoch  732 | Train=0.001205 | Val=0.001219
# [WMSE]  Epoch  733 | Train=0.001204 | Val=0.001218
# [WMSE]  Epoch  734 | Train=0.001202 | Val=0.001216
# [WMSE]  Epoch  735 | Train=0.001201 | Val=0.001215
# [WMSE]  Epoch  736 | Train=0.001199 | Val=0.001213
# [WMSE]  Epoch  737 | Train=0.001198 | Val=0.001212
# [WMSE]  Epoch  738 | Train=0.001197 | Val=0.001211
# [WMSE]  Epoch  739 | Train=0.001195 | Val=0.001209
# [WMSE]  Epoch  740 | Train=0.001194 | Val=0.001208
# [WMSE]  Epoch  741 | Train=0.001192 | Val=0.001206
# [WMSE]  Epoch  742 | Train=0.001191 | Val=0.001205
# [WMSE]  Epoch  743 | Train=0.001190 | Val=0.001204
# [WMSE]  Epoch  744 | Train=0.001188 | Val=0.001202
# [WMSE]  Epoch  745 | Train=0.001187 | Val=0.001201
# [WMSE]  Epoch  746 | Train=0.001186 | Val=0.001199
# [WMSE]  Epoch  747 | Train=0.001184 | Val=0.001198
# [WMSE]  Epoch  748 | Train=0.001183 | Val=0.001197
# [WMSE]  Epoch  749 | Train=0.001181 | Val=0.001195
# [WMSE]  Epoch  750 | Train=0.001180 | Val=0.001194
# [WMSE]  Epoch  751 | Train=0.001179 | Val=0.001193
# [WMSE]  Epoch  752 | Train=0.001177 | Val=0.001191
# [WMSE]  Epoch  753 | Train=0.001176 | Val=0.001190
# [WMSE]  Epoch  754 | Train=0.001175 | Val=0.001188
# [WMSE]  Epoch  755 | Train=0.001173 | Val=0.001187
# [WMSE]  Epoch  756 | Train=0.001172 | Val=0.001186
# [WMSE]  Epoch  757 | Train=0.001171 | Val=0.001184
# [WMSE]  Epoch  758 | Train=0.001169 | Val=0.001183
# [WMSE]  Epoch  759 | Train=0.001168 | Val=0.001182
# [WMSE]  Epoch  760 | Train=0.001167 | Val=0.001180
# [WMSE]  Epoch  761 | Train=0.001165 | Val=0.001179
# [WMSE]  Epoch  762 | Train=0.001164 | Val=0.001178
# [WMSE]  Epoch  763 | Train=0.001163 | Val=0.001176
# [WMSE]  Epoch  764 | Train=0.001162 | Val=0.001175
# [WMSE]  Epoch  765 | Train=0.001160 | Val=0.001174
# [WMSE]  Epoch  766 | Train=0.001159 | Val=0.001172
# [WMSE]  Epoch  767 | Train=0.001158 | Val=0.001171
# [WMSE]  Epoch  768 | Train=0.001156 | Val=0.001170
# [WMSE]  Epoch  769 | Train=0.001155 | Val=0.001168
# [WMSE]  Epoch  770 | Train=0.001154 | Val=0.001167
# [WMSE]  Epoch  771 | Train=0.001152 | Val=0.001166
# [WMSE]  Epoch  772 | Train=0.001151 | Val=0.001165
# [WMSE]  Epoch  773 | Train=0.001150 | Val=0.001163
# [WMSE]  Epoch  774 | Train=0.001149 | Val=0.001162
# [WMSE]  Epoch  775 | Train=0.001147 | Val=0.001161
# [WMSE]  Epoch  776 | Train=0.001146 | Val=0.001159
# [WMSE]  Epoch  777 | Train=0.001145 | Val=0.001158
# [WMSE]  Epoch  778 | Train=0.001143 | Val=0.001157
# [WMSE]  Epoch  779 | Train=0.001142 | Val=0.001155
# [WMSE]  Epoch  780 | Train=0.001141 | Val=0.001154
# [WMSE]  Epoch  781 | Train=0.001140 | Val=0.001153
# [WMSE]  Epoch  782 | Train=0.001138 | Val=0.001152
# [WMSE]  Epoch  783 | Train=0.001137 | Val=0.001150
# [WMSE]  Epoch  784 | Train=0.001136 | Val=0.001149
# [WMSE]  Epoch  785 | Train=0.001134 | Val=0.001148
# [WMSE]  Epoch  786 | Train=0.001133 | Val=0.001146
# [WMSE]  Epoch  787 | Train=0.001132 | Val=0.001145
# [WMSE]  Epoch  788 | Train=0.001131 | Val=0.001144
# [WMSE]  Epoch  789 | Train=0.001129 | Val=0.001142
# [WMSE]  Epoch  790 | Train=0.001128 | Val=0.001141
# [WMSE]  Epoch  791 | Train=0.001127 | Val=0.001140
# [WMSE]  Epoch  792 | Train=0.001126 | Val=0.001139
# [WMSE]  Epoch  793 | Train=0.001124 | Val=0.001137
# [WMSE]  Epoch  794 | Train=0.001123 | Val=0.001136
# [WMSE]  Epoch  795 | Train=0.001122 | Val=0.001135
# [WMSE]  Epoch  796 | Train=0.001120 | Val=0.001133
# [WMSE]  Epoch  797 | Train=0.001119 | Val=0.001132
# [WMSE]  Epoch  798 | Train=0.001118 | Val=0.001131
# [WMSE]  Epoch  799 | Train=0.001117 | Val=0.001130
# [WMSE]  Epoch  800 | Train=0.001115 | Val=0.001128
# [WMSE]  Epoch  801 | Train=0.001114 | Val=0.001127
# [WMSE]  Epoch  802 | Train=0.001113 | Val=0.001126
# [WMSE]  Epoch  803 | Train=0.001111 | Val=0.001124
# [WMSE]  Epoch  804 | Train=0.001110 | Val=0.001123
# [WMSE]  Epoch  805 | Train=0.001109 | Val=0.001122
# [WMSE]  Epoch  806 | Train=0.001107 | Val=0.001120
# [WMSE]  Epoch  807 | Train=0.001106 | Val=0.001119
# [WMSE]  Epoch  808 | Train=0.001105 | Val=0.001118
# [WMSE]  Epoch  809 | Train=0.001104 | Val=0.001116
# [WMSE]  Epoch  810 | Train=0.001102 | Val=0.001115
# [WMSE]  Epoch  811 | Train=0.001101 | Val=0.001114
# [WMSE]  Epoch  812 | Train=0.001100 | Val=0.001112
# [WMSE]  Epoch  813 | Train=0.001098 | Val=0.001111
# [WMSE]  Epoch  814 | Train=0.001097 | Val=0.001110
# [WMSE]  Epoch  815 | Train=0.001096 | Val=0.001108
# [WMSE]  Epoch  816 | Train=0.001094 | Val=0.001107
# [WMSE]  Epoch  817 | Train=0.001093 | Val=0.001106
# [WMSE]  Epoch  818 | Train=0.001092 | Val=0.001104
# [WMSE]  Epoch  819 | Train=0.001090 | Val=0.001103
# [WMSE]  Epoch  820 | Train=0.001089 | Val=0.001102
# [WMSE]  Epoch  821 | Train=0.001088 | Val=0.001100
# [WMSE]  Epoch  822 | Train=0.001086 | Val=0.001099
# [WMSE]  Epoch  823 | Train=0.001085 | Val=0.001098
# [WMSE]  Epoch  824 | Train=0.001084 | Val=0.001096
# [WMSE]  Epoch  825 | Train=0.001082 | Val=0.001095
# [WMSE]  Epoch  826 | Train=0.001081 | Val=0.001094
# [WMSE]  Epoch  827 | Train=0.001080 | Val=0.001092
# [WMSE]  Epoch  828 | Train=0.001079 | Val=0.001091
# [WMSE]  Epoch  829 | Train=0.001077 | Val=0.001090
# [WMSE]  Epoch  830 | Train=0.001076 | Val=0.001089
# [WMSE]  Epoch  831 | Train=0.001075 | Val=0.001087
# [WMSE]  Epoch  832 | Train=0.001073 | Val=0.001086
# [WMSE]  Epoch  833 | Train=0.001072 | Val=0.001085
# [WMSE]  Epoch  834 | Train=0.001071 | Val=0.001083
# [WMSE]  Epoch  835 | Train=0.001070 | Val=0.001082
# [WMSE]  Epoch  836 | Train=0.001068 | Val=0.001081
# [WMSE]  Epoch  837 | Train=0.001067 | Val=0.001080
# [WMSE]  Epoch  838 | Train=0.001066 | Val=0.001078
# [WMSE]  Epoch  839 | Train=0.001065 | Val=0.001077
# [WMSE]  Epoch  840 | Train=0.001063 | Val=0.001076
# [WMSE]  Epoch  841 | Train=0.001062 | Val=0.001075
# [WMSE]  Epoch  842 | Train=0.001061 | Val=0.001074
# [WMSE]  Epoch  843 | Train=0.001060 | Val=0.001072
# [WMSE]  Epoch  844 | Train=0.001059 | Val=0.001071
# [WMSE]  Epoch  845 | Train=0.001057 | Val=0.001070
# [WMSE]  Epoch  846 | Train=0.001056 | Val=0.001069
# [WMSE]  Epoch  847 | Train=0.001055 | Val=0.001068
# [WMSE]  Epoch  848 | Train=0.001054 | Val=0.001066
# [WMSE]  Epoch  849 | Train=0.001053 | Val=0.001065
# [WMSE]  Epoch  850 | Train=0.001052 | Val=0.001064
# [WMSE]  Epoch  851 | Train=0.001050 | Val=0.001063
# [WMSE]  Epoch  852 | Train=0.001049 | Val=0.001062
# [WMSE]  Epoch  853 | Train=0.001048 | Val=0.001061
# [WMSE]  Epoch  854 | Train=0.001047 | Val=0.001059
# [WMSE]  Epoch  855 | Train=0.001046 | Val=0.001058
# [WMSE]  Epoch  856 | Train=0.001045 | Val=0.001057
# [WMSE]  Epoch  857 | Train=0.001044 | Val=0.001056
# [WMSE]  Epoch  858 | Train=0.001042 | Val=0.001055
# [WMSE]  Epoch  859 | Train=0.001041 | Val=0.001054
# [WMSE]  Epoch  860 | Train=0.001040 | Val=0.001052
# [WMSE]  Epoch  861 | Train=0.001039 | Val=0.001051
# [WMSE]  Epoch  862 | Train=0.001038 | Val=0.001050
# [WMSE]  Epoch  863 | Train=0.001037 | Val=0.001049
# [WMSE]  Epoch  864 | Train=0.001036 | Val=0.001048
# [WMSE]  Epoch  865 | Train=0.001034 | Val=0.001047
# [WMSE]  Epoch  866 | Train=0.001033 | Val=0.001046
# [WMSE]  Epoch  867 | Train=0.001032 | Val=0.001044
# [WMSE]  Epoch  868 | Train=0.001031 | Val=0.001043
# [WMSE]  Epoch  869 | Train=0.001030 | Val=0.001042
# [WMSE]  Epoch  870 | Train=0.001029 | Val=0.001041
# [WMSE]  Epoch  871 | Train=0.001028 | Val=0.001040
# [WMSE]  Epoch  872 | Train=0.001027 | Val=0.001039
# [WMSE]  Epoch  873 | Train=0.001025 | Val=0.001037
# [WMSE]  Epoch  874 | Train=0.001024 | Val=0.001036
# [WMSE]  Epoch  875 | Train=0.001023 | Val=0.001035
# [WMSE]  Epoch  876 | Train=0.001022 | Val=0.001034
# [WMSE]  Epoch  877 | Train=0.001021 | Val=0.001033
# [WMSE]  Epoch  878 | Train=0.001020 | Val=0.001032
# [WMSE]  Epoch  879 | Train=0.001019 | Val=0.001031
# [WMSE]  Epoch  880 | Train=0.001018 | Val=0.001029
# [WMSE]  Epoch  881 | Train=0.001016 | Val=0.001028
# [WMSE]  Epoch  882 | Train=0.001015 | Val=0.001027
# [WMSE]  Epoch  883 | Train=0.001014 | Val=0.001026
# [WMSE]  Epoch  884 | Train=0.001013 | Val=0.001025
# [WMSE]  Epoch  885 | Train=0.001012 | Val=0.001024
# [WMSE]  Epoch  886 | Train=0.001011 | Val=0.001023
# [WMSE]  Epoch  887 | Train=0.001010 | Val=0.001021
# [WMSE]  Epoch  888 | Train=0.001009 | Val=0.001020
# [WMSE]  Epoch  889 | Train=0.001007 | Val=0.001019
# [WMSE]  Epoch  890 | Train=0.001006 | Val=0.001018
# [WMSE]  Epoch  891 | Train=0.001005 | Val=0.001017
# [WMSE]  Epoch  892 | Train=0.001004 | Val=0.001016
# [WMSE]  Epoch  893 | Train=0.001003 | Val=0.001015
# [WMSE]  Epoch  894 | Train=0.001002 | Val=0.001013
# [WMSE]  Epoch  895 | Train=0.001001 | Val=0.001012
# [WMSE]  Epoch  896 | Train=0.001000 | Val=0.001011
# [WMSE]  Epoch  897 | Train=0.000998 | Val=0.001010
# [WMSE]  Epoch  898 | Train=0.000997 | Val=0.001009
# [WMSE]  Epoch  899 | Train=0.000996 | Val=0.001008
# [WMSE]  Epoch  900 | Train=0.000995 | Val=0.001007
# [WMSE]  Epoch  901 | Train=0.000994 | Val=0.001005
# [WMSE]  Epoch  902 | Train=0.000993 | Val=0.001004
# [WMSE]  Epoch  903 | Train=0.000992 | Val=0.001003
# [WMSE]  Epoch  904 | Train=0.000991 | Val=0.001002
# [WMSE]  Epoch  905 | Train=0.000990 | Val=0.001001
# [WMSE]  Epoch  906 | Train=0.000988 | Val=0.001000
# [WMSE]  Epoch  907 | Train=0.000987 | Val=0.000999
# [WMSE]  Epoch  908 | Train=0.000986 | Val=0.000997
# [WMSE]  Epoch  909 | Train=0.000985 | Val=0.000996
# [WMSE]  Epoch  910 | Train=0.000984 | Val=0.000995
# [WMSE]  Epoch  911 | Train=0.000983 | Val=0.000994
# [WMSE]  Epoch  912 | Train=0.000982 | Val=0.000993
# [WMSE]  Epoch  913 | Train=0.000981 | Val=0.000992
# [WMSE]  Epoch  914 | Train=0.000979 | Val=0.000991
# [WMSE]  Epoch  915 | Train=0.000978 | Val=0.000990
# [WMSE]  Epoch  916 | Train=0.000977 | Val=0.000988
# [WMSE]  Epoch  917 | Train=0.000976 | Val=0.000987
# [WMSE]  Epoch  918 | Train=0.000975 | Val=0.000986
# [WMSE]  Epoch  919 | Train=0.000974 | Val=0.000985
# [WMSE]  Epoch  920 | Train=0.000973 | Val=0.000984
# [WMSE]  Epoch  921 | Train=0.000972 | Val=0.000983
# [WMSE]  Epoch  922 | Train=0.000970 | Val=0.000981
# [WMSE]  Epoch  923 | Train=0.000969 | Val=0.000980
# [WMSE]  Epoch  924 | Train=0.000968 | Val=0.000979
# [WMSE]  Epoch  925 | Train=0.000967 | Val=0.000978
# [WMSE]  Epoch  926 | Train=0.000966 | Val=0.000977
# [WMSE]  Epoch  927 | Train=0.000965 | Val=0.000976
# [WMSE]  Epoch  928 | Train=0.000964 | Val=0.000975
# [WMSE]  Epoch  929 | Train=0.000963 | Val=0.000973
# [WMSE]  Epoch  930 | Train=0.000961 | Val=0.000972
# [WMSE]  Epoch  931 | Train=0.000960 | Val=0.000971
# [WMSE]  Epoch  932 | Train=0.000959 | Val=0.000970
# [WMSE]  Epoch  933 | Train=0.000958 | Val=0.000969
# [WMSE]  Epoch  934 | Train=0.000957 | Val=0.000968
# [WMSE]  Epoch  935 | Train=0.000956 | Val=0.000967
# [WMSE]  Epoch  936 | Train=0.000955 | Val=0.000965
# [WMSE]  Epoch  937 | Train=0.000953 | Val=0.000964
# [WMSE]  Epoch  938 | Train=0.000952 | Val=0.000963
# [WMSE]  Epoch  939 | Train=0.000951 | Val=0.000962
# [WMSE]  Epoch  940 | Train=0.000950 | Val=0.000961
# [WMSE]  Epoch  941 | Train=0.000949 | Val=0.000960
# [WMSE]  Epoch  942 | Train=0.000948 | Val=0.000958
# [WMSE]  Epoch  943 | Train=0.000947 | Val=0.000957
# [WMSE]  Epoch  944 | Train=0.000945 | Val=0.000956
# [WMSE]  Epoch  945 | Train=0.000944 | Val=0.000955
# [WMSE]  Epoch  946 | Train=0.000943 | Val=0.000954
# [WMSE]  Epoch  947 | Train=0.000942 | Val=0.000953
# [WMSE]  Epoch  948 | Train=0.000941 | Val=0.000951
# [WMSE]  Epoch  949 | Train=0.000940 | Val=0.000950
# [WMSE]  Epoch  950 | Train=0.000939 | Val=0.000949
# [WMSE]  Epoch  951 | Train=0.000937 | Val=0.000948
# [WMSE]  Epoch  952 | Train=0.000936 | Val=0.000947
# [WMSE]  Epoch  953 | Train=0.000935 | Val=0.000946
# [WMSE]  Epoch  954 | Train=0.000934 | Val=0.000944
# [WMSE]  Epoch  955 | Train=0.000933 | Val=0.000943
# [WMSE]  Epoch  956 | Train=0.000932 | Val=0.000942
# [WMSE]  Epoch  957 | Train=0.000930 | Val=0.000941
# [WMSE]  Epoch  958 | Train=0.000929 | Val=0.000940
# [WMSE]  Epoch  959 | Train=0.000928 | Val=0.000939
# [WMSE]  Epoch  960 | Train=0.000927 | Val=0.000937
# [WMSE]  Epoch  961 | Train=0.000926 | Val=0.000936
# [WMSE]  Epoch  962 | Train=0.000925 | Val=0.000935
# [WMSE]  Epoch  963 | Train=0.000923 | Val=0.000934
# [WMSE]  Epoch  964 | Train=0.000922 | Val=0.000933
# [WMSE]  Epoch  965 | Train=0.000921 | Val=0.000931
# [WMSE]  Epoch  966 | Train=0.000920 | Val=0.000930
# [WMSE]  Epoch  967 | Train=0.000919 | Val=0.000929
# [WMSE]  Epoch  968 | Train=0.000918 | Val=0.000928
# [WMSE]  Epoch  969 | Train=0.000916 | Val=0.000927
# [WMSE]  Epoch  970 | Train=0.000915 | Val=0.000925
# [WMSE]  Epoch  971 | Train=0.000914 | Val=0.000924
# [WMSE]  Epoch  972 | Train=0.000913 | Val=0.000923
# [WMSE]  Epoch  973 | Train=0.000912 | Val=0.000922
# [WMSE]  Epoch  974 | Train=0.000911 | Val=0.000921
# [WMSE]  Epoch  975 | Train=0.000909 | Val=0.000919
# [WMSE]  Epoch  976 | Train=0.000908 | Val=0.000918
# [WMSE]  Epoch  977 | Train=0.000907 | Val=0.000917
# [WMSE]  Epoch  978 | Train=0.000906 | Val=0.000916
# [WMSE]  Epoch  979 | Train=0.000905 | Val=0.000915
# [WMSE]  Epoch  980 | Train=0.000903 | Val=0.000913
# [WMSE]  Epoch  981 | Train=0.000902 | Val=0.000912
# [WMSE]  Epoch  982 | Train=0.000901 | Val=0.000911
# [WMSE]  Epoch  983 | Train=0.000900 | Val=0.000910
# [WMSE]  Epoch  984 | Train=0.000899 | Val=0.000909
# [WMSE]  Epoch  985 | Train=0.000897 | Val=0.000907
# [WMSE]  Epoch  986 | Train=0.000896 | Val=0.000906
# [WMSE]  Epoch  987 | Train=0.000895 | Val=0.000905
# [WMSE]  Epoch  988 | Train=0.000894 | Val=0.000904
# [WMSE]  Epoch  989 | Train=0.000893 | Val=0.000903
# [WMSE]  Epoch  990 | Train=0.000891 | Val=0.000901
# [WMSE]  Epoch  991 | Train=0.000890 | Val=0.000900
# [WMSE]  Epoch  992 | Train=0.000889 | Val=0.000899
# [WMSE]  Epoch  993 | Train=0.000888 | Val=0.000898
# [WMSE]  Epoch  994 | Train=0.000887 | Val=0.000896
# [WMSE]  Epoch  995 | Train=0.000885 | Val=0.000895
# [WMSE]  Epoch  996 | Train=0.000884 | Val=0.000894
# [WMSE]  Epoch  997 | Train=0.000883 | Val=0.000893
# [WMSE]  Epoch  998 | Train=0.000882 | Val=0.000892
# [WMSE]  Epoch  999 | Train=0.000881 | Val=0.000890

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5), sharey=True)

# MSE
epochs_mse = np.arange(1, len(train_losses) + 1)
axes[0].plot(epochs_mse, train_losses, label="Train", linewidth=2)
axes[0].plot(epochs_mse, val_losses, label="Validation", linewidth=2)
axes[0].set_title("MSE Training")
axes[0].set_xlabel("Epochs")
axes[0].set_ylabel("Loss")
axes[0].set_yscale("log")
axes[0].legend()
axes[0].grid(True, which="both", alpha=0.4)

# WMSE
epochs_wmse = np.arange(1, len(wmse_train_losses) + 1)
axes[1].plot(epochs_wmse, wmse_train_losses, label="Train", linewidth=2)
axes[1].plot(epochs_wmse, wmse_val_losses, label="Validation", linewidth=2)
axes[1].set_title("WMSE Training")
axes[1].set_xlabel("Epochs")
axes[1].set_yscale("log")
axes[1].legend()
axes[1].grid(True, which="both", alpha=0.4)

plt.tight_layout()
plt.show()

# %% [markdown]
# >Both objectives exibits stable and smooth convergence with nearly identical loss trajectories across full training horizon. Training and validation curves remian closely aligned in both the cases indicating no overfitting. Moreover this indicates that Gaussain sample weights in loss doesnot materially cause any numerical instability or convergence issues. Since the weighting scheme is smooth, bounded and strictly positive it preserves the well behaved optimization lanscape of the sqaured error loss.

# %% [markdown]
# #### Compute predictions on Test Sets

# %%
# test set evaluation 
def evaluate_model(model, x, y, weights, model_name='Model'):   # weights w_i(M,T) are required for wmse calcualtions 
    model.eval()                                               # deactivates dropuout and batchnorm during inference                             
    with torch.no_grad():                                      # no gradient calculation for the code block, for memory and fast inference 
        pred = model(x).squeeze()
        
        
        # evaluation metrics 
        mse = nn.MSELoss()(pred, y).item()
        mae = torch.mean(torch.abs(pred - y)).item()
        rmse = np.sqrt(mse)            
        eps = 1e-8                                                # to avoid not defined results for the MAPE E[y-ycap/y]
        mape = torch.mean(torch.abs((pred - y) / (y.abs() + eps))).item()
        
        
        # weighted metrics 
        wmse = weighted_mse(pred, y, weights).item()               # weighte mse  
        
        
        # ATM-specific metrics (|M| < 0.1)
        M = x[:, 0] 
        atm_mask = torch.abs(M) < 0.1 
        
        
        # check if atm sample greater than 0
        if atm_mask.sum() > 0:
            atm_mse = nn.MSELoss()(pred[atm_mask], y[atm_mask]).item()
            atm_mae = torch.mean(torch.abs(pred[atm_mask] - y[atm_mask])).item()
            atm_rmse = np.sqrt(atm_mse)
            atm_mape = torch.mean(torch.abs((pred[atm_mask] - y[atm_mask]) / y[atm_mask])).item()
        else:
            atm_mse = atm_mae = atm_rmse = atm_mape = float('nan')         
            
        # short dated - ATM options are evaluatee seperately to check the objective function performance
        # and compare high gamma and hedging sensetive region 
        # ATM-short dated matrics 
        T = x[:, 1]
        short_atm_mask = (torch.abs(M) < 0.1) & (torch.abs(T) < 0.04)                              # near atm and 15 days to expiry
        if short_atm_mask.sum() > 0:
            short_atm_mse = nn.MSELoss()(pred[short_atm_mask], y[short_atm_mask]).item()
            short_atm_rmse = np.sqrt(short_atm_mse)
            short_atm_mae = torch.mean(torch.abs(pred[short_atm_mask] - y[short_atm_mask])).item()
        else:
            short_atm_mse = short_atm_rmse = short_atm_mae = float('nan')
        
    # result dict 
    results = {
        'model': model_name,
        'overall_mse': mse,
        'overall_rmse': rmse,
        'overall_mae': mae,
        'overall_mape': mape,
        'weighted_mse': wmse,
        'atm_mse': atm_mse,
        'atm_rmse': atm_rmse,
        'atm_mae': atm_mae,
        'atm_mape': atm_mape,
        'short_atm_mse': short_atm_mse,
        'short_atm_rmse': short_atm_rmse,
        'atm_samples': atm_mask.sum().item(),
        'short_atm_samples': short_atm_mask.sum().item(),
        'short_atm_mae': short_atm_mae
    }
    
    return results, pred.cpu().numpy() # convert to numpy array for plots

# %%
mse_results, mse_pred = evaluate_model(model_mse, x_test, y_test, weights_test, "MSE")
wmse_results, wmse_pred = evaluate_model(model_wmse, x_test, y_test, weights_test, "WMSE")

df_results = pd.DataFrame([mse_results, wmse_results])
df_results.set_index("model")
# Out:
#        overall_mse  overall_rmse  overall_mae  overall_mape  weighted_mse  \
# model
# MSE       0.001010      0.031786     0.025545  371598.71875      0.001080
# WMSE      0.000974      0.031208     0.024289  404298.03125      0.000866
#
#         atm_mse  atm_rmse   atm_mae      atm_mape  short_atm_mse  \
# model
# MSE    0.002888  0.053740  0.044745  3.354672e+29       0.008688
# WMSE   0.001815  0.042607  0.034778  2.820979e+29       0.005527
#
#        short_atm_rmse  atm_samples  short_atm_samples  short_atm_mae
# model
# MSE          0.093207         2631                188       0.092462
# WMSE         0.074345         2631                188       0.073697

# %%
# percentage 
 
delta_mse = (wmse_results['overall_mse'] - mse_results['overall_mse']) / mse_results['overall_mse'] * 100
print(f" Delta Overall MSE: {delta_mse:.4f}")

delta_mae = (wmse_results['overall_mae'] - mse_results['overall_mae']) / mse_results['overall_mae'] * 100
print(f" Delta Overall MAE: {delta_mae:.4f}")

delta_rmse = (wmse_results['overall_rmse'] - mse_results['overall_rmse']) / mse_results['overall_rmse'] * 100
print(f" Delta Overall RMSE: {delta_rmse:.4f}")

delta_atm_mae = (wmse_results['atm_mae'] - mse_results['atm_mae']) / mse_results['atm_mae'] * 100
print(f" Delta ATM MAE: {delta_atm_mae:.4f}")

delta_atm_rmse = (wmse_results['atm_rmse'] - mse_results['atm_rmse']) / mse_results['atm_rmse'] * 100
print(f" Delta ATM RMSE: {delta_atm_rmse:.4f}")

delta_atm_mse = (wmse_results['atm_mse'] - mse_results['atm_mse']) / mse_results['atm_mse'] * 100
print(f" Delta ATM MSE: {delta_atm_mse:.4f}")

delta_short_atm_mse = (wmse_results['short_atm_mse'] - mse_results['short_atm_mse']) / mse_results['short_atm_mse'] * 100
print(f" Short ATM MSE: {delta_short_atm_mse:.4f}")

delta_short_atm_rmse = (wmse_results['short_atm_rmse'] - mse_results['short_atm_rmse']) / mse_results['short_atm_rmse'] * 100
print(f" Short ATM RMSE: {delta_atm_rmse:.4f}")

delta_short_atm_mae = (wmse_results['short_atm_mae'] - mse_results['short_atm_mae']) / mse_results['short_atm_mae'] * 100
print(f" Short ATM MAE: {delta_short_atm_mae:.4f}")
# Out:
#  Delta Overall MSE: -3.6056
#  Delta Overall MAE: -4.9186
#  Delta Overall RMSE: -1.8194
#  Delta ATM MAE: -22.2767
#  Delta ATM RMSE: -20.7168
#  Delta ATM MSE: -37.1418
#  Short ATM MSE: -36.3788
#  Short ATM RMSE: -20.7168
#  Short ATM MAE: -20.2951

# %% [markdown]
# ### Evaluation
# - WMSE performs slightly better in overall fit
# - WMSE performs very good when only compared in ATM-Short Dated option
#
# Hence, we can cofidently say that, Weighted MSE performs better as overall model as well as gives strong performance in the economicly significant region.
#
# Additionally, even after using the small eps for the numerical stability for MAPE, they are ill-poised for the out-of-money errors and doesnot provide any robust comparision

# %%
# Scatter plot for moneyness error 
# detach to break the graph; prevents memory leak during plotting 
# detach has shared memory so donont modify inplace 
y_true = y_test.detach().cpu().numpy().squeeze()
pred_mse = mse_pred.squeeze()
pred_wmse = wmse_pred.squeeze()
res_mse = pred_mse - y_true
res_wmse = pred_wmse - y_true

plt.figure()
plt.hist(res_mse, bins=60, alpha=0.5, label="MSE Model")
plt.hist(res_wmse, bins=60, alpha=0.5, label="WMSE Model")
plt.xlabel("Residual (ŷ - y)")
plt.ylabel("Count")
plt.title("Residual Distribution")
plt.legend()
plt.tight_layout()
plt.show()


x_np = x_test.detach().cpu().numpy()
M = x_np[:, 0]
T = x_np[:, 1]

abs_err_mse = np.abs(res_mse)
abs_err_wmse = np.abs(res_wmse)

plt.figure()
plt.scatter(M, abs_err_mse, s=5, alpha=0.5, label="MSE Model")
plt.scatter(M, abs_err_wmse, s=5, alpha=0.5, label="WMSE Model")
plt.xlabel("Moneyness M")
plt.ylabel(" Absolute Error")
plt.title("Absolute error vs moneyness")
plt.legend()
plt.show()

# %% [markdown]
# > **Residual Distribution**:
# > - Residual Distrubution suggests that both MSE and WMSE Models are centered around zero (slightly negative), and hence both are unbiased. This confirms that using WMSE does not introduce any systematic bias in the model
# > - WMSE Model has slighlty tighter distribution around mean which suggests that there is little variance reduction in predictions compared to MSE
# > - The residuals are following gaussian distribution and donot have any heavy tail and outliers
# > - its important to note that a slight negative errors suggests that the model is undervalauing the option prices >
#
# > **Absolute Error based on Moneyness**
# > - There is an evident reduction of error for ATM options
# > - However the error increeses at deep-in the money and deep- out of the money options; this tradeoff can be justified as deep-itm and deep-otm options are less liquid and have high bid-ask spreads. We can conclude that on synthetic data, the model behaves the way it is intended, focusing on ATM and short dated options without introducing significant bias (except for the deep-ITM -OTM options)

# %% [markdown]
# ## Market Data

# %%
import pandas as pd
import numpy as np
from scipy.stats import norm, qmc
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import yfinance
import datetime
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns

# %%
import random
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", DEVICE)
# Out:
# Using device: cpu

# %%
# reproducibility
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

# %%
df_market = pd.read_csv("market_data.csv")
df_market.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'optionSymbol', 'expiration', 'dte',
#        'intrinsicValue', 'extrinsicValue', 'strike', 'mid', 'underlyingPrice',
#        'spot_price', 'snapshot_date', 'volume', 'inTheMoney', 't_ann', 'M',
#        'VIX', 'C/K', 'C', 'pred_ck_mse', 'pred_ck_wmse', 'pred_mid_mse',
#        'pred_mid_wmse', 'ATM', 'SHORT', 'ATM_x_SHORT', 'C_dollar'],
#       dtype='object')

# %% [markdown]
# #### Loading, Cleaning and Feature Engineering
# - Fetaure
#     - `M`= log(S/K): Log moneyness
#     - `t_ann` = time to maturity annulized
#     - `sigma` = VIX is chosen as a proxy, if VIX is not available then constant Vol = 0.20
#       - IV is avoided to avoid circularity
# - Traget
#     - `y_{c/k}`= `mid`/`Strike` (Normalized Call price by Strike price)

# %%
CSV_PATH = "market_data.csv"
df = pd.read_csv(CSV_PATH)

# Check required columns exist
req = ["snapshot_date", "t_ann", "M", "mid", "strike"]

# parsing date 
df["snapshot_date"] = pd.to_datetime(df["snapshot_date"], errors="coerce")
df = df[df["snapshot_date"].notna()].copy()

# Clean data
df = df[np.isfinite(df[["t_ann","M","mid","strike"]]).all(axis=1)].copy()
df = df[(df["t_ann"] > 0) & (df["strike"] > 0) & (df["mid"] >= 0)].copy()

# Create target: C/K
df["y_ck"] = (df["mid"] / df["strike"]).astype(np.float32)

# %% [markdown]
# ##### Data Check
# We enforce basic financial and numerical sanity checks prior to model training. Time-to-maturity (t_ann) is required to be strictly positive to avoid degenerate contracts. All model inputs (M, t_ann, VIX) are constrained to be finite, excluding missing or infinite values that would destabilize optimization. Option strikes are restricted to positive values, and observed mid-prices are constrained to be non-negative, consistent with no-arbitrage bounds. These assertions ensure numerical stability and economic validity of the training dataset.

# %%
# assert 
assert (df_market["t_ann"] > 0).all()
assert np.isfinite(df_market[["M", "t_ann", "VIX"]]).all().all(), "NaNs or infs in X"
assert (df_market["strike"] > 0).all(), "Invalid strikes"
assert (df_market["mid"] >= 0).all(), "Negative prices"            
  
# target variable 
df_market["C/K"] = df_market["mid"] / df_market["strike"]
df_market["C_dollar"] = df_market["mid"]

# %%
def pick_sigma(df):
    if "VIX" in df.columns and np.isfinite(df["VIX"]).mean() > 0.99:
        return "VIX"
    df["sigma_proxy"] = 0.20
    return "sigma_proxy"

sigma_col = pick_sigma(df)

# %% [markdown]
# #### Train:Test Split: Time based split
# - sorted by dates
# - first 80% dates for training
# - last 20% for testing

# %%
dates = np.array(sorted(df["snapshot_date"].unique()))
if len(dates) < 5:
    raise ValueError(f"Need more unique dates for time split, got {len(dates)}")


# 80:20
split = int(0.8 * len(dates))
train_dates = set(dates[:split])
test_dates  = set(dates[split:])


# split base on time 
train_df = df[df["snapshot_date"].isin(train_dates)].copy()
test_df  = df[df["snapshot_date"].isin(test_dates)].copy()

print(f"Unique dates: {len(dates)} | Train dates: {len(train_dates)} | Test dates: {len(test_dates)}")
print(f"Train rows: {len(train_df)} | Test rows: {len(test_df)}")
# Out:
# Unique dates: 195 | Train dates: 156 | Test dates: 39
# Train rows: 38065 | Test rows: 9958

# %% [markdown]
# #### Gaussian weighted loss function calcualtion for the real data

# %%
# # weights implementation
# def gaussian_weights(df, lam=1, beta=0.5, M_col="M", T_col="t_ann", normalize_mean=True):
#     M = df[M_col].astype(float).to_numpy()
#     T = df[T_col].astype(float).to_numpy()
    
#     # weights
#     w = np.exp(-(M**2) / (2.0 * lam**2) - beta * T).astype(np.float32)
#     w = np.clip(w, 1e-4, None)        #  prevents zero-weight underflow
#     w = w / (np.mean(w) + 1e-8)
    
#     # Normalize weights to mean=1
#     if normalize_mean:
#         w = w / (np.mean(w) + 1e-8)
    
#     return w

def gaussian_weights(
    df,
    lam=0.2,              # wider ATM band
    beta=3.0,             # much softer time decay
    M_col="M",
    T_col="t_ann",
    normalize_mean=True,
    w_floor_itm=0.05      # << NEW
):
    M = df[M_col].to_numpy(float)
    T = df[T_col].to_numpy(float)

    w = np.exp(-(M**2)/(2*lam**2) - beta*T)

    # region-aware floor
    itM = M > 0.05
    w[itM] = np.maximum(w[itM], w_floor_itm)

    w = w.astype(np.float32)
    w /= (np.mean(w) + 1e-8)

    if normalize_mean:
        w /= (np.mean(w) + 1e-8)

    return w

# %% [markdown]
# #### Hyperparameter Lambda and Beta

# %%
LAMBDA = 0.4   # lambda (log-moneyness width) 
BETA   = 5.0   # beta (time penalty rate)
ALPHA = 0.9


w_train = gaussian_weights(train_df, 
                           lam=LAMBDA, 
                           beta=BETA)
w_test  = gaussian_weights(test_df,  
                           lam=LAMBDA, 
                           beta=BETA)


# chceck tarin weights
print(f"Train weights: min={w_train.min():.4e}, max={w_train.max():.4e}, mean={w_train.mean():.4f}, median={np.median(w_train):.4f}")
# Out:
# Train weights: min=6.5763e-02, max=1.2974e+00, mean=1.0000, median=1.0838

# %% [markdown]
# #### Feature Engineering
# #### Z-Score Standardization
# The scale and distribution of the inputs are heterogeous and hence required standardization for numerical stability and gradient scaling. Therefore Z-score scaling has been used with the following properties:
# - compute the mu and sigma on training data, and freeze it to avoid lookahead bias
# - apply the same transformation on the test data
# $$\hat x_{test} = \frac{x_{test} - \mu_{train}}{\sigma_{train}}$$

# %%
FEATURES = ["t_ann", "M", sigma_col]  # X=[T, logM, sigma]

# Input features 
X_train = train_df[FEATURES].to_numpy(np.float32)
X_test  = test_df[FEATURES].to_numpy(np.float32)

# target variables 
y_train = train_df["y_ck"].to_numpy(np.float32)                          
y_test  = test_df["y_ck"].to_numpy(np.float32)

# Compute mean/std on TRAIN only
mu = X_train.mean(axis=0)                                             
sd = X_train.std(axis=0)
sd = np.where(sd < 1e-8, 1.0, sd)

# Apply to both train and test 
# the mu and sigma are calulated on the training set only to avoid lookahead bias 
X_train_z = (X_train - mu) / sd
X_test_z  = (X_test  - mu) / sd

# %% [markdown]
# #### DataLoader with weights
# -  batching the dataset into batches for efficient trainig
# - using dataloader for bathcing
# - shuffle=True, training will be shuffled but (only on the training dataset)
#
# PyTorch `DataLoader` is a utility class designed to simplify the load and iteration over the datset for training. It has various contraints for the batching, suffling and processing data.
# - Batching helps to reduce the memory footprint by leveraging parallel processing
# - shuffling prevents the model to overfit to noise by shuffling the dataset on the learning, provides more stable training and avoid stucking in local minima
#
# In our code:
# we are loading the whole dataset from the disk into ram (since dataset is small), converting it into tensor (it lives on RAM), then we `__getitem__` lazy, from the ram on the index i (all labels at i), this avoid making a copy on the ram for the shuffled data on the RAM. Which is abstracted by the the DataLoader class by pytorch

# %%
from torch.utils.data import Dataset, DataLoader

# Data loading and batching 
class OptionDataset(Dataset):
    def __init__(self, X, y, w):
        # convert into tensor 
        self.X = torch.tensor(X, dtype=torch.float32)
        self.y = torch.tensor(y, dtype=torch.float32)
        self.w = torch.tensor(w, dtype=torch.float32)  # Weights 
    
    # length of data    
    def __len__(self):
        return len(self.X)
    
    # get each values at index i
    def __getitem__(self, i):                                         
        return self.X[i], self.y[i], self.w[i]
    

# batch training 
BATCH = 2048

train_ds = OptionDataset(X_train_z, y_train, w_train)
test_ds  = OptionDataset(X_test_z,  y_test,  w_test)

train_loader = DataLoader(train_ds, batch_size=BATCH, shuffle=True, drop_last=False)        
test_loader  = DataLoader(test_ds,  batch_size=BATCH, shuffle=False, drop_last=False)

# %% [markdown]
# #### Model Architecture

# %%
# 17K param model same as above 
class MLP(nn.Module):
    def __init__(self, in_dim=3, hidden=(64, 64), dropout=0.0, use_softplus=True):
        super().__init__()
        layers = []
        d = in_dim
        for h in hidden:
            layers.append(nn.Linear(d, h))
            layers.append(nn.ELU())
            if dropout > 0:
                layers.append(nn.Dropout(dropout))
            d = h  # update input dimension for next layer

        self.body = nn.Sequential(*layers)
        self.out = nn.Linear(d, 1)  # d is last hidden size
        self.softplus = nn.Softplus() if use_softplus else nn.Identity()

    def forward(self, x):
        x = self.body(x)
        x = self.out(x)
        x = self.softplus(x)        # enforces non-negative output
        return x

# %%
m = MLP(in_dim=3, hidden=(64,64), use_softplus=True)
xb = torch.randn(2048, 3)
print(m(xb).shape)  # should be torch.Size([2048, 1])
# Out:
# torch.Size([2048, 1])

# %% [markdown]
# ##### Loss function design
# - we are using the same example as we used in the synthetic dataset.

# %%
def loss_mse(pred, y):
    return torch.mean((pred - y) ** 2)

def loss_wmse(pred, y, w):
    # wighted mse formula see equation*
    return torch.sum(w * (pred - y) ** 2) / torch.sum(w)

# Mixture Loss:  alpha*WMSE + (1-alpha)*MSE
def loss_mix(pred, y, w, alpha=0.7):
    mse  = torch.mean((pred - y) ** 2)
    wmse = torch.sum(w * (pred - y) ** 2) / (torch.sum(w) + 1e-8)
    return alpha * wmse + (1.0 - alpha) * mse

# %% [markdown]
# #### Training and Testing
# - Outer Split: Split the data into 80:20 (train:test)
# - inner split: Split train data into 90:10 (train:val)
# - keep test data completely out of sample
# - validation use early stopping and model selection without peeking the test
# ______________________________

# %% [markdown]
# ##### Helper functions
# 1. inner split
# 2. mask for inner split and validation
# 3. feature selection and numpy extraction

# %% [markdown]
# #### Temporal Data Partitioning
# `inner_split_masks`: This function creates a temporal split on the data by sorting the date and hold out the future date for the validation

# %%
def inner_split_masks(train_df_,
                            date_col = "snapshot_date", 
                            frac_train=0.9
                            ):
    """_summary_
    Time-based split unique dates in the date column,
    prevents look ahead bias by construction 

    Returns:
        inner_mask and val_mask for the time based split for the training dataset 
    """
    # assert missing date col
    assert date_col in train_df_.columns, "Missing Date Column"
    
    # arrange chronologically and select the dates 
    dts = np.array(sorted(train_df_[date_col].unique()))
    
    # cut select the index max of training data, which we will use later for validation, 
    # this avoid look-ahead bias in the validation set 
    cut = max(1, int(frac_train * len(dts)))
    
    # return set for past and future dts for immutable faster lookup later 
    inner_train_dates = set(dts[:cut])
    val_dates = set(dts[cut:])
    
    # convert it into inner and val mask  
    inner_mask = train_df_[date_col].isin(inner_train_dates).to_numpy()
    val_mask   = train_df_[date_col].isin(val_dates).to_numpy()

    # safe assertion 
    assert inner_mask.shape == val_mask.shape                                                 # shape check 
    assert inner_mask.sum() > 0, "No rows in inner train split"                               # greater than 0 rows
    assert val_mask.sum() > 0, "No rows in val split"                                       
    assert not np.any(inner_mask & val_mask), "Overlap between inner train and val!"          # no overlap for look ahead bias in val

    return inner_mask, val_mask

# %% [markdown]
# #### Data preperation and Data Integrity
# - `extract_arrays`: extracts the feature and target columns and convert them into np.float32 for later use
# - `fit_zscore`: Explicitly calls the fit_zscore(X_inner) only on the training set and hence avoid *Data leakage* from the test dataset. For numerical robustness np.where(sd < eps) ensures that the there is 1 SD instead of NaN or Zero

# %%
## Data Extraction and Numpy conversion
def extract_arrays(df_, 
                   feature_cols,
                   y_col="y_ck", 
                   dtype=np.float32):
    """_summary_

    Args:
        df_: training dataFrame 
        feature_cols: t_ann, M and sigma  
        y_col: Strike normalized Call price 
        dtype: Defaults to np.float32.

    Returns:
        X, y numpy arrays 
    """

# check if column exists in df
    assert all(c in df_.columns for c in feature_cols), f"Missing features: {feature_cols}"  
    assert y_col in df_.columns, f"Missing target col: {y_col}"  

    X = df_[feature_cols].to_numpy(dtype)
    y = df_[y_col].to_numpy(dtype)
    return X, y


# apply z-score for inner traing only 
def fit_zscore(X, eps=1e-8):   
    mu = X.mean(axis=0)
    sd = X.std(axis=0)
    sd = np.where(sd < eps, 1.0, sd)     # if feature has zero variance -> sd = 0 -> default to 1   
    return mu, sd

def apply_zscore(X, mu, sd):
    return (X - mu) / sd


# inner val loader and tensors 
def make_inner_val_loaders(
    train_df_,
    feature_cols,
    w_train_all,                 # weights aligned with train_df_ rows (same order)
    date_col="snapshot_date",
    frac_train=0.9,
    batch_size=2048  
):
    
    # masks
    inner_mask, val_mask = inner_split_masks(train_df_, 
                                                   date_col=date_col, 
                                                   frac_train=frac_train)

    # arrays
    X_all, y_all = extract_arrays(train_df_, 
                                  feature_cols, 
                                  y_col="y_ck")

    # split
    X_inner, y_inner, w_inner = X_all[inner_mask], y_all[inner_mask], w_train_all[inner_mask]
    X_val,   y_val,   w_val   = X_all[val_mask],   y_all[val_mask],   w_train_all[val_mask]

    # fit scaler on inner-train only - no lookahead into val  
    mu, sd = fit_zscore(X_inner)

    # the X_val and X_inner z score values are kept seperate 
    X_inner_z = apply_zscore(X_inner, mu, sd).astype(np.float32)       
    X_val_z   = apply_zscore(X_val,   mu, sd).astype(np.float32) 

    # generator seed
    g = torch.Generator()
    g.manual_seed(SEED)
    
    # datasets/loaders
    inner_ds = OptionDataset(X_inner_z, y_inner, w_inner)
    inner_loader = DataLoader(inner_ds, 
                              batch_size=batch_size, 
                              shuffle=True, 
                              drop_last=False, 
                              generator=g)

    # val tensors
    X_val_t = torch.tensor(X_val_z, dtype=torch.float32, device=DEVICE)
    y_val_t = torch.tensor(y_val,   dtype=torch.float32, device=DEVICE)
    w_val_t = torch.tensor(w_val,   dtype=torch.float32, device=DEVICE)

    return inner_loader, (X_val_t, y_val_t, w_val_t), (mu, sd), (inner_mask, val_mask)

# %% [markdown]
# ##### Training function for EPOCH and Loss Calcualtions
# This function implements a single epoch training using opt=ADAM optimizer. During each iteration, loader from DataLoader provides the mini-batches of inputs (xb), targets (yb) and sample weights (wb). All tensor are passed to DEVICE.
#
# The objective is selected dynamically using the mode parameter:
# 1. 'mse': Mean squared error, treating all the error samples uniformly
# 2. 'wmse': wighted mean square error with the ephasis on ATM-short dated options
# 3. 'mix': a convex combination of MSE and WMSE, controlled by a mixing coefficient alpha
#
# Before backprop, gradients are cleared, setting graients to None. Epoch level loss is accumulated as a **sum of batch loss weighted by batch size** rather than averaging per-batch loss directly. This ensure partial batches are handled correctly and loss represent the true sample level avg loss across epochs.
#
# The function returns the avergae loss per observation for the epoch

# %%
import copy
import torch
import torch.nn as nn

# training one EPOCH  
def train_one_epoch(model, loader, opt, mode="mse"): 
    model.train()                                          # set model to training            
    total_loss = 0.0                                       # total loss 
    n_obs = 0                                              # total no of observation in the batch

    for xb, yb, wb in loader:                              # chuck training from loader 
        xb = xb.to(DEVICE)                                     # laoder handles the shuffling of batch data         
        yb = yb.to(DEVICE)                                        # handles partial batches 
        wb = wb.to(DEVICE)

        pred = model(xb).squeeze(-1)

        if mode == "mse":                                     
            loss = loss_mse(pred, yb)
        elif mode == "wmse":
            loss = loss_wmse(pred, yb, wb)
        elif mode == "mix":
            loss = loss_mix(pred, yb, wb, alpha=ALPHA)
        else:
            raise ValueError(f"Unknown mode: {mode}")

        opt.zero_grad(set_to_none=True)                       # Optimization 
        loss.backward()
        opt.step()

        bs = xb.shape[0]                                      # calcualte the batch size              
        total_loss += float(loss.item()) * bs                 # total loss = loss * batch size; convert tensor into -> float 
        n_obs += bs

    return total_loss / max(1, n_obs)                          # final loss = total loss / avg sample in epoch

# %% [markdown]
# ##### Loss Evaluation: MSE, WMSE and MIX model

# %%
# evaluation function for both methods 
@torch.no_grad()                                       # no grad for eval 
def eval_loss(model, 
              X_t, 
              y_t, 
              w_t, 
              mode="mse"):
    model.eval()
    pred = model(X_t).squeeze(-1)

    if mode == "mse":                                  # two models for comparision with different loss function
        return float(loss_mse(pred, y_t).item())
    elif mode == "wmse":                              
        return float(loss_wmse(pred, y_t, w_t).item())
    elif mode == "mix":
        return float(loss_mix(pred, y_t, w_t, alpha=ALPHA).item())
    else:
        raise ValueError(f"Unknown mode: {mode}")

# %% [markdown]
# ##### Model Training and Early Stopping
# - this function uses the `model`, `inner_loader` (to load the batched data), `tain_one_epoch`, and `eval_loss`
# - `model_train_ES` function loop over multiple EPOCH to train the model with early stopping, the early stopping condition is checked using the validation loss with a small tolerance to create a buffer for improvement in the model, the best model weights are then saved and loaded using the `state_dict` object (python dict), it returns model and best_val

# %%
# Training with early stopping 
def model_train_ES(
    model,
    inner_loader,
    val_pack,                 # (X_val_t, y_val_t, w_val_t)
    mode="mse",
    lr=1e-3,
    epochs=100,               
    patience=15,
    tol=1e-6,
    status_print=10
):
    model = model.to(DEVICE)
    opt = torch.optim.Adam(model.parameters(), lr=lr)   

    X_val_t, y_val_t, w_val_t = val_pack    # unpack
  
    best_val = float("inf")                 # best validation loss; initialize at inf 
    best_state = None                       # Model weights when best val was achieved
    bad = 0                                 # a counter for epochs without improvement in val 

    for ep in range(1, epochs + 1):          
        # for each epoch complete pass
        tr = train_one_epoch(model, 
                             inner_loader, 
                             opt, 
                             mode=mode)
        
        # for each epoch calculate eval loss 
        v  = eval_loss(model,                        
                       X_val_t, 
                       y_val_t, 
                       w_val_t, 
                       mode=mode)


        # Early stopping.                                        # if current loss < best_loss - tolerance\
        if v < best_val - tol:                                     # early stopping if no significant error 
            best_val = v                                            # update best val 
            best_state = copy.deepcopy(model.state_dict())          # to save the weights in the dataset
            bad = 0                                                   # for each epoch count the bad 
        else:
            bad += 1                                                # increment if no improvelement for the epoch

        if ep == 1 or ep % status_print == 0:
            print(f"[{mode.upper()}] ep {ep:3d} | train {tr:.6f} | val {best_val:.6f} | bad {bad}/{patience}")

        # if bad epoch > patience stop 
        if bad >= patience:
            break

    # restore the best model from the best epoch 
    if best_state is not None:
        model.load_state_dict(best_state)

    return model, best_val

# %% [markdown]
# #### Test Set Tensor Preparation
# - Standardization: Test features are standardized using the mean (mu) and standard deviation (sd) computed on the training set only.

# %%
# convert to tensors 
def make_test_tensors(test_df, 
                      feature_cols, 
                      mu, 
                      sd, 
                      w_test, 
                      y_col="y_ck"):
    # raw arrays
    X_test = test_df[feature_cols].to_numpy(np.float32)
    y_test = test_df[y_col].to_numpy(np.float32)

    # Standardize using taraing statistics - apply TRAIN-FIT scaler (mu, sd)
    X_test_z = ((X_test - mu) / sd).astype(np.float32)

    
    # create tensors 
    X_test_t = torch.tensor(X_test_z, 
                            dtype=torch.float32, 
                            device=DEVICE)              # to have consistent output after division we convert again to float32
    y_test_t = torch.tensor(y_test,   
                            dtype=torch.float32, 
                            device=DEVICE)
    w_test_t = torch.tensor(w_test,   
                            dtype=torch.float32, 
                            device=DEVICE)
    return X_test_t, y_test_t, w_test_t

# %% [markdown]
# #### Metrics and  Evaluation
# The module below provides a the metrics to compare the three models (MSE, WMSE and MIX objective function) to understand the performace on the MSE, WMSE, RMSE and MAE.

# %%
# Predict  
# model eval mode on MSE, WMSE, MAE, RMSE
@torch.no_grad()
def predict(model, X_t):
    model.eval()
    return model(X_t).squeeze(-1).detach().cpu().numpy()      # no gradients to numpy array 

# METRICS 
# MSE 
def mse(a, b):
    a = np.asarray(a)
    b = np.asarray(b)
    return float(np.mean((a - b) **2))

# WMSE 
def wmse(a, b, w):
    a = np.asarray(a)
    b = np.asarray(b)
    w = np.asarray(w)
    return float(np.sum(w * (a - b)**2) / np.sum(w))

# Metrics 
# rmse 
def rmse(a, b):
    a = np.asarray(a)
    b = np.asarray(b)
    return float(np.sqrt(np.mean((a - b) ** 2)))                # float gives better precision compared to np.float

# mae 
def mae(a, b):
    a = np.asarray(a)
    b = np.asarray(b)
    return float(np.mean(np.abs(a - b)))        

# eval on the following metrics 
def eval_on_test(model, X_test_t, y_test_t, w_test_t):
    yhat = predict(model, X_test_t)
    ytrue = y_test_t.detach().cpu().numpy()

    # unwighted results 
    results = {
        "mse": mse(yhat, ytrue),
        "rmse": rmse(yhat, ytrue),
        "mae": mae(yhat, ytrue),
        "yhat_mean": float(np.mean(yhat)),
        "y_mean": float(np.mean(ytrue)),
    }
    
    # weighted result addition 
    if w_test_t is not None:
        w_test = w_test_t.detach().cpu().numpy()
        results["wmse"] = wmse(yhat, ytrue, w_test)
        
    return results

# %% [markdown]
# ### Model Experiment: MSE vs WMSE vs MIX Model
# This is a controlled experiment for comparing only the objective function on the same architecture and same dataset with same initialization. The only difference is the objective function.
#
# This block constitutes a clean ablation study where:
# - architecture and data are held constant,
# - initialization is identical across models,
# - training hyperparameters and early stopping rules are identical,
# - and the only treatment variable is the loss function.

# %%
# inner/val loaders and scaler 
inner_loader, val_pack, (mu_in, sd_in), (inner_mask, val_mask) = make_inner_val_loaders(
                                                                        train_df,
                                                                        feature_cols=FEATURES,
                                                                        w_train_all=w_train,
                                                                        date_col="snapshot_date",
                                                                        frac_train=0.9,
                                                                        batch_size=BATCH
                                                                    )

# initialize models from identical weights - for comparision 
base = MLP(in_dim=len(FEATURES),                             # create a base state and use for MSE and WMSE Model  
           hidden=(64,64), 
           dropout=0.0).to(DEVICE)
base_state = copy.deepcopy(base.state_dict())


# MSE-MODEL
model_mse = MLP(in_dim=len(FEATURES),                 
                hidden=(64,64),                             
                dropout=0.0).to(DEVICE)
model_mse.load_state_dict(base_state)


# WMSE-MODEL
model_wmse = MLP(in_dim=len(FEATURES), 
                 hidden=(64,64), 
                 dropout=0.0).to(DEVICE)
model_wmse.load_state_dict(base_state)


# MIX-MODEL
model_mix = MLP(in_dim=len(FEATURES), 
                hidden=(64,64), 
                dropout=0.0).to(DEVICE)
model_mix.load_state_dict(base_state)


# train all three (same data, same init)
# mse loss
model_mse,  best_val_mse  = model_train_ES(model_mse,  
                                        inner_loader, 
                                        val_pack, 
                                        mode="mse",
                                        lr=1e-3, 
                                        epochs=300, 
                                        patience=15)


# wmse loss
model_wmse, best_val_wmse = model_train_ES(model_wmse, 
                                    inner_loader, 
                                    val_pack, 
                                    mode="wmse",
                                    lr=1e-3, 
                                    epochs=300, 
                                    patience=15)

# mix loss
model_mix, best_val_mix = model_train_ES(
    model_mix,
    inner_loader,
    val_pack,
    mode="mix",
    lr=1e-3,
    epochs=300,
    patience=15
)

print("Best val mse:", best_val_mse)
print("Best val wmse:", best_val_wmse)
print("Best val mix:", best_val_mix)


# build test tensors using the SAME mu/sd (mu_in, sd_in)
X_test_t, y_test_t, w_test_t = make_test_tensors(test_df, FEATURES, mu_in, sd_in, w_test, y_col="y_ck")

# evaluate on test
print("TEST MSE model:",  eval_on_test(model_mse,  X_test_t, y_test_t, w_test_t))
print("TEST WMSE model:", eval_on_test(model_wmse, X_test_t, y_test_t, w_test_t))
print("TEST MIX model:", eval_on_test(model_mix, X_test_t, y_test_t, w_test_t))
# Out:
# [MSE] ep   1 | train 0.180908 | val 0.045372 | bad 0/15
# [MSE] ep  10 | train 0.002892 | val 0.002169 | bad 0/15
# [MSE] ep  20 | train 0.001971 | val 0.001381 | bad 0/15
# [MSE] ep  30 | train 0.001058 | val 0.000726 | bad 0/15
# [MSE] ep  40 | train 0.000476 | val 0.000347 | bad 0/15
# [MSE] ep  50 | train 0.000261 | val 0.000201 | bad 0/15
# [MSE] ep  60 | train 0.000181 | val 0.000150 | bad 0/15
# [MSE] ep  70 | train 0.000139 | val 0.000115 | bad 2/15
# [MSE] ep  80 | train 0.000108 | val 0.000093 | bad 0/15
# [MSE] ep  90 | train 0.000083 | val 0.000075 | bad 1/15
# [MSE] ep 100 | train 0.000064 | val 0.000055 | bad 0/15
# [MSE] ep 110 | train 0.000051 | val 0.000046 | bad 0/15
# [MSE] ep 120 | train 0.000039 | val 0.000038 | bad 1/15
# [MSE] ep 130 | train 0.000032 | val 0.000032 | bad 1/15
# [MSE] ep 140 | train 0.000027 | val 0.000029 | bad 2/15
# [MSE] ep 150 | train 0.000024 | val 0.000024 | bad 1/15
# [MSE] ep 160 | train 0.000021 | val 0.000022 | bad 2/15
# [MSE] ep 170 | train 0.000019 | val 0.000020 | bad 4/15
# [MSE] ep 180 | train 0.000017 | val 0.000018 | bad 3/15
# [MSE] ep 190 | train 0.000015 | val 0.000016 | bad 6/15
# [MSE] ep 200 | train 0.000014 | val 0.000014 | bad 2/15
# [MSE] ep 210 | train 0.000013 | val 0.000013 | bad 2/15
# [MSE] ep 220 | train 0.000012 | val 0.000012 | bad 4/15
# [MSE] ep 230 | train 0.000011 | val 0.000011 | bad 2/15
# [MSE] ep 240 | train 0.000010 | val 0.000011 | bad 12/15
# [MSE] ep 250 | train 0.000009 | val 0.000009 | bad 9/15
# [MSE] ep 260 | train 0.000009 | val 0.000008 | bad 4/15
# [MSE] ep 270 | train 0.000008 | val 0.000008 | bad 14/15
# [WMSE] ep   1 | train 0.165521 | val 0.046483 | bad 0/15
# [WMSE] ep  10 | train 0.002161 | val 0.001844 | bad 0/15
# [WMSE] ep  20 | train 0.001415 | val 0.001194 | bad 0/15
# [WMSE] ep  30 | train 0.001087 | val 0.000861 | bad 0/15
# [WMSE] ep  40 | train 0.000799 | val 0.000636 | bad 0/15
# [WMSE] ep  50 | train 0.000523 | val 0.000435 | bad 0/15
# [WMSE] ep  60 | train 0.000310 | val 0.000278 | bad 0/15
# [WMSE] ep  70 | train 0.000184 | val 0.000179 | bad 0/15
# [WMSE] ep  80 | train 0.000126 | val 0.000128 | bad 0/15
# [WMSE] ep  90 | train 0.000100 | val 0.000100 | bad 0/15
# [WMSE] ep 100 | train 0.000083 | val 0.000082 | bad 0/15
# [WMSE] ep 110 | train 0.000069 | val 0.000069 | bad 0/15
# [WMSE] ep 120 | train 0.000058 | val 0.000057 | bad 0/15
# [WMSE] ep 130 | train 0.000050 | val 0.000050 | bad 1/15
# [WMSE] ep 140 | train 0.000043 | val 0.000042 | bad 0/15
# [WMSE] ep 150 | train 0.000037 | val 0.000036 | bad 0/15
# [WMSE] ep 160 | train 0.000032 | val 0.000031 | bad 1/15
# [WMSE] ep 170 | train 0.000028 | val 0.000027 | bad 0/15
# [WMSE] ep 180 | train 0.000024 | val 0.000024 | bad 2/15
# [WMSE] ep 190 | train 0.000021 | val 0.000021 | bad 0/15
# [WMSE] ep 200 | train 0.000019 | val 0.000018 | bad 0/15
# [WMSE] ep 210 | train 0.000017 | val 0.000017 | bad 4/15
# [WMSE] ep 220 | train 0.000015 | val 0.000015 | bad 3/15
# [WMSE] ep 230 | train 0.000014 | val 0.000014 | bad 6/15
# [WMSE] ep 240 | train 0.000012 | val 0.000011 | bad 0/15
# [WMSE] ep 250 | train 0.000011 | val 0.000010 | bad 1/15
# [WMSE] ep 260 | train 0.000010 | val 0.000009 | bad 0/15
# [WMSE] ep 270 | train 0.000010 | val 0.000009 | bad 10/15
# [WMSE] ep 280 | train 0.000009 | val 0.000008 | bad 8/15
# [WMSE] ep 290 | train 0.000008 | val 0.000007 | bad 3/15
# [WMSE] ep 300 | train 0.000008 | val 0.000007 | bad 13/15
# [MIX] ep   1 | train 0.167481 | val 0.045976 | bad 0/15
# [MIX] ep  10 | train 0.002272 | val 0.001893 | bad 0/15
# [MIX] ep  20 | train 0.001596 | val 0.001260 | bad 0/15
# [MIX] ep  30 | train 0.001228 | val 0.000943 | bad 0/15
# [MIX] ep  40 | train 0.000835 | val 0.000667 | bad 0/15
# [MIX] ep  50 | train 0.000497 | val 0.000422 | bad 0/15
# [MIX] ep  60 | train 0.000274 | val 0.000254 | bad 0/15
# [MIX] ep  70 | train 0.000170 | val 0.000168 | bad 0/15
# [MIX] ep  80 | train 0.000128 | val 0.000127 | bad 0/15
# [MIX] ep  90 | train 0.000105 | val 0.000104 | bad 0/15
# [MIX] ep 100 | train 0.000086 | val 0.000085 | bad 0/15
# [MIX] ep 110 | train 0.000072 | val 0.000072 | bad 0/15
# [MIX] ep 120 | train 0.000060 | val 0.000060 | bad 0/15
# [MIX] ep 130 | train 0.000051 | val 0.000052 | bad 1/15
# [MIX] ep 140 | train 0.000044 | val 0.000044 | bad 0/15
# [MIX] ep 150 | train 0.000037 | val 0.000038 | bad 1/15
# [MIX] ep 160 | train 0.000032 | val 0.000032 | bad 0/15
# [MIX] ep 170 | train 0.000028 | val 0.000029 | bad 1/15
# [MIX] ep 180 | train 0.000024 | val 0.000025 | bad 2/15
# [MIX] ep 190 | train 0.000021 | val 0.000022 | bad 0/15
# [MIX] ep 200 | train 0.000019 | val 0.000019 | bad 2/15
# [MIX] ep 210 | train 0.000017 | val 0.000017 | bad 1/15
# [MIX] ep 220 | train 0.000015 | val 0.000016 | bad 6/15
# [MIX] ep 230 | train 0.000014 | val 0.000014 | bad 2/15
# [MIX] ep 240 | train 0.000013 | val 0.000013 | bad 5/15
# [MIX] ep 250 | train 0.000012 | val 0.000012 | bad 6/15
# [MIX] ep 260 | train 0.000011 | val 0.000011 | bad 7/15
# [MIX] ep 270 | train 0.000010 | val 0.000010 | bad 6/15
# [MIX] ep 280 | train 0.000009 | val 0.000009 | bad 4/15
# [MIX] ep 290 | train 0.000009 | val 0.000009 | bad 14/15
# [MIX] ep 300 | train 0.000008 | val 0.000007 | bad 9/15
# Best val mse: 8.358768354810309e-06
# Best val wmse: 7.245264896482695e-06
# Best val mix: 7.478974112018477e-06
# TEST MSE model: {'mse': 0.05814395472407341, 'rmse': 0.24113057553768158, 'mae': 0.02210351638495922, 'yhat_mean': 0.3728775978088379, 'y_mean': 0.39178839325904846, 'wmse': 0.004264452029019594}
# TEST WMSE model: {'mse': 0.07437066733837128, 'rmse': 0.27270984649658203, 'mae': 0.02593688853085041, 'yhat_mean': 0.3695581257343292, 'y_mean': 0.39178839325904846, 'wmse': 0.005449828691780567}
# TEST MIX model: {'mse': 0.06660093367099762, 'rmse': 0.25807157158851624, 'mae': 0.02407079190015793, 'yhat_mean': 0.37078356742858887, 'y_mean': 0.39178839325904846, 'wmse': 0.004881417844444513}

# %%
# Get predictions (already have this function)
@torch.no_grad()
def predict(model, X_t):
    model.eval()
    return model(X_t).squeeze(-1).detach().cpu().numpy()

# Predict with both models
pred_mse  = predict(model_mse,  X_test_t)
pred_wmse = predict(model_wmse, X_test_t)
pred_mix  = predict(model_mix,  X_test_t)   # <-- NEW

y_true = y_test_t.detach().cpu().numpy()


# Add to test dataframe for analysis
test_df['pred_mse'] = pred_mse
test_df['pred_wmse'] = pred_wmse
test_df['error_mse'] = np.abs(pred_mse - y_true)
test_df['error_wmse'] = np.abs(pred_wmse - y_true)
test_df['sq_error_mse'] = (pred_mse - y_true) ** 2
test_df['sq_error_wmse'] = (pred_wmse - y_true) ** 2

print(f"Shapes: {test_df.shape}")
# Out:
# Shapes: (9958, 34)

# %% [markdown]
# ##### Checks: Negative Option Price
# Since negative option price is violation of the option pricing, we check the role of `softplus` in the output layer which allows for strict non-negative call option pricing

# %%
def neg_report(name, preds):
    n_neg = int((preds < 0).sum())
    print(f"{name}: {n_neg:,} negative predictions ({100*n_neg/len(preds):.2f}%)")

neg_report("MSE model",  pred_mse)
neg_report("WMSE model", pred_wmse)
neg_report("MIX model",  pred_mix)
# Out:
# MSE model: 0 negative predictions (0.00%)
# WMSE model: 0 negative predictions (0.00%)
# MIX model: 0 negative predictions (0.00%)

# %%
# predictions
out = test_df.copy()

out["pred_ck_mse"]  = pred_mse
out["pred_ck_wmse"] = pred_wmse
out["pred_ck_mix"]  = pred_mix              # mix

# errors
out["err_mse"]  = out["pred_ck_mse"]  - y_true
out["err_wmse"] = out["pred_ck_wmse"] - y_true
out["err_mix"]  = out["pred_ck_mix"]  - y_true   # mix

out["abs_err_mse"]  = np.abs(out["err_mse"])
out["abs_err_wmse"] = np.abs(out["err_wmse"])
out["abs_err_mix"]  = np.abs(out["err_mix"])     # mix

out["sq_error_mse"]  = out["err_mse"]**2
out["sq_error_wmse"] = out["err_wmse"]**2
out["sq_error_mix"]  = out["err_mix"]**2         # mix

out.to_csv("preds_test.csv", index=False)
print("Saved: preds_test.csv")
# Out:
# Saved: preds_test.csv

# %%
def wmse_metric(y, yhat, w):
    y = np.asarray(y); yhat = np.asarray(yhat); w = np.asarray(w)
    return float(np.sum(w * (y - yhat)**2) / (np.sum(w) + 1e-12))

w_test_raw = gaussian_weights(test_df, lam=LAMBDA, beta=BETA, normalize_mean=False)

print("\nTest weighted MSE metric:")
print("  MSE-model :",  wmse_metric(y_true, pred_mse,  w_test_raw))
print("  WMSE-model:",  wmse_metric(y_true, pred_wmse, w_test_raw))
print("  MIX-model :",  wmse_metric(y_true, pred_mix,  w_test_raw))
# Out:
# Test weighted MSE metric:
#   MSE-model : 0.0042644524946808815
#   WMSE-model: 0.005449829623103142
#   MIX-model : 0.004881418310105801

# %% [markdown]
# We analyzes model performance across moneyness regimes, with a specific focus on the at-the-money (ATM) region, which is the most liquid and economically relevant part of the option surface.
#
# The thresholds are chosen to:
#
# - separate deep out-of-the-money and deep in-the-money tails,
# - isolate a narrow ATM band around zero where pricing sensitivity (gamma) is highest,
# - align with common practitioner heuristics rather than arbitrary percentiles.

# %%
def categorize_moneyness(M):
    if M < -0.5: return "Deep OTM"
    elif M < -0.05: return "OTM"
    elif M <= 0.05: return "ATM"
    elif M <= 0.5: return "ITM"
    else: return "Deep ITM"

out["moneyness_region"] = out["M"].apply(categorize_moneyness)
out["tradeable"] = (out["y_ck"] >= 0.001) & (out["y_ck"] < 1.0)

atm_mask = (out["M"].abs() < 0.05)

def atm_report(label, sq_err_col):
    rmse_val = float(np.sqrt(out.loc[atm_mask, sq_err_col].mean()))
    return rmse_val

atm_rmse_mse  = atm_report("MSE",  "sq_error_mse")
atm_rmse_wmse = atm_report("WMSE", "sq_error_wmse")
atm_rmse_mix  = atm_report("MIX",  "sq_error_mix")  

print("\nATM REGION (|M| < 0.05) Result:")
print(f"Samples: {int(atm_mask.sum()):,}")
print(f"RMSE (MSE):  {atm_rmse_mse:.6f}")
print(f"RMSE (WMSE): {atm_rmse_wmse:.6f}  | Improvement vs MSE: {100*(atm_rmse_mse-atm_rmse_wmse)/atm_rmse_mse:+.1f}%")
print(f"RMSE (MIX):  {atm_rmse_mix:.6f}   | Improvement vs MSE: {100*(atm_rmse_mse-atm_rmse_mix)/atm_rmse_mse:+.1f}%")
# Out:
# ATM REGION (|M| < 0.05) Result:
# Samples: 2,620
# RMSE (MSE):  0.005148
# RMSE (WMSE): 0.004536  | Improvement vs MSE: +11.9%
# RMSE (MIX):  0.004630   | Improvement vs MSE: +10.1%

# %%
def compare_by_region(df):
    rows = []
    for region in ["Deep OTM", "OTM", "ATM", "ITM", "Deep ITM"]:
        mask = (df["moneyness_region"] == region)
        n = int(mask.sum())
        if n == 0:
            continue

        rmse_mse  = float(np.sqrt(df.loc[mask, "sq_error_mse"].mean()))
        rmse_wmse = float(np.sqrt(df.loc[mask, "sq_error_wmse"].mean()))
        rmse_mix  = float(np.sqrt(df.loc[mask, "sq_error_mix"].mean()))

        rows.append({
            "Region": region,
            "n": n,
            "RMSE (MSE)":  rmse_mse,
            "RMSE (WMSE)": rmse_wmse,
            "RMSE (MIX)":  rmse_mix,
            "WMSE vs MSE %": 100.0 * (rmse_mse - rmse_wmse) / (rmse_mse + 1e-12),
            "MIX vs MSE %":  100.0 * (rmse_mse - rmse_mix)  / (rmse_mse + 1e-12),
        })

    return pd.DataFrame(rows)

print("PERFORMANCE BY REGION:")
reg_tab = compare_by_region(out)
print(reg_tab.to_string(index=False, float_format=lambda x: f"{x:.6g}"))
out.to_csv("predictions_with_analysis.csv", index=False)
# Out:
# PERFORMANCE BY REGION:
#   Region    n  RMSE (MSE)  RMSE (WMSE)  RMSE (MIX)  WMSE vs MSE %  MIX vs MSE %
# Deep OTM  117 4.22858e-06  4.23052e-06 4.24125e-06     -0.0460385     -0.299761
#      OTM 2189  0.00119561   0.00100817  0.00102842        15.6778       13.9838
#      ATM 2620  0.00514805   0.00453563  0.00462966        11.8961       10.0696
#      ITM 3421   0.0019234   0.00189587   0.0017868        1.43128       7.10209
# Deep ITM 1611    0.599458     0.677983    0.641587       -13.0994      -7.02792

# %%
def overall_metrics(y, yhat):
    y = np.asarray(y); yhat = np.asarray(yhat)
    mse  = float(np.mean((y - yhat)**2))
    rmse = float(np.sqrt(mse))
    mae  = float(np.mean(np.abs(y - yhat)))
    return {"mse": mse, "rmse": rmse, "mae": mae, "yhat_mean": float(np.mean(yhat)), "y_mean": float(np.mean(y))}

m_mse  = overall_metrics(y_true, pred_mse)
m_wmse = overall_metrics(y_true, pred_wmse)
m_mix  = overall_metrics(y_true, pred_mix)

summary = pd.DataFrame([m_mse, m_wmse, m_mix], index=["MSE-model", "WMSE-model", "MIX-model"])
summary["RMSE_impr_%_vs_MSE"] = 100.0 * (summary.loc["MSE-model","rmse"] - summary["rmse"]) / (summary.loc["MSE-model","rmse"] + 1e-12)
summary["MAE_impr_%_vs_MSE"]  = 100.0 * (summary.loc["MSE-model","mae"]  - summary["mae"])  / (summary.loc["MSE-model","mae"]  + 1e-12)

print("\nOVERALL TEST FIT:")
print(summary[["mse","rmse","mae","RMSE_impr_%_vs_MSE","MAE_impr_%_vs_MSE","yhat_mean","y_mean"]]
      .to_string(float_format=lambda x: f"{x:.6g}"))
summary.to_csv("overall_fit_3way.csv")
# Out:
# OVERALL TEST FIT:
#                  mse     rmse       mae  RMSE_impr_%_vs_MSE  MAE_impr_%_vs_MSE  yhat_mean   y_mean
# MSE-model   0.058144 0.241131 0.0221035                   0                  0   0.372878 0.391788
# WMSE-model 0.0743707  0.27271 0.0259369            -13.0963           -17.3428   0.369558 0.391788
# MIX-model  0.0666009 0.258072 0.0240708            -7.02565           -8.90028   0.370784 0.391788

# %%
plt.figure(figsize=(7.5, 4.2))

plt.scatter(out["M"], out["err_mse"],  s=6, alpha=0.22, label="MSE")
plt.scatter(out["M"], out["err_wmse"], s=6, alpha=0.22, label="WMSE")
plt.scatter(out["M"], out["err_mix"],  s=6, alpha=0.22, label=f"MIX (α={ALPHA})")

plt.axhline(0, color="k", lw=1)
plt.axvline(0, color="k", lw=1)

plt.xlabel("Log-Moneyness M = log(S/K)")
plt.ylabel("Prediction Error (C/K)")
plt.title("Prediction Error vs Log-Moneyness (Test Set)")
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Model Robustness Check
# no-arb diagnostic is checked on the test dataset, thus out of sample check. **This only include the tradable universe** which is T > 0.05 years, ultra-short dated options are highly sensetive to marketmicrostucture noise, wide bid-ask spread and discontinious pay-off behaviour near expiry. The stratification is done based on the moneyness where liquid universe is (M <= 0.2) which includes out-of-money, at-the-money and slightly in-the-money options, the deep-in-the-money options M (Log (S/K)) > 0.2 ~ 1.22 or 22% ITM  where the intrincic value dominates.
#
# #### No arb constrain
# For european call option, no-arb requires the option price to satisfy the lower bound
#
# $$C \geq max(S - K^{-rt}, 0$$
#
# meaning the option must be worth atleast its discounted intrinsic value, otherwise, a static arb opportunity exist. Prices are evaluated in normalized in C/K form as above.
#
# A lower-bound violation is recorded when the predicted normalized price falls below the theoretical bound by more than a numerical tolerance eps = 0.001, corresponding to $0.10 per $100 strike.This tolerance accounts for floating-point precision and is well within typical bid-ask spreads for SPY options. Market mid-prices are evaluated against the same no-arbitrage criterion and serve as a baseline. Due to **discretization** i.e. there can be small violation arising due to tick-size and use of mid quotes rather than executable price. Also microstructure effects (stale quotes, bid-ask spread due to liquidity), even observed market prices may exhibit occasional bound violations, providing a realistic benchmark for model performance.

# %%
#  tradable uni
# Tradeable options (exclude ultra-short maturity ~18 days)
tradeable = out[out["t_ann"] > 0.05].copy()

liquid   = tradeable[tradeable["M"] <= 0.2].copy()
deep_itm = tradeable[tradeable["M"] > 0.2].copy()

print(f"Tradeable options: {len(tradeable)}")
print(f"Liquid (M ≤ 0.2): {len(liquid)}")
print(f"Deep ITM (M > 0.2): {len(deep_itm)}")

# normalized bound 
def lower_bound_normalized(df, r=0.035):
    S_over_K = np.exp(df["M"].values)                          # European call lower bound (normalized):
    discount = np.exp(-r * df["t_ann"].values)                      # C/K ≥ max(S/K - e^{-rT}, 0)
    return np.maximum(S_over_K - discount, 0.0)                         # assuming 0.035 risk free interest rate 
                                                                
lb_liquid = lower_bound_normalized(liquid)
lb_deep   = lower_bound_normalized(deep_itm)
# Out:
# Tradeable options: 1032
# Liquid (M ≤ 0.2): 746
# Deep ITM (M > 0.2): 286

# %% [markdown]
# **70% option in the tradable universe**

# %%
# viloation
TOL = 0.001  # $0.10 per $100 strike

def violation_stats(df, preds, lower_bound):
    viol = preds < (lower_bound - TOL)
    return {
        "N": len(preds),
        "Violations (%)": 100 * viol.mean(),
        "MAE ($)": 100 * np.mean(np.abs(preds - df["y_ck"].values))
    }


# results 
models = [
    ("Market", "y_ck"),
    ("MSE",    "pred_ck_mse"),
    ("WMSE",   "pred_ck_wmse"),
    ("MIX",    "pred_ck_mix"),
]

results = []

# Liquid universe
for name, col in models:
    stats = violation_stats(liquid, liquid[col].values, lb_liquid)
    stats.update({"Universe": "Liquid (M≤0.2)", "Model": name})
    results.append(stats)

# Deep ITM universe
for name, col in models:
    stats = violation_stats(deep_itm, deep_itm[col].values, lb_deep)
    stats.update({"Universe": "Deep ITM (M>0.2)", "Model": name})
    results.append(stats)

results_df = pd.DataFrame(results)
print(results_df)
# Out:
#      N  Violations (%)   MAE ($)          Universe   Model
# 0  746        0.000000  0.000000    Liquid (M≤0.2)  Market
# 1  746        8.981233  0.211672    Liquid (M≤0.2)     MSE
# 2  746        0.000000  0.187989    Liquid (M≤0.2)    WMSE
# 3  746        0.000000  0.190553    Liquid (M≤0.2)     MIX
# 4  286        5.944056  0.000000  Deep ITM (M>0.2)  Market
# 5  286       31.468531  0.466583  Deep ITM (M>0.2)     MSE
# 6  286       33.216783  0.848416  Deep ITM (M>0.2)    WMSE
# 7  286       34.965035  0.700001  Deep ITM (M>0.2)     MIX

# %% [markdown]
# ### Summary
# We evaluate the no-arb and MAE on the out of sample data. The analysis focuses on liquid call options $T > 0.05$ & $\, M \leq 0.2$ which consist of 70% of the test sample contracts. The MSE model violates the European call option lower bound by ~9%, whereas the proposed WMSE and Hybrid MIX model resulted into zero no-arb violation for the liquid options.
#
# However, in the deep-ITM (M>0.2) (where also model performance drops significantly -13% when WMSE compared to MSE and -11% for MIX compared to MSE), but there are 5% market violation of the lower bound rule suggesting discretization and market microstructure noise.
